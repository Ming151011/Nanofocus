# %%
import meep as mp
import meep.adjoint as mpa
from meep import Animate2D
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
from meep.materials import Ag
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from PIL import Image
import matplotlib.colors as mcolors

mp.verbosity(1)
TiO2 = mp.Medium(index=2.6)
SiO2 = mp.Medium(index=1.44)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1)

# %% [markdown]
# In this example, we consider wave propagation through a simple 1d nonlinear medium with a non-zero Kerr susceptibility

# %%
os.makedirs('DFT_GAS',exist_ok=True) # Create Folder

# %% [markdown]
# 以下主要為複製在ADJOINT優化下的環境，主要是MAPPIING的函數要相同，才不會使重現結構時出現問題

# %%
resolution = 100
design_region_resolution = int(resolution)

design_region_x_width  = 1   #100 nm
design_region_y_height = 1   #100 nm
design_region_z_height = 0.02  #20 nm or 10nm

pml_size = 1.0
pml_layers = [mp.PML(pml_size,direction=mp.Z)]

Sz_size = 0.6
Sx = design_region_x_width
Sy = design_region_y_height 
Sz = 2 * pml_size + design_region_z_height + Sz_size
cell_size = mp.Vector3(Sx, Sy, Sz)

wavelengths = np.array([1.55])     # wavelengths = np.array([1.5 ,1.55, 1.6])
frequencies = np.array([1 / 1.55])

nf = 1                 #3 #wavelengths Number

minimum_length = 0.02  # minimum length scale (microns)
eta_i = 0.5            # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55           # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e      # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

Source_distance = -0.2

fcen   = 1 / 1.55
width  = 0.2  
fwidth = width * fcen
source_center = mp.Vector3(0,0,Source_distance)  
source_size   = mp.Vector3(design_region_x_width, design_region_y_height, 0)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)]   

Nx = int(design_region_resolution * design_region_x_width) + 1
Ny = int(design_region_resolution * design_region_y_height) + 1
Nz = 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, Ag, grid_type="U_MEAN")
design_region    = mpa.DesignRegion(
            design_variables,
            volume=mp.Volume(
            center=mp.Vector3(0,0,0),
            size=mp.Vector3(design_region_x_width, design_region_y_height, design_region_z_height),
            ),
)

def mapping(x, eta, beta):
    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_x_width,
        design_region_y_height,
        design_region_resolution,
    )
    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)
    projected_field = (npa.fliplr(projected_field) + projected_field) / 2
    projected_field = (npa.flipud(projected_field) + projected_field) / 2  # left-right symmetry    
    
    return projected_field.flatten()


geometry = [mp.Block(center=design_region.center, size=design_region.size, material=design_variables)]

kpoint = mp.Vector3()
sim = mp.Simulation(
    cell_size        = cell_size,
    boundary_layers  = pml_layers,
    geometry         = geometry,
    sources          = source,
    default_material = Air,
    k_point          = kpoint,
    symmetries       = [mp.Mirror(direction=mp.X)],
    resolution       = resolution,
    extra_materials  = [Ag],       # Introducing metal complex terms
)
#---------------------------------------------------------------------------------------------------#


#-----------------[4]---------------------------------#
monitor_position   = mp.Vector3(0, 0, 0)       # Focus position
monitor_size       = mp.Vector3(0.01,0.01,design_region_z_height)     # Focus Size//////0.11
FourierFields_x    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ex,yee_grid=True)
FourierFields_y    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ey,yee_grid=True)
FourierFields_z    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list            = [FourierFields_x,FourierFields_y,FourierFields_z]


def J(fields_x,fields_y,fields_z):
    ET_x = 0
    ET_y = 0
    ET_z = 0
    ET_x_length = fields_x.shape[1]
    ET_y_length = fields_y.shape[1]
    ET_z_length = fields_z.shape[1]
    for k in range(0,ET_x_length):
        ET_x = ET_x + npa.abs(fields_x[:,k]) ** 2
    for k in range(0,ET_y_length):
        ET_y = ET_y + npa.abs(fields_y[:,k]) ** 2
    for k in range(0,ET_z_length):
        ET_z = ET_z + npa.abs(fields_z[:,k]) ** 2
    ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2)  
    return ET


opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decimation_factor = 1 ,           # KEY BUG!!
    maximum_run_time=50,
)

# %% [markdown]
# 以下引入5個檔案
# evaluation_history為FOM趨勢
# beta_A,eta_A,cur_A 為mapping可能用到的參數
# x_A 為最終的結構參數

# %%
evaluation_history = np.load('Post_evaluation_history.npy')
beta_A  = np.load("Post_beta_scale_array.npy")
eta_A   = np.load("Post_eta_i_array.npy")
cur_A   = np.load("Post_cur_beta_array.npy")
x_A     = np.load("Post_x_array.npy")

# %%
plt.figure()
plt.plot(evaluation_history, "o-")

for i in range(1,13):
    plt.axvline(x=15*i, color='purple', linestyle='--', label='x=3')
plt.grid(True)
plt.xlim(0)
plt.ylim(0)
plt.xlabel("Iteration")
plt.ylabel("FOM")
# Out:
# Text(0, 0.5, 'FOM')

# %% [markdown]
# 使用 opt.update_design 函數來將sim裡的結構更新為優化完成的結構

# %%
opt.update_design([mapping(x_A, eta_A, cur_A/beta_A)])  # cur_beta/beta_scale is the final beta in the optimization.
plt.figure(figsize=(5,5))
ax = plt.gca()
opt.plot2D(
    False,
    ax=ax,
    plot_sources_flag=False,
    plot_monitors_flag=False,
    plot_boundaries_flag=False,
    output_plane = mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(design_region_x_width, design_region_y_height, 0))
)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %%
opt.sim = mp.Simulation(
    cell_size=mp.Vector3(Sx, Sy ,Sz),
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point=kpoint,
    #symmetries=[mp.Mirror(direction=mp.X)],
    extra_materials = [Ag],
)
#src = mp.ContinuousSource(frequency=frequencies[0], fwidth=0.01 ,is_integrated=True)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)] 
opt.sim.change_sources(source)

dft_fields_xz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(Sx,0,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_yz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(0,Sy,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_xyz12 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False
                                )

dft_fields_xyz00 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False 
                                )

dft_fields_x0yz0 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(0,Sy,0),
                                yee_grid=False
                                )


#opt.sim.run(until_after_sources = 0)
opt.sim.run(until_after_sources=mp.stop_when_dft_decayed(
            tol=1e-11,
            minimum_run_time=0,
            maximum_run_time=50)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000124931 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 2.62 with resolution 100
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 4.90949 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# FloatProgress(value=0.0, description='0% done ', max=77.5)
# Meep progress: 0.005/77.5 = 0.0% done in 4.6s, 71230.1s to go
# on time step 1 (time=0.005), 4.59221 s/step
# Meep progress: 0.03/77.5 = 0.0% done in 9.3s, 23982.1s to go
# on time step 6 (time=0.03), 0.938099 s/step
# Meep progress: 0.055/77.5 = 0.1% done in 14.2s, 19937.8s to go
# on time step 11 (time=0.055), 0.974313 s/step
# Meep progress: 0.085/77.5 = 0.1% done in 18.6s, 16959.3s to go
# on time step 17 (time=0.085), 0.743303 s/step
# Meep progress: 0.115/77.5 = 0.1% done in 22.9s, 15378.6s to go
# on time step 23 (time=0.115), 0.705402 s/step
# Meep progress: 0.145/77.5 = 0.2% done in 27.1s, 14455.4s to go
# on time step 29 (time=0.145), 0.706948 s/step
# Meep progress: 0.17500000000000002/77.5 = 0.2% done in 31.4s, 13864.1s to go
# on time step 35 (time=0.175), 0.713265 s/step
# Meep progress: 0.20500000000000002/77.5 = 0.3% done in 35.7s, 13471.7s to go
# on time step 41 (time=0.205), 0.72531 s/step
# Meep progress: 0.23500000000000001/77.5 = 0.3% done in 40.2s, 13207.5s to go
# on time step 47 (time=0.235), 0.740022 s/step
# Meep progress: 0.265/77.5 = 0.3% done in 44.9s, 13073.3s to go
# on time step 53 (time=0.265), 0.780707 s/step
# Meep progress: 0.295/77.5 = 0.4% done in 49.6s, 12974.8s to go
# on time step 59 (time=0.295), 0.786751 s/step
# Meep progress: 0.325/77.5 = 0.4% done in 54.3s, 12898.5s to go
# on time step 65 (time=0.325), 0.790135 s/step
# Meep progress: 0.355/77.5 = 0.5% done in 59.1s, 12838.7s to go
# on time step 71 (time=0.355), 0.793639 s/step
# Meep progress: 0.385/77.5 = 0.5% done in 63.8s, 12780.9s to go
# on time step 77 (time=0.385), 0.788098 s/step
# Meep progress: 0.41000000000000003/77.5 = 0.5% done in 67.8s, 12753.7s to go
# on time step 82 (time=0.41), 0.803977 s/step
# Meep progress: 0.435/77.5 = 0.6% done in 71.8s, 12728.9s to go
# on time step 87 (time=0.435), 0.803762 s/step
# Meep progress: 0.46/77.5 = 0.6% done in 75.9s, 12710.3s to go
# on time step 92 (time=0.46), 0.808362 s/step
# Meep progress: 0.485/77.5 = 0.6% done in 79.9s, 12694.6s to go
# on time step 97 (time=0.485), 0.810132 s/step
# Meep progress: 0.51/77.5 = 0.7% done in 84.0s, 12674.9s to go
# on time step 102 (time=0.51), 0.803467 s/step
# Meep progress: 0.535/77.5 = 0.7% done in 88.0s, 12658.8s to go
# on time step 107 (time=0.535), 0.806337 s/step
# Meep progress: 0.56/77.5 = 0.7% done in 92.0s, 12641.7s to go
# on time step 112 (time=0.56), 0.803342 s/step
# Meep progress: 0.585/77.5 = 0.8% done in 96.1s, 12629.6s to go
# on time step 117 (time=0.585), 0.809086 s/step
# Meep progress: 0.61/77.5 = 0.8% done in 100.1s, 12616.6s to go
# on time step 122 (time=0.61), 0.806845 s/step
# Meep progress: 0.635/77.5 = 0.8% done in 104.1s, 12601.2s to go
# on time step 127 (time=0.635), 0.801657 s/step
# Meep progress: 0.66/77.5 = 0.9% done in 108.1s, 12590.2s to go
# on time step 132 (time=0.66), 0.80753 s/step
# Meep progress: 0.685/77.5 = 0.9% done in 112.3s, 12591.5s to go
# on time step 137 (time=0.685), 0.828685 s/step
# Meep progress: 0.71/77.5 = 0.9% done in 116.3s, 12583.0s to go
# on time step 142 (time=0.71), 0.811344 s/step
# Meep progress: 0.735/77.5 = 0.9% done in 120.5s, 12580.1s to go
# on time step 147 (time=0.735), 0.82145 s/step
# Meep progress: 0.76/77.5 = 1.0% done in 124.5s, 12573.1s to go
# on time step 152 (time=0.76), 0.813308 s/step
# Meep progress: 0.785/77.5 = 1.0% done in 128.7s, 12577.0s to go
# on time step 157 (time=0.785), 0.835558 s/step
# Meep progress: 0.81/77.5 = 1.0% done in 132.9s, 12581.2s to go
# on time step 162 (time=0.81), 0.837017 s/step
# Meep progress: 0.835/77.5 = 1.1% done in 137.1s, 12583.7s to go
# on time step 167 (time=0.835), 0.834567 s/step
# Meep progress: 0.865/77.5 = 1.1% done in 141.5s, 12539.8s to go
# on time step 173 (time=0.865), 0.747129 s/step
# Meep progress: 0.895/77.5 = 1.2% done in 145.9s, 12484.7s to go
# on time step 179 (time=0.895), 0.720389 s/step
# Meep progress: 0.925/77.5 = 1.2% done in 150.3s, 12438.6s to go
# on time step 185 (time=0.925), 0.731249 s/step
# Meep progress: 0.9550000000000001/77.5 = 1.2% done in 154.7s, 12397.6s to go
# on time step 191 (time=0.955), 0.737002 s/step
# Meep progress: 0.985/77.5 = 1.3% done in 159.2s, 12368.9s to go
# on time step 197 (time=0.985), 0.75825 s/step
# Meep progress: 1.0150000000000001/77.5 = 1.3% done in 163.8s, 12341.2s to go
# on time step 203 (time=1.015), 0.757561 s/step
# Meep progress: 1.045/77.5 = 1.3% done in 168.2s, 12302.9s to go
# on time step 209 (time=1.045), 0.730315 s/step
# Meep progress: 1.075/77.5 = 1.4% done in 172.5s, 12266.0s to go
# on time step 215 (time=1.075), 0.729225 s/step
# Meep progress: 1.105/77.5 = 1.4% done in 176.8s, 12225.8s to go
# on time step 221 (time=1.105), 0.717019 s/step
# Meep progress: 1.135/77.5 = 1.5% done in 181.2s, 12190.2s to go
# on time step 227 (time=1.135), 0.723682 s/step
# Meep progress: 1.165/77.5 = 1.5% done in 185.5s, 12154.9s to go
# on time step 233 (time=1.165), 0.720508 s/step
# Meep progress: 1.185/77.5 = 1.5% done in 189.9s, 12229.2s to go
# on time step 237 (time=1.185), 1.09686 s/step
# Meep progress: 1.205/77.5 = 1.6% done in 194.6s, 12321.3s to go
# on time step 241 (time=1.205), 1.17737 s/step
# Meep progress: 1.225/77.5 = 1.6% done in 199.4s, 12413.4s to go
# on time step 245 (time=1.225), 1.19017 s/step
# Meep progress: 1.245/77.5 = 1.6% done in 204.1s, 12500.7s to go
# on time step 249 (time=1.245), 1.18299 s/step
# Meep progress: 1.2650000000000001/77.5 = 1.6% done in 208.8s, 12583.8s to go
# on time step 253 (time=1.265), 1.17797 s/step
# Meep progress: 1.285/77.5 = 1.7% done in 213.6s, 12666.6s to go
# on time step 257 (time=1.285), 1.1874 s/step
# Meep progress: 1.305/77.5 = 1.7% done in 218.3s, 12747.2s to go
# on time step 261 (time=1.305), 1.19025 s/step
# Meep progress: 1.325/77.5 = 1.7% done in 223.0s, 12821.3s to go
# on time step 265 (time=1.325), 1.17309 s/step
# Meep progress: 1.345/77.5 = 1.7% done in 227.7s, 12894.3s to go
# on time step 269 (time=1.345), 1.17825 s/step
# Meep progress: 1.365/77.5 = 1.8% done in 232.6s, 12972.3s to go
# on time step 273 (time=1.365), 1.21139 s/step
# Meep progress: 1.385/77.5 = 1.8% done in 237.3s, 13041.3s to go
# on time step 277 (time=1.385), 1.18128 s/step
# Meep progress: 1.405/77.5 = 1.8% done in 242.1s, 13113.0s to go
# on time step 281 (time=1.405), 1.20292 s/step
# Meep progress: 1.425/77.5 = 1.8% done in 246.9s, 13182.0s to go
# on time step 285 (time=1.425), 1.20051 s/step
# Meep progress: 1.445/77.5 = 1.9% done in 251.7s, 13249.0s to go
# on time step 289 (time=1.445), 1.20055 s/step
# Meep progress: 1.465/77.5 = 1.9% done in 256.4s, 13309.9s to go
# on time step 293 (time=1.465), 1.18086 s/step
# Meep progress: 1.485/77.5 = 1.9% done in 261.1s, 13367.8s to go
# on time step 297 (time=1.485), 1.17496 s/step
# Meep progress: 1.5050000000000001/77.5 = 1.9% done in 265.9s, 13428.4s to go
# on time step 301 (time=1.505), 1.19621 s/step
# Meep progress: 1.5250000000000001/77.5 = 2.0% done in 270.7s, 13487.3s to go
# on time step 305 (time=1.525), 1.19686 s/step
# Meep progress: 1.545/77.5 = 2.0% done in 275.6s, 13547.9s to go
# on time step 309 (time=1.545), 1.21337 s/step
# Meep progress: 1.565/77.5 = 2.0% done in 280.2s, 13593.4s to go
# on time step 313 (time=1.565), 1.14459 s/step
# Meep progress: 1.585/77.5 = 2.0% done in 284.7s, 13636.9s to go
# on time step 317 (time=1.585), 1.14076 s/step
# Meep progress: 1.605/77.5 = 2.1% done in 289.3s, 13680.2s to go
# on time step 321 (time=1.605), 1.1455 s/step
# Meep progress: 1.625/77.5 = 2.1% done in 293.9s, 13722.5s to go
# on time step 325 (time=1.625), 1.14684 s/step
# Meep progress: 1.645/77.5 = 2.1% done in 298.5s, 13763.0s to go
# on time step 329 (time=1.645), 1.14335 s/step
# Meep progress: 1.665/77.5 = 2.1% done in 303.0s, 13801.6s to go
# on time step 333 (time=1.665), 1.1389 s/step
# Meep progress: 1.685/77.5 = 2.2% done in 307.6s, 13840.1s to go
# on time step 337 (time=1.685), 1.14395 s/step
# Meep progress: 1.71/77.5 = 2.2% done in 312.2s, 13836.6s to go
# on time step 342 (time=1.71), 0.917076 s/step
# Meep progress: 1.74/77.5 = 2.2% done in 316.5s, 13778.7s to go
# on time step 348 (time=1.74), 0.712065 s/step
# Meep progress: 1.77/77.5 = 2.3% done in 320.7s, 13723.2s to go
# on time step 354 (time=1.77), 0.714177 s/step
# Meep progress: 1.8/77.5 = 2.3% done in 324.9s, 13663.4s to go
# on time step 360 (time=1.8), 0.690745 s/step
# Meep progress: 1.83/77.5 = 2.4% done in 329.0s, 13604.1s to go
# on time step 366 (time=1.83), 0.684943 s/step
# Meep progress: 1.86/77.5 = 2.4% done in 333.2s, 13549.5s to go
# on time step 372 (time=1.86), 0.697347 s/step
# Meep progress: 1.8900000000000001/77.5 = 2.4% done in 337.4s, 13496.1s to go
# on time step 378 (time=1.89), 0.695318 s/step
# Meep progress: 1.92/77.5 = 2.5% done in 341.6s, 13446.7s to go
# on time step 384 (time=1.92), 0.705758 s/step
# Meep progress: 1.95/77.5 = 2.5% done in 345.8s, 13398.8s to go
# on time step 390 (time=1.95), 0.706642 s/step
# Meep progress: 1.98/77.5 = 2.6% done in 350.1s, 13352.5s to go
# on time step 396 (time=1.98), 0.70738 s/step
# Meep progress: 2.0100000000000002/77.5 = 2.6% done in 354.3s, 13307.1s to go
# on time step 402 (time=2.01), 0.705601 s/step
# Meep progress: 2.04/77.5 = 2.6% done in 358.5s, 13262.2s to go
# on time step 408 (time=2.04), 0.702813 s/step
# Meep progress: 2.07/77.5 = 2.7% done in 362.8s, 13219.5s to go
# on time step 414 (time=2.07), 0.707311 s/step
# Meep progress: 2.1/77.5 = 2.7% done in 367.1s, 13180.5s to go
# on time step 420 (time=2.1), 0.719608 s/step
# Meep progress: 2.13/77.5 = 2.7% done in 371.5s, 13143.9s to go
# on time step 426 (time=2.13), 0.726654 s/step
# Meep progress: 2.16/77.5 = 2.8% done in 375.8s, 13107.9s to go
# on time step 432 (time=2.16), 0.724261 s/step
# Meep progress: 2.19/77.5 = 2.8% done in 380.2s, 13072.9s to go
# on time step 438 (time=2.19), 0.725396 s/step
# Meep progress: 2.22/77.5 = 2.9% done in 384.5s, 13037.3s to go
# on time step 444 (time=2.22), 0.718906 s/step
# Meep progress: 2.25/77.5 = 2.9% done in 388.8s, 13002.5s to go
# on time step 450 (time=2.25), 0.718192 s/step
# Meep progress: 2.2800000000000002/77.5 = 2.9% done in 393.2s, 12973.5s to go
# on time step 456 (time=2.28), 0.743369 s/step
# Meep progress: 2.31/77.5 = 3.0% done in 397.6s, 12940.3s to go
# on time step 462 (time=2.31), 0.718763 s/step
# Meep progress: 2.34/77.5 = 3.0% done in 402.0s, 12910.5s to go
# on time step 468 (time=2.34), 0.732588 s/step
# Meep progress: 2.37/77.5 = 3.1% done in 406.3s, 12881.2s to go
# on time step 474 (time=2.37), 0.731776 s/step
# Meep progress: 2.4/77.5 = 3.1% done in 410.7s, 12850.4s to go
# on time step 480 (time=2.4), 0.720032 s/step
# Meep progress: 2.43/77.5 = 3.1% done in 415.2s, 12827.9s to go
# on time step 486 (time=2.43), 0.762161 s/step
# Meep progress: 2.46/77.5 = 3.2% done in 419.9s, 12807.6s to go
# on time step 492 (time=2.46), 0.771132 s/step
# Meep progress: 2.49/77.5 = 3.2% done in 424.5s, 12788.6s to go
# on time step 498 (time=2.49), 0.776417 s/step
# Meep progress: 2.52/77.5 = 3.3% done in 429.2s, 12769.3s to go
# on time step 504 (time=2.52), 0.772795 s/step
# Meep progress: 2.5500000000000003/77.5 = 3.3% done in 433.8s, 12750.5s to go
# on time step 510 (time=2.55), 0.773866 s/step
# Meep progress: 2.58/77.5 = 3.3% done in 438.5s, 12733.1s to go
# on time step 516 (time=2.58), 0.779684 s/step
# Meep progress: 2.61/77.5 = 3.4% done in 443.1s, 12714.9s to go
# on time step 522 (time=2.61), 0.773886 s/step
# Meep progress: 2.64/77.5 = 3.4% done in 447.8s, 12696.7s to go
# on time step 528 (time=2.64), 0.771666 s/step
# Meep progress: 2.67/77.5 = 3.4% done in 452.4s, 12678.0s to go
# on time step 534 (time=2.67), 0.76709 s/step
# Meep progress: 2.7/77.5 = 3.5% done in 456.9s, 12658.2s to go
# on time step 540 (time=2.7), 0.757877 s/step
# Meep progress: 2.73/77.5 = 3.5% done in 461.4s, 12637.1s to go
# on time step 546 (time=2.73), 0.748897 s/step
# Meep progress: 2.7600000000000002/77.5 = 3.6% done in 465.9s, 12616.5s to go
# on time step 552 (time=2.76), 0.748995 s/step
# Meep progress: 2.79/77.5 = 3.6% done in 470.5s, 12598.0s to go
# on time step 558 (time=2.79), 0.760261 s/step
# Meep progress: 2.82/77.5 = 3.6% done in 475.1s, 12581.9s to go
# on time step 564 (time=2.82), 0.773674 s/step
# Meep progress: 2.85/77.5 = 3.7% done in 479.7s, 12565.9s to go
# on time step 570 (time=2.85), 0.772426 s/step
# Meep progress: 2.88/77.5 = 3.7% done in 484.4s, 12549.9s to go
# on time step 576 (time=2.88), 0.771128 s/step
# Meep progress: 2.91/77.5 = 3.8% done in 489.0s, 12534.4s to go
# on time step 582 (time=2.91), 0.772963 s/step
# Meep progress: 2.94/77.5 = 3.8% done in 493.7s, 12519.2s to go
# on time step 588 (time=2.94), 0.77341 s/step
# Meep progress: 2.97/77.5 = 3.8% done in 498.3s, 12504.1s to go
# on time step 594 (time=2.97), 0.772212 s/step
# Meep progress: 3.0/77.5 = 3.9% done in 502.9s, 12489.5s to go
# on time step 600 (time=3), 0.774291 s/step
# Meep progress: 3.0300000000000002/77.5 = 3.9% done in 507.1s, 12464.4s to go
# on time step 606 (time=3.03), 0.702008 s/step
# Meep progress: 3.06/77.5 = 3.9% done in 511.8s, 12451.4s to go
# on time step 612 (time=3.06), 0.782331 s/step
# Meep progress: 3.085/77.5 = 4.0% done in 516.4s, 12455.7s to go
# on time step 617 (time=3.085), 0.906488 s/step
# Meep progress: 3.11/77.5 = 4.0% done in 520.9s, 12459.9s to go
# on time step 622 (time=3.11), 0.906286 s/step
# Meep progress: 3.1350000000000002/77.5 = 4.0% done in 525.5s, 12464.2s to go
# on time step 627 (time=3.135), 0.909249 s/step
# Meep progress: 3.16/77.5 = 4.1% done in 530.0s, 12468.7s to go
# on time step 632 (time=3.16), 0.911705 s/step
# Meep progress: 3.185/77.5 = 4.1% done in 534.6s, 12474.5s to go
# on time step 637 (time=3.185), 0.923515 s/step
# Meep progress: 3.21/77.5 = 4.1% done in 539.3s, 12480.2s to go
# on time step 642 (time=3.21), 0.924345 s/step
# Meep progress: 3.235/77.5 = 4.2% done in 543.9s, 12485.1s to go
# on time step 647 (time=3.235), 0.919022 s/step
# Meep progress: 3.2600000000000002/77.5 = 4.2% done in 548.5s, 12490.9s to go
# on time step 652 (time=3.26), 0.928222 s/step
# Meep progress: 3.285/77.5 = 4.2% done in 553.2s, 12497.9s to go
# on time step 657 (time=3.285), 0.940122 s/step
# Meep progress: 3.31/77.5 = 4.3% done in 557.8s, 12502.7s to go
# on time step 662 (time=3.31), 0.922231 s/step
# Meep progress: 3.335/77.5 = 4.3% done in 562.5s, 12509.6s to go
# on time step 667 (time=3.335), 0.942395 s/step
# Meep progress: 3.36/77.5 = 4.3% done in 567.2s, 12515.0s to go
# on time step 672 (time=3.36), 0.930437 s/step
# Meep progress: 3.3850000000000002/77.5 = 4.4% done in 571.7s, 12518.4s to go
# on time step 677 (time=3.385), 0.912853 s/step
# Meep progress: 3.41/77.5 = 4.4% done in 576.1s, 12516.5s to go
# on time step 682 (time=3.41), 0.865684 s/step
# Meep progress: 3.435/77.5 = 4.4% done in 580.3s, 12512.0s to go
# on time step 687 (time=3.435), 0.842569 s/step
# Meep progress: 3.46/77.5 = 4.5% done in 584.6s, 12508.8s to go
# on time step 692 (time=3.46), 0.854032 s/step
# Meep progress: 3.485/77.5 = 4.5% done in 588.6s, 12500.5s to go
# on time step 697 (time=3.485), 0.80573 s/step
# Meep progress: 3.5100000000000002/77.5 = 4.5% done in 592.6s, 12492.7s to go
# on time step 702 (time=3.51), 0.81049 s/step
# Meep progress: 3.535/77.5 = 4.6% done in 596.7s, 12484.7s to go
# on time step 707 (time=3.535), 0.808173 s/step
# Meep progress: 3.565/77.5 = 4.6% done in 601.0s, 12464.3s to go
# on time step 713 (time=3.565), 0.720574 s/step
# Meep progress: 3.595/77.5 = 4.6% done in 605.0s, 12437.8s to go
# on time step 719 (time=3.595), 0.668668 s/step
# Meep progress: 3.63/77.5 = 4.7% done in 609.7s, 12407.1s to go
# on time step 726 (time=3.63), 0.667568 s/step
# Meep progress: 3.66/77.5 = 4.7% done in 613.7s, 12381.6s to go
# on time step 732 (time=3.66), 0.670052 s/step
# Meep progress: 3.6950000000000003/77.5 = 4.8% done in 618.0s, 12343.2s to go
# on time step 739 (time=3.695), 0.605823 s/step
# Meep progress: 3.73/77.5 = 4.8% done in 622.3s, 12307.5s to go
# on time step 746 (time=3.73), 0.620824 s/step
# Meep progress: 3.765/77.5 = 4.9% done in 627.0s, 12278.7s to go
# on time step 753 (time=3.765), 0.666015 s/step
# Meep progress: 3.795/77.5 = 4.9% done in 631.1s, 12256.9s to go
# on time step 759 (time=3.795), 0.688459 s/step
# Meep progress: 3.825/77.5 = 4.9% done in 635.3s, 12236.1s to go
# on time step 765 (time=3.825), 0.694436 s/step
# Meep progress: 3.855/77.5 = 5.0% done in 639.4s, 12215.9s to go
# on time step 771 (time=3.855), 0.697369 s/step
# Meep progress: 3.8850000000000002/77.5 = 5.0% done in 643.7s, 12196.6s to go
# on time step 777 (time=3.885), 0.703253 s/step
# Meep progress: 3.915/77.5 = 5.1% done in 647.8s, 12176.3s to go
# on time step 783 (time=3.915), 0.692461 s/step
# Meep progress: 3.9450000000000003/77.5 = 5.1% done in 651.8s, 12153.7s to go
# on time step 789 (time=3.945), 0.669692 s/step
# Meep progress: 3.975/77.5 = 5.1% done in 655.9s, 12131.4s to go
# on time step 795 (time=3.975), 0.669524 s/step
# Meep progress: 4.01/77.5 = 5.2% done in 660.5s, 12104.5s to go
# on time step 802 (time=4.01), 0.660217 s/step
# Meep progress: 4.045/77.5 = 5.2% done in 665.1s, 12077.2s to go
# on time step 809 (time=4.045), 0.653949 s/step
# Meep progress: 4.08/77.5 = 5.3% done in 669.7s, 12051.7s to go
# on time step 816 (time=4.08), 0.665589 s/step
# Meep progress: 4.11/77.5 = 5.3% done in 673.7s, 12030.5s to go
# on time step 822 (time=4.11), 0.668644 s/step
# Meep progress: 4.14/77.5 = 5.3% done in 677.7s, 12009.6s to go
# on time step 828 (time=4.14), 0.66912 s/step
# Meep progress: 4.17/77.5 = 5.4% done in 681.8s, 11989.1s to go
# on time step 834 (time=4.17), 0.670482 s/step
# Meep progress: 4.205/77.5 = 5.4% done in 686.4s, 11964.9s to go
# on time step 841 (time=4.205), 0.665983 s/step
# Meep progress: 4.24/77.5 = 5.5% done in 691.1s, 11940.2s to go
# on time step 848 (time=4.24), 0.659027 s/step
# Meep progress: 4.275/77.5 = 5.5% done in 695.7s, 11916.0s to go
# on time step 855 (time=4.275), 0.660733 s/step
# Meep progress: 4.3100000000000005/77.5 = 5.6% done in 700.3s, 11892.7s to go
# on time step 862 (time=4.31), 0.665574 s/step
# Meep progress: 4.34/77.5 = 5.6% done in 704.3s, 11873.3s to go
# on time step 868 (time=4.34), 0.66839 s/step
# Meep progress: 4.37/77.5 = 5.6% done in 708.4s, 11854.1s to go
# on time step 874 (time=4.37), 0.668558 s/step
# Meep progress: 4.4/77.5 = 5.7% done in 712.4s, 11836.0s to go
# on time step 880 (time=4.4), 0.67806 s/step
# Meep progress: 4.43/77.5 = 5.7% done in 716.5s, 11817.5s to go
# on time step 886 (time=4.43), 0.671413 s/step
# Meep progress: 4.46/77.5 = 5.8% done in 720.5s, 11799.7s to go
# on time step 892 (time=4.46), 0.676945 s/step
# Meep progress: 4.49/77.5 = 5.8% done in 724.6s, 11782.7s to go
# on time step 898 (time=4.49), 0.682219 s/step
# Meep progress: 4.5200000000000005/77.5 = 5.8% done in 728.6s, 11764.3s to go
# on time step 904 (time=4.52), 0.667461 s/step
# Meep progress: 4.55/77.5 = 5.9% done in 732.7s, 11747.2s to go
# on time step 910 (time=4.55), 0.678048 s/step
# Meep progress: 4.585/77.5 = 5.9% done in 737.3s, 11725.4s to go
# on time step 917 (time=4.585), 0.660066 s/step
# Meep progress: 4.62/77.5 = 6.0% done in 741.9s, 11703.9s to go
# on time step 924 (time=4.62), 0.660121 s/step
# Meep progress: 4.655/77.5 = 6.0% done in 746.6s, 11682.7s to go
# on time step 931 (time=4.655), 0.660254 s/step
# Meep progress: 4.69/77.5 = 6.1% done in 751.2s, 11661.8s to go
# on time step 938 (time=4.69), 0.661492 s/step
# Meep progress: 4.7250000000000005/77.5 = 6.1% done in 755.8s, 11641.5s to go
# on time step 945 (time=4.725), 0.664159 s/step
# Meep progress: 4.76/77.5 = 6.1% done in 760.5s, 11621.1s to go
# on time step 952 (time=4.76), 0.661308 s/step
# Meep progress: 4.795/77.5 = 6.2% done in 765.1s, 11600.7s to go
# on time step 959 (time=4.795), 0.659548 s/step
# Meep progress: 4.83/77.5 = 6.2% done in 769.7s, 11580.8s to go
# on time step 966 (time=4.83), 0.661584 s/step
# Meep progress: 4.86/77.5 = 6.3% done in 773.7s, 11564.6s to go
# on time step 972 (time=4.86), 0.669856 s/step
# Meep progress: 4.89/77.5 = 6.3% done in 777.8s, 11548.6s to go
# on time step 978 (time=4.89), 0.66993 s/step
# Meep progress: 4.92/77.5 = 6.3% done in 781.8s, 11532.8s to go
# on time step 984 (time=4.92), 0.670166 s/step
# Meep progress: 4.95/77.5 = 6.4% done in 785.8s, 11517.1s to go
# on time step 990 (time=4.95), 0.669992 s/step
# Meep progress: 4.98/77.5 = 6.4% done in 789.8s, 11501.7s to go
# on time step 996 (time=4.98), 0.672145 s/step
# Meep progress: 5.01/77.5 = 6.5% done in 793.9s, 11486.5s to go
# on time step 1002 (time=5.01), 0.672125 s/step
# Meep progress: 5.04/77.5 = 6.5% done in 797.9s, 11471.2s to go
# on time step 1008 (time=5.04), 0.669773 s/step
# Meep progress: 5.07/77.5 = 6.5% done in 801.9s, 11456.1s to go
# on time step 1014 (time=5.07), 0.670233 s/step
# Meep progress: 5.1000000000000005/77.5 = 6.6% done in 805.9s, 11441.0s to go
# on time step 1020 (time=5.1), 0.670262 s/step
# Meep progress: 5.13/77.5 = 6.6% done in 809.9s, 11426.0s to go
# on time step 1026 (time=5.13), 0.668323 s/step
# Meep progress: 5.16/77.5 = 6.7% done in 814.0s, 11411.2s to go
# on time step 1032 (time=5.16), 0.669732 s/step
# Meep progress: 5.19/77.5 = 6.7% done in 818.0s, 11396.6s to go
# on time step 1038 (time=5.19), 0.670749 s/step
# Meep progress: 5.22/77.5 = 6.7% done in 822.0s, 11382.1s to go
# on time step 1044 (time=5.22), 0.66955 s/step
# Meep progress: 5.255/77.5 = 6.8% done in 826.7s, 11365.0s to go
# on time step 1051 (time=5.255), 0.66657 s/step
# Meep progress: 5.285/77.5 = 6.8% done in 830.7s, 11351.0s to go
# on time step 1057 (time=5.285), 0.673355 s/step
# Meep progress: 5.315/77.5 = 6.9% done in 834.8s, 11337.3s to go
# on time step 1063 (time=5.315), 0.675355 s/step
# Meep progress: 5.345/77.5 = 6.9% done in 838.8s, 11323.6s to go
# on time step 1069 (time=5.345), 0.675038 s/step
# Meep progress: 5.375/77.5 = 6.9% done in 842.9s, 11310.0s to go
# on time step 1075 (time=5.375), 0.674014 s/step
# Meep progress: 5.405/77.5 = 7.0% done in 846.9s, 11296.7s to go
# on time step 1081 (time=5.405), 0.676004 s/step
# Meep progress: 5.4350000000000005/77.5 = 7.0% done in 851.0s, 11283.5s to go
# on time step 1087 (time=5.435), 0.676657 s/step
# Meep progress: 5.47/77.5 = 7.1% done in 855.2s, 11261.6s to go
# on time step 1094 (time=5.47), 0.604676 s/step
# Meep progress: 5.505/77.5 = 7.1% done in 859.7s, 11243.2s to go
# on time step 1101 (time=5.505), 0.640509 s/step
# Meep progress: 5.545/77.5 = 7.2% done in 864.1s, 11212.7s to go
# on time step 1109 (time=5.545), 0.546819 s/step
# Meep progress: 5.58/77.5 = 7.2% done in 868.6s, 11195.1s to go
# on time step 1116 (time=5.58), 0.645002 s/step
# Meep progress: 5.62/77.5 = 7.3% done in 872.8s, 11162.9s to go
# on time step 1124 (time=5.62), 0.524671 s/step
# Meep progress: 5.66/77.5 = 7.3% done in 876.9s, 11130.7s to go
# on time step 1132 (time=5.66), 0.520032 s/step
# Meep progress: 5.695/77.5 = 7.3% done in 881.0s, 11108.3s to go
# on time step 1139 (time=5.695), 0.581388 s/step
# Meep progress: 5.73/77.5 = 7.4% done in 885.2s, 11087.4s to go
# on time step 1146 (time=5.73), 0.59756 s/step
# Meep progress: 5.765/77.5 = 7.4% done in 889.3s, 11065.8s to go
# on time step 1153 (time=5.765), 0.585952 s/step
# Meep progress: 5.8/77.5 = 7.5% done in 893.4s, 11044.2s to go
# on time step 1160 (time=5.8), 0.583667 s/step
# Meep progress: 5.835/77.5 = 7.5% done in 897.9s, 11027.4s to go
# on time step 1167 (time=5.835), 0.637986 s/step
# Meep progress: 5.87/77.5 = 7.6% done in 902.3s, 11010.5s to go
# on time step 1174 (time=5.87), 0.634463 s/step
# Meep progress: 5.905/77.5 = 7.6% done in 906.8s, 10994.4s to go
# on time step 1181 (time=5.905), 0.641703 s/step
# Meep progress: 5.94/77.5 = 7.7% done in 911.3s, 10978.8s to go
# on time step 1188 (time=5.94), 0.647005 s/step
# Meep progress: 5.97/77.5 = 7.7% done in 915.4s, 10967.5s to go
# on time step 1194 (time=5.97), 0.673281 s/step
# Meep progress: 6.0/77.5 = 7.7% done in 919.4s, 10955.8s to go
# on time step 1201 (time=6.005), 0.666258 s/step
# Meep progress: 6.03/77.5 = 7.8% done in 923.4s, 10944.3s to go
# on time step 1207 (time=6.035), 0.670878 s/step
# Meep progress: 6.0600000000000005/77.5 = 7.8% done in 927.4s, 10933.1s to go
# on time step 1213 (time=6.065), 0.673537 s/step
# Meep progress: 6.09/77.5 = 7.9% done in 931.5s, 10922.4s to go
# on time step 1219 (time=6.095), 0.675474 s/step
# Meep progress: 6.12/77.5 = 7.9% done in 935.5s, 10910.9s to go
# on time step 1225 (time=6.125), 0.667353 s/step
# Meep progress: 6.15/77.5 = 7.9% done in 939.6s, 10900.3s to go
# on time step 1231 (time=6.155), 0.676545 s/step
# Meep progress: 6.18/77.5 = 8.0% done in 943.6s, 10889.6s to go
# on time step 1237 (time=6.185), 0.678417 s/step
# Meep progress: 6.21/77.5 = 8.0% done in 947.8s, 10880.6s to go
# on time step 1243 (time=6.215), 0.699528 s/step
# Meep progress: 6.24/77.5 = 8.1% done in 952.0s, 10871.7s to go
# on time step 1249 (time=6.245), 0.701871 s/step
# Meep progress: 6.2700000000000005/77.5 = 8.1% done in 956.2s, 10863.1s to go
# on time step 1255 (time=6.275), 0.706281 s/step
# Meep progress: 6.3/77.5 = 8.1% done in 960.5s, 10854.8s to go
# on time step 1261 (time=6.305), 0.705213 s/step
# Meep progress: 6.33/77.5 = 8.2% done in 964.7s, 10846.6s to go
# on time step 1267 (time=6.335), 0.709146 s/step
# Meep progress: 6.36/77.5 = 8.2% done in 969.0s, 10838.3s to go
# on time step 1273 (time=6.365), 0.705116 s/step
# Meep progress: 6.390000000000001/77.5 = 8.2% done in 973.2s, 10830.4s to go
# on time step 1279 (time=6.395), 0.715916 s/step
# Meep progress: 6.42/77.5 = 8.3% done in 977.5s, 10822.7s to go
# on time step 1285 (time=6.425), 0.710849 s/step
# Meep progress: 6.45/77.5 = 8.3% done in 981.8s, 10814.8s to go
# on time step 1291 (time=6.455), 0.709853 s/step
# Meep progress: 6.48/77.5 = 8.4% done in 986.0s, 10806.8s to go
# on time step 1297 (time=6.485), 0.710873 s/step
# Meep progress: 6.51/77.5 = 8.4% done in 990.3s, 10799.0s to go
# on time step 1303 (time=6.515), 0.708963 s/step
# Meep progress: 6.54/77.5 = 8.4% done in 994.6s, 10791.4s to go
# on time step 1309 (time=6.545), 0.713719 s/step
# Meep progress: 6.57/77.5 = 8.5% done in 998.7s, 10781.7s to go
# on time step 1315 (time=6.575), 0.668108 s/step
# Meep progress: 6.61/77.5 = 8.5% done in 1003.1s, 10758.2s to go
# on time step 1323 (time=6.615), 0.543892 s/step
# Meep progress: 6.65/77.5 = 8.6% done in 1007.4s, 10732.5s to go
# on time step 1331 (time=6.655), 0.534907 s/step
# Meep progress: 6.6850000000000005/77.5 = 8.6% done in 1011.6s, 10716.0s to go
# on time step 1338 (time=6.69), 0.625195 s/step
# Meep progress: 6.715/77.5 = 8.7% done in 1015.8s, 10707.6s to go
# on time step 1344 (time=6.72), 0.705001 s/step
# Meep progress: 6.745/77.5 = 8.7% done in 1020.2s, 10701.8s to go
# on time step 1350 (time=6.75), 0.725348 s/step
# Meep progress: 6.7700000000000005/77.5 = 8.7% done in 1024.4s, 10702.1s to go
# on time step 1355 (time=6.775), 0.90265 s/step
# Meep progress: 6.79/77.5 = 8.8% done in 1028.6s, 10711.8s to go
# on time step 1359 (time=6.795), 1.0697 s/step
# Meep progress: 6.8100000000000005/77.5 = 8.8% done in 1033.0s, 10722.5s to go
# on time step 1363 (time=6.815), 1.10148 s/step
# Meep progress: 6.83/77.5 = 8.8% done in 1037.6s, 10735.7s to go
# on time step 1367 (time=6.835), 1.14935 s/step
# Meep progress: 6.8500000000000005/77.5 = 8.8% done in 1042.1s, 10748.1s to go
# on time step 1371 (time=6.855), 1.13527 s/step
# Meep progress: 6.87/77.5 = 8.9% done in 1046.7s, 10761.3s to go
# on time step 1375 (time=6.875), 1.15361 s/step
# Meep progress: 6.890000000000001/77.5 = 8.9% done in 1051.2s, 10773.4s to go
# on time step 1379 (time=6.895), 1.14158 s/step
# Meep progress: 6.91/77.5 = 8.9% done in 1056.0s, 10787.6s to go
# on time step 1383 (time=6.915), 1.19377 s/step
# Meep progress: 6.93/77.5 = 8.9% done in 1060.7s, 10801.8s to go
# on time step 1387 (time=6.935), 1.17946 s/step
# Meep progress: 6.95/77.5 = 9.0% done in 1065.4s, 10815.4s to go
# on time step 1391 (time=6.955), 1.18546 s/step
# Meep progress: 6.97/77.5 = 9.0% done in 1070.2s, 10829.1s to go
# on time step 1395 (time=6.975), 1.18072 s/step
# Meep progress: 6.99/77.5 = 9.0% done in 1075.0s, 10843.9s to go
# on time step 1399 (time=6.995), 1.2174 s/step
# Meep progress: 7.01/77.5 = 9.0% done in 1079.9s, 10858.9s to go
# on time step 1403 (time=7.015), 1.21381 s/step
# Meep progress: 7.03/77.5 = 9.1% done in 1084.8s, 10873.8s to go
# on time step 1407 (time=7.035), 1.21368 s/step
# Meep progress: 7.05/77.5 = 9.1% done in 1089.6s, 10888.4s to go
# on time step 1411 (time=7.055), 1.22109 s/step
# Meep progress: 7.07/77.5 = 9.1% done in 1094.5s, 10902.8s to go
# on time step 1415 (time=7.075), 1.20488 s/step
# Meep progress: 7.09/77.5 = 9.1% done in 1099.3s, 10917.0s to go
# on time step 1419 (time=7.095), 1.21086 s/step
# Meep progress: 7.11/77.5 = 9.2% done in 1104.2s, 10931.5s to go
# on time step 1423 (time=7.115), 1.18977 s/step
# Meep progress: 7.135/77.5 = 9.2% done in 1108.6s, 10932.9s to go
# on time step 1429 (time=7.145), 0.783917 s/step
# Meep progress: 7.17/77.5 = 9.3% done in 1113.0s, 10917.3s to go
# on time step 1436 (time=7.18), 0.603878 s/step
# Meep progress: 7.205/77.5 = 9.3% done in 1117.2s, 10900.3s to go
# on time step 1443 (time=7.215), 0.611906 s/step
# Meep progress: 7.24/77.5 = 9.3% done in 1121.6s, 10884.0s to go
# on time step 1450 (time=7.25), 0.614585 s/step
# Meep progress: 7.275/77.5 = 9.4% done in 1125.9s, 10868.2s to go
# on time step 1457 (time=7.285), 0.625724 s/step
# Meep progress: 7.3100000000000005/77.5 = 9.4% done in 1130.4s, 10854.1s to go
# on time step 1464 (time=7.32), 0.639535 s/step
# Meep progress: 7.345/77.5 = 9.5% done in 1134.8s, 10838.6s to go
# on time step 1471 (time=7.355), 0.621297 s/step
# Meep progress: 7.38/77.5 = 9.5% done in 1139.2s, 10823.6s to go
# on time step 1478 (time=7.39), 0.633909 s/step
# Meep progress: 7.415/77.5 = 9.6% done in 1143.6s, 10809.2s to go
# on time step 1485 (time=7.425), 0.642161 s/step
# Meep progress: 7.45/77.5 = 9.6% done in 1148.2s, 10796.1s to go
# on time step 1492 (time=7.46), 0.644502 s/step
# Meep progress: 7.485/77.5 = 9.7% done in 1152.7s, 10782.2s to go
# on time step 1499 (time=7.495), 0.639379 s/step
# Meep progress: 7.5200000000000005/77.5 = 9.7% done in 1157.0s, 10767.1s to go
# on time step 1506 (time=7.53), 0.616987 s/step
# Meep progress: 7.555/77.5 = 9.7% done in 1161.5s, 10753.6s to go
# on time step 1513 (time=7.565), 0.662927 s/step
# Meep progress: 7.585/77.5 = 9.8% done in 1165.6s, 10744.2s to go
# on time step 1519 (time=7.595), 0.682912 s/step
# Meep progress: 7.615/77.5 = 9.8% done in 1169.7s, 10734.9s to go
# on time step 1525 (time=7.625), 0.680735 s/step
# Meep progress: 7.6450000000000005/77.5 = 9.9% done in 1173.8s, 10725.4s to go
# on time step 1531 (time=7.655), 0.681063 s/step
# Meep progress: 7.675/77.5 = 9.9% done in 1177.9s, 10716.1s to go
# on time step 1537 (time=7.685), 0.679604 s/step
# Meep progress: 7.705/77.5 = 9.9% done in 1182.0s, 10706.7s to go
# on time step 1543 (time=7.715), 0.679358 s/step
# Meep progress: 7.735/77.5 = 10.0% done in 1186.1s, 10697.6s to go
# on time step 1549 (time=7.745), 0.688083 s/step
# Meep progress: 7.765000000000001/77.5 = 10.0% done in 1190.2s, 10689.0s to go
# on time step 1555 (time=7.775), 0.692333 s/step
# Meep progress: 7.795/77.5 = 10.1% done in 1194.4s, 10680.2s to go
# on time step 1561 (time=7.805), 0.686714 s/step
# Meep progress: 7.825/77.5 = 10.1% done in 1198.6s, 10672.9s to go
# on time step 1567 (time=7.835), 0.723778 s/step
# Meep progress: 7.855/77.5 = 10.1% done in 1202.9s, 10665.7s to go
# on time step 1573 (time=7.865), 0.71921 s/step
# Meep progress: 7.885/77.5 = 10.2% done in 1207.4s, 10659.5s to go
# on time step 1579 (time=7.895), 0.734448 s/step
# Meep progress: 7.915/77.5 = 10.2% done in 1211.7s, 10652.5s to go
# on time step 1585 (time=7.925), 0.720001 s/step
# Meep progress: 7.945/77.5 = 10.3% done in 1216.0s, 10645.6s to go
# on time step 1591 (time=7.955), 0.755375 s/step
# Meep progress: 7.97/77.5 = 10.3% done in 1220.1s, 10643.9s to go
# on time step 1597 (time=7.985), 0.797327 s/step
# Meep progress: 8.0/77.5 = 10.3% done in 1224.8s, 10640.6s to go
# on time step 1603 (time=8.015), 0.800451 s/step
# Meep progress: 8.025/77.5 = 10.4% done in 1228.8s, 10638.3s to go
# on time step 1609 (time=8.045), 0.798351 s/step
# Meep progress: 8.05/77.5 = 10.4% done in 1232.9s, 10636.2s to go
# on time step 1614 (time=8.07), 0.814261 s/step
# Meep progress: 8.075/77.5 = 10.4% done in 1237.0s, 10634.8s to go
# on time step 1619 (time=8.095), 0.821265 s/step
# Meep progress: 8.1/77.5 = 10.5% done in 1241.1s, 10633.6s to go
# on time step 1624 (time=8.12), 0.885504 s/step
# Meep progress: 8.125/77.5 = 10.5% done in 1245.5s, 10634.9s to go
# on time step 1629 (time=8.145), 0.893842 s/step
# Meep progress: 8.15/77.5 = 10.5% done in 1250.0s, 10636.6s to go
# on time step 1634 (time=8.17), 0.888804 s/step
# Meep progress: 8.175/77.5 = 10.5% done in 1254.5s, 10637.9s to go
# on time step 1639 (time=8.195), 0.884707 s/step
# Meep progress: 8.2/77.5 = 10.6% done in 1258.9s, 10638.9s to go
# on time step 1644 (time=8.22), 0.880876 s/step
# Meep progress: 8.225/77.5 = 10.6% done in 1263.3s, 10639.8s to go
# on time step 1649 (time=8.245), 0.888127 s/step
# Meep progress: 8.25/77.5 = 10.6% done in 1267.7s, 10641.1s to go
# on time step 1654 (time=8.27), 0.879207 s/step
# Meep progress: 8.275/77.5 = 10.7% done in 1272.1s, 10641.8s to go
# on time step 1659 (time=8.295), 0.882829 s/step
# Meep progress: 8.3/77.5 = 10.7% done in 1276.5s, 10642.7s to go
# on time step 1664 (time=8.32), 0.844346 s/step
# Meep progress: 8.325/77.5 = 10.7% done in 1280.7s, 10641.7s to go
# on time step 1669 (time=8.345), 0.834147 s/step
# Meep progress: 8.35/77.5 = 10.8% done in 1284.9s, 10640.6s to go
# on time step 1674 (time=8.37), 0.83307 s/step
# Meep progress: 8.375/77.5 = 10.8% done in 1289.0s, 10639.4s to go
# on time step 1679 (time=8.395), 0.852072 s/step
# Meep progress: 8.4/77.5 = 10.8% done in 1293.3s, 10639.2s to go
# on time step 1684 (time=8.42), 0.85645 s/step
# Meep progress: 8.425/77.5 = 10.9% done in 1297.6s, 10638.8s to go
# on time step 1689 (time=8.445), 0.857657 s/step
# Meep progress: 8.45/77.5 = 10.9% done in 1301.9s, 10638.6s to go
# on time step 1694 (time=8.47), 0.861965 s/step
# Meep progress: 8.475/77.5 = 10.9% done in 1306.2s, 10638.5s to go
# on time step 1699 (time=8.495), 0.857561 s/step
# Meep progress: 8.5/77.5 = 11.0% done in 1310.5s, 10638.1s to go
# on time step 1704 (time=8.52), 0.859762 s/step
# Meep progress: 8.525/77.5 = 11.0% done in 1314.8s, 10637.9s to go
# on time step 1709 (time=8.545), 0.856821 s/step
# Meep progress: 8.55/77.5 = 11.0% done in 1319.1s, 10637.6s to go
# on time step 1714 (time=8.57), 0.85713 s/step
# Meep progress: 8.575000000000001/77.5 = 11.1% done in 1323.4s, 10637.1s to go
# on time step 1719 (time=8.595), 0.856596 s/step
# Meep progress: 8.6/77.5 = 11.1% done in 1327.7s, 10636.7s to go
# on time step 1724 (time=8.62), 0.855413 s/step
# Meep progress: 8.625/77.5 = 11.1% done in 1331.9s, 10636.2s to go
# on time step 1729 (time=8.645), 0.856772 s/step
# Meep progress: 8.65/77.5 = 11.2% done in 1336.2s, 10635.7s to go
# on time step 1734 (time=8.67), 0.817943 s/step
# Meep progress: 8.685/77.5 = 11.2% done in 1340.4s, 10620.7s to go
# on time step 1743 (time=8.715), 0.523932 s/step
# Meep progress: 8.72/77.5 = 11.3% done in 1345.2s, 10610.8s to go
# on time step 1747 (time=8.735), 1.07572 s/step
# Meep progress: 8.74/77.5 = 11.3% done in 1349.5s, 10617.3s to go
# on time step 1751 (time=8.755), 1.10309 s/step
# Meep progress: 8.76/77.5 = 11.3% done in 1354.0s, 10625.0s to go
# on time step 1755 (time=8.775), 1.14459 s/step
# Meep progress: 8.78/77.5 = 11.3% done in 1359.0s, 10636.4s to go
# on time step 1758 (time=8.79), 1.4876 s/step
# Meep progress: 8.795/77.5 = 11.3% done in 1363.4s, 10650.5s to go
# on time step 1761 (time=8.805), 1.46737 s/step
# Meep progress: 8.81/77.5 = 11.4% done in 1367.9s, 10665.0s to go
# on time step 1764 (time=8.82), 1.51335 s/step
# Meep progress: 8.825000000000001/77.5 = 11.4% done in 1372.4s, 10679.5s to go
# on time step 1767 (time=8.835), 1.46767 s/step
# Meep progress: 8.84/77.5 = 11.4% done in 1376.8s, 10693.2s to go
# on time step 1770 (time=8.85), 1.5018 s/step
# Meep progress: 8.855/77.5 = 11.4% done in 1381.2s, 10707.6s to go
# on time step 1773 (time=8.865), 1.46323 s/step
# Meep progress: 8.870000000000001/77.5 = 11.4% done in 1385.7s, 10721.4s to go
# on time step 1776 (time=8.88), 1.49758 s/step
# Meep progress: 8.885/77.5 = 11.5% done in 1390.2s, 10735.7s to go
# on time step 1779 (time=8.895), 1.47779 s/step
# Meep progress: 8.9/77.5 = 11.5% done in 1394.6s, 10749.2s to go
# on time step 1782 (time=8.91), 1.46355 s/step
# Meep progress: 8.915000000000001/77.5 = 11.5% done in 1399.0s, 10762.9s to go
# on time step 1785 (time=8.925), 1.48545 s/step
# Meep progress: 8.93/77.5 = 11.5% done in 1403.4s, 10776.4s to go
# on time step 1788 (time=8.94), 1.46758 s/step
# Meep progress: 8.950000000000001/77.5 = 11.5% done in 1407.8s, 10782.7s to go
# on time step 1795 (time=8.975), 0.729486 s/step
# Meep progress: 8.98/77.5 = 11.6% done in 1412.7s, 10779.3s to go
# on time step 1799 (time=8.995), 1.21777 s/step
# Meep progress: 9.0/77.5 = 11.6% done in 1417.6s, 10789.3s to go
# on time step 1803 (time=9.015), 1.21653 s/step
# Meep progress: 9.02/77.5 = 11.6% done in 1422.4s, 10799.1s to go
# on time step 1807 (time=9.035), 1.21971 s/step
# Meep progress: 9.040000000000001/77.5 = 11.7% done in 1427.1s, 10807.4s to go
# on time step 1812 (time=9.06), 0.828456 s/step
# Meep progress: 9.07/77.5 = 11.7% done in 1431.8s, 10802.5s to go
# on time step 1818 (time=9.09), 0.798105 s/step
# Meep progress: 9.095/77.5 = 11.7% done in 1435.8s, 10799.2s to go
# on time step 1823 (time=9.115), 0.812724 s/step
# Meep progress: 9.120000000000001/77.5 = 11.8% done in 1439.9s, 10796.1s to go
# on time step 1828 (time=9.14), 0.812529 s/step
# Meep progress: 9.145/77.5 = 11.8% done in 1444.0s, 10793.1s to go
# on time step 1833 (time=9.165), 0.812236 s/step
# Meep progress: 9.17/77.5 = 11.8% done in 1448.0s, 10790.0s to go
# on time step 1838 (time=9.19), 0.81301 s/step
# Meep progress: 9.195/77.5 = 11.9% done in 1452.1s, 10786.9s to go
# on time step 1843 (time=9.215), 0.813022 s/step
# Meep progress: 9.22/77.5 = 11.9% done in 1456.2s, 10783.8s to go
# on time step 1848 (time=9.24), 0.814971 s/step
# Meep progress: 9.245000000000001/77.5 = 11.9% done in 1460.2s, 10780.8s to go
# on time step 1853 (time=9.265), 0.813659 s/step
# Meep progress: 9.27/77.5 = 12.0% done in 1464.3s, 10777.8s to go
# on time step 1858 (time=9.29), 0.813812 s/step
# Meep progress: 9.295/77.5 = 12.0% done in 1468.4s, 10774.7s to go
# on time step 1863 (time=9.315), 0.814122 s/step
# Meep progress: 9.32/77.5 = 12.0% done in 1472.5s, 10771.7s to go
# on time step 1868 (time=9.34), 0.816766 s/step
# Meep progress: 9.345/77.5 = 12.1% done in 1476.5s, 10768.7s to go
# on time step 1873 (time=9.365), 0.812262 s/step
# Meep progress: 9.370000000000001/77.5 = 12.1% done in 1480.6s, 10765.6s to go
# on time step 1878 (time=9.39), 0.813881 s/step
# Meep progress: 9.395/77.5 = 12.1% done in 1484.7s, 10762.5s to go
# on time step 1883 (time=9.415), 0.812017 s/step
# Meep progress: 9.42/77.5 = 12.2% done in 1488.7s, 10759.3s to go
# on time step 1888 (time=9.44), 0.812955 s/step
# Meep progress: 9.445/77.5 = 12.2% done in 1492.8s, 10756.2s to go
# on time step 1893 (time=9.465), 0.812607 s/step
# Meep progress: 9.47/77.5 = 12.2% done in 1496.9s, 10753.1s to go
# on time step 1898 (time=9.49), 0.813426 s/step
# Meep progress: 9.495000000000001/77.5 = 12.3% done in 1500.9s, 10749.9s to go
# on time step 1903 (time=9.515), 0.815071 s/step
# Meep progress: 9.52/77.5 = 12.3% done in 1505.0s, 10746.9s to go
# on time step 1908 (time=9.54), 0.814257 s/step
# Meep progress: 9.545/77.5 = 12.3% done in 1509.1s, 10743.9s to go
# on time step 1913 (time=9.565), 0.815965 s/step
# Meep progress: 9.57/77.5 = 12.3% done in 1513.2s, 10740.8s to go
# on time step 1918 (time=9.59), 0.814402 s/step
# Meep progress: 9.595/77.5 = 12.4% done in 1517.2s, 10737.7s to go
# on time step 1923 (time=9.615), 0.834316 s/step
# Meep progress: 9.620000000000001/77.5 = 12.4% done in 1521.4s, 10735.3s to go
# on time step 1928 (time=9.64), 0.817151 s/step
# Meep progress: 9.645/77.5 = 12.4% done in 1525.5s, 10732.3s to go
# on time step 1933 (time=9.665), 0.819672 s/step
# Meep progress: 9.67/77.5 = 12.5% done in 1529.7s, 10729.9s to go
# on time step 1938 (time=9.69), 0.828664 s/step
# Meep progress: 9.695/77.5 = 12.5% done in 1533.7s, 10726.7s to go
# on time step 1943 (time=9.715), 0.809217 s/step
# Meep progress: 9.72/77.5 = 12.5% done in 1537.8s, 10723.4s to go
# on time step 1948 (time=9.74), 0.823327 s/step
# Meep progress: 9.745000000000001/77.5 = 12.6% done in 1541.9s, 10720.5s to go
# on time step 1953 (time=9.765), 0.815681 s/step
# Meep progress: 9.77/77.5 = 12.6% done in 1546.0s, 10717.5s to go
# on time step 1958 (time=9.79), 0.820326 s/step
# Meep progress: 9.795/77.5 = 12.6% done in 1550.1s, 10714.5s to go
# on time step 1963 (time=9.815), 0.813153 s/step
# Meep progress: 9.82/77.5 = 12.7% done in 1554.2s, 10711.3s to go
# on time step 1968 (time=9.84), 0.816382 s/step
# Meep progress: 9.845/77.5 = 12.7% done in 1558.2s, 10708.2s to go
# on time step 1973 (time=9.865), 0.823591 s/step
# Meep progress: 9.870000000000001/77.5 = 12.7% done in 1562.4s, 10705.4s to go
# on time step 1978 (time=9.89), 0.813881 s/step
# Meep progress: 9.895/77.5 = 12.8% done in 1566.4s, 10702.2s to go
# on time step 1983 (time=9.915), 0.81603 s/step
# Meep progress: 9.92/77.5 = 12.8% done in 1570.5s, 10699.1s to go
# on time step 1988 (time=9.94), 0.820145 s/step
# Meep progress: 9.945/77.5 = 12.8% done in 1574.6s, 10696.1s to go
# on time step 1993 (time=9.965), 0.816242 s/step
# Meep progress: 9.97/77.5 = 12.9% done in 1578.7s, 10693.0s to go
# on time step 1998 (time=9.99), 0.814794 s/step
# Meep progress: 9.995000000000001/77.5 = 12.9% done in 1582.8s, 10689.8s to go
# on time step 2003 (time=10.015), 0.808826 s/step
# Meep progress: 10.02/77.5 = 12.9% done in 1586.8s, 10686.4s to go
# on time step 2008 (time=10.04), 0.812798 s/step
# Meep progress: 10.045/77.5 = 13.0% done in 1590.9s, 10683.2s to go
# on time step 2013 (time=10.065), 0.816897 s/step
# Meep progress: 10.07/77.5 = 13.0% done in 1595.0s, 10680.1s to go
# on time step 2018 (time=10.09), 0.816779 s/step
# Meep progress: 10.095/77.5 = 13.0% done in 1599.1s, 10677.1s to go
# on time step 2023 (time=10.115), 0.819482 s/step
# Meep progress: 10.120000000000001/77.5 = 13.1% done in 1603.2s, 10674.0s to go
# on time step 2028 (time=10.14), 0.815499 s/step
# Meep progress: 10.145/77.5 = 13.1% done in 1607.2s, 10670.8s to go
# on time step 2035 (time=10.175), 0.586769 s/step
# Meep progress: 10.185/77.5 = 13.1% done in 1611.4s, 10650.2s to go
# on time step 2041 (time=10.205), 0.687141 s/step
# Meep progress: 10.21/77.5 = 13.2% done in 1615.7s, 10648.2s to go
# on time step 2045 (time=10.225), 1.0146 s/step
# Meep progress: 10.23/77.5 = 13.2% done in 1619.7s, 10650.9s to go
# on time step 2049 (time=10.245), 1.01322 s/step
# Meep progress: 10.25/77.5 = 13.2% done in 1623.8s, 10653.5s to go
# on time step 2053 (time=10.265), 1.01136 s/step
# Meep progress: 10.27/77.5 = 13.3% done in 1627.8s, 10656.2s to go
# on time step 2057 (time=10.285), 1.01481 s/step
# Meep progress: 10.290000000000001/77.5 = 13.3% done in 1631.9s, 10658.7s to go
# on time step 2061 (time=10.305), 1.00451 s/step
# Meep progress: 10.31/77.5 = 13.3% done in 1635.9s, 10661.0s to go
# on time step 2065 (time=10.325), 1.04586 s/step
# Meep progress: 10.33/77.5 = 13.3% done in 1640.2s, 10665.1s to go
# on time step 2069 (time=10.345), 1.02922 s/step
# Meep progress: 10.355/77.5 = 13.4% done in 1645.2s, 10667.7s to go
# on time step 2074 (time=10.37), 0.98004 s/step
# Meep progress: 10.38/77.5 = 13.4% done in 1650.0s, 10669.7s to go
# on time step 2079 (time=10.395), 0.966225 s/step
# Meep progress: 10.405/77.5 = 13.4% done in 1654.8s, 10670.7s to go
# on time step 2084 (time=10.42), 0.918313 s/step
# Meep progress: 10.43/77.5 = 13.5% done in 1659.3s, 10670.4s to go
# on time step 2089 (time=10.445), 0.907557 s/step
# Meep progress: 10.455/77.5 = 13.5% done in 1663.9s, 10670.0s to go
# on time step 2094 (time=10.47), 0.91204 s/step
# Meep progress: 10.48/77.5 = 13.5% done in 1668.5s, 10669.9s to go
# on time step 2099 (time=10.495), 0.910561 s/step
# Meep progress: 10.505/77.5 = 13.6% done in 1673.0s, 10669.4s to go
# on time step 2104 (time=10.52), 0.902691 s/step
# Meep progress: 10.53/77.5 = 13.6% done in 1677.5s, 10668.7s to go
# on time step 2109 (time=10.545), 0.923028 s/step
# Meep progress: 10.555/77.5 = 13.6% done in 1682.1s, 10668.9s to go
# on time step 2114 (time=10.57), 0.909016 s/step
# Meep progress: 10.58/77.5 = 13.7% done in 1686.7s, 10668.5s to go
# on time step 2119 (time=10.595), 0.892121 s/step
# Meep progress: 10.605/77.5 = 13.7% done in 1691.2s, 10667.9s to go
# on time step 2124 (time=10.62), 0.91338 s/step
# Meep progress: 10.63/77.5 = 13.7% done in 1695.7s, 10666.8s to go
# on time step 2129 (time=10.645), 0.85178 s/step
# Meep progress: 10.655/77.5 = 13.7% done in 1700.1s, 10665.6s to go
# on time step 2134 (time=10.67), 0.947844 s/step
# Meep progress: 10.68/77.5 = 13.8% done in 1704.7s, 10665.7s to go
# on time step 2139 (time=10.695), 0.91089 s/step
# Meep progress: 10.705/77.5 = 13.8% done in 1709.2s, 10664.8s to go
# on time step 2144 (time=10.72), 0.909758 s/step
# Meep progress: 10.73/77.5 = 13.8% done in 1713.8s, 10664.8s to go
# on time step 2149 (time=10.745), 0.930869 s/step
# Meep progress: 10.755/77.5 = 13.9% done in 1718.4s, 10664.5s to go
# on time step 2154 (time=10.77), 0.928696 s/step
# Meep progress: 10.78/77.5 = 13.9% done in 1723.2s, 10665.1s to go
# on time step 2159 (time=10.795), 0.933473 s/step
# Meep progress: 10.805/77.5 = 13.9% done in 1727.8s, 10665.2s to go
# on time step 2164 (time=10.82), 0.933192 s/step
# Meep progress: 10.83/77.5 = 14.0% done in 1732.4s, 10665.0s to go
# on time step 2169 (time=10.845), 0.898947 s/step
# Meep progress: 10.855/77.5 = 14.0% done in 1737.0s, 10664.1s to go
# on time step 2174 (time=10.87), 0.927364 s/step
# Meep progress: 10.88/77.5 = 14.0% done in 1741.6s, 10664.2s to go
# on time step 2179 (time=10.895), 0.94079 s/step
# Meep progress: 10.905/77.5 = 14.1% done in 1746.4s, 10664.9s to go
# on time step 2184 (time=10.92), 0.958925 s/step
# Meep progress: 10.93/77.5 = 14.1% done in 1751.2s, 10665.7s to go
# on time step 2189 (time=10.945), 0.953278 s/step
# Meep progress: 10.955/77.5 = 14.1% done in 1755.9s, 10665.7s to go
# on time step 2194 (time=10.97), 0.924283 s/step
# Meep progress: 10.98/77.5 = 14.2% done in 1760.5s, 10665.5s to go
# on time step 2199 (time=10.995), 0.91476 s/step
# Meep progress: 11.005/77.5 = 14.2% done in 1765.1s, 10665.3s to go
# on time step 2204 (time=11.02), 0.951265 s/step
# Meep progress: 11.03/77.5 = 14.2% done in 1769.9s, 10666.0s to go
# on time step 2209 (time=11.045), 0.96215 s/step
# Meep progress: 11.055/77.5 = 14.3% done in 1774.7s, 10666.7s to go
# on time step 2214 (time=11.07), 0.958494 s/step
# Meep progress: 11.08/77.5 = 14.3% done in 1779.5s, 10667.5s to go
# on time step 2219 (time=11.095), 0.961717 s/step
# Meep progress: 11.105/77.5 = 14.3% done in 1784.3s, 10668.1s to go
# on time step 2224 (time=11.12), 0.958205 s/step
# Meep progress: 11.13/77.5 = 14.4% done in 1789.1s, 10668.8s to go
# on time step 2229 (time=11.145), 0.948515 s/step
# Meep progress: 11.155/77.5 = 14.4% done in 1793.8s, 10668.6s to go
# on time step 2234 (time=11.17), 0.917357 s/step
# Meep progress: 11.18/77.5 = 14.4% done in 1798.4s, 10668.0s to go
# on time step 2239 (time=11.195), 0.940193 s/step
# Meep progress: 11.205/77.5 = 14.5% done in 1803.1s, 10668.4s to go
# on time step 2244 (time=11.22), 0.957854 s/step
# Meep progress: 11.23/77.5 = 14.5% done in 1807.9s, 10668.9s to go
# on time step 2249 (time=11.245), 0.958929 s/step
# Meep progress: 11.255/77.5 = 14.5% done in 1812.7s, 10669.4s to go
# on time step 2254 (time=11.27), 0.952256 s/step
# Meep progress: 11.28/77.5 = 14.6% done in 1817.4s, 10669.2s to go
# on time step 2259 (time=11.295), 0.924872 s/step
# Meep progress: 11.305/77.5 = 14.6% done in 1822.2s, 10669.4s to go
# on time step 2264 (time=11.32), 0.999925 s/step
# Meep progress: 11.325000000000001/77.5 = 14.6% done in 1826.2s, 10671.2s to go
# on time step 2268 (time=11.34), 1.03693 s/step
# ...
# on time step 14569 (time=72.845), 0.902752 s/step
# Meep progress: 72.87/77.5 = 94.0% done in 12132.5s, 770.9s to go
# on time step 14574 (time=72.87), 0.877659 s/step
# Meep progress: 72.895/77.5 = 94.1% done in 12136.7s, 766.7s to go
# on time step 14579 (time=72.895), 0.829523 s/step
# Meep progress: 72.93/77.5 = 94.1% done in 12141.1s, 760.8s to go
# on time step 14586 (time=72.93), 0.633991 s/step
# Meep progress: 72.965/77.5 = 94.1% done in 12145.8s, 754.9s to go
# on time step 14593 (time=72.965), 0.661809 s/step
# Meep progress: 72.995/77.5 = 94.2% done in 12149.8s, 749.8s to go
# on time step 14599 (time=72.995), 0.670587 s/step
# Meep progress: 73.025/77.5 = 94.2% done in 12153.8s, 744.8s to go
# on time step 14605 (time=73.025), 0.673244 s/step
# Meep progress: 73.06/77.5 = 94.3% done in 12158.5s, 738.9s to go
# on time step 14612 (time=73.06), 0.663779 s/step
# Meep progress: 73.09/77.5 = 94.3% done in 12162.5s, 733.8s to go
# on time step 14618 (time=73.09), 0.670112 s/step
# Meep progress: 73.125/77.5 = 94.4% done in 12167.1s, 727.9s to go
# on time step 14625 (time=73.125), 0.659924 s/step
# Meep progress: 73.16/77.5 = 94.4% done in 12171.7s, 722.1s to go
# on time step 14632 (time=73.16), 0.66244 s/step
# Meep progress: 73.19500000000001/77.5 = 94.4% done in 12176.3s, 716.2s to go
# on time step 14639 (time=73.195), 0.656082 s/step
# Meep progress: 73.23/77.5 = 94.5% done in 12180.9s, 710.3s to go
# on time step 14646 (time=73.23), 0.653876 s/step
# Meep progress: 73.265/77.5 = 94.5% done in 12185.4s, 704.4s to go
# on time step 14653 (time=73.265), 0.647685 s/step
# Meep progress: 73.3/77.5 = 94.6% done in 12189.9s, 698.5s to go
# on time step 14660 (time=73.3), 0.638263 s/step
# Meep progress: 73.33500000000001/77.5 = 94.6% done in 12194.4s, 692.6s to go
# on time step 14667 (time=73.335), 0.640653 s/step
# Meep progress: 73.37/77.5 = 94.7% done in 12198.9s, 686.7s to go
# on time step 14674 (time=73.37), 0.638235 s/step
# Meep progress: 73.405/77.5 = 94.7% done in 12203.4s, 680.8s to go
# on time step 14681 (time=73.405), 0.644389 s/step
# Meep progress: 73.44/77.5 = 94.8% done in 12207.9s, 674.9s to go
# on time step 14688 (time=73.44), 0.649874 s/step
# Meep progress: 73.47500000000001/77.5 = 94.8% done in 12212.4s, 669.0s to go
# on time step 14695 (time=73.475), 0.639079 s/step
# Meep progress: 73.51/77.5 = 94.9% done in 12217.0s, 663.1s to go
# on time step 14702 (time=73.51), 0.650472 s/step
# Meep progress: 73.545/77.5 = 94.9% done in 12221.4s, 657.2s to go
# on time step 14709 (time=73.545), 0.637244 s/step
# Meep progress: 73.58/77.5 = 94.9% done in 12225.9s, 651.3s to go
# on time step 14716 (time=73.58), 0.646058 s/step
# Meep progress: 73.615/77.5 = 95.0% done in 12230.4s, 645.5s to go
# on time step 14723 (time=73.615), 0.639653 s/step
# Meep progress: 73.65/77.5 = 95.0% done in 12234.9s, 639.6s to go
# on time step 14730 (time=73.65), 0.637149 s/step
# Meep progress: 73.685/77.5 = 95.1% done in 12239.4s, 633.7s to go
# on time step 14737 (time=73.685), 0.641973 s/step
# Meep progress: 73.72/77.5 = 95.1% done in 12243.8s, 627.8s to go
# on time step 14744 (time=73.72), 0.633478 s/step
# Meep progress: 73.755/77.5 = 95.2% done in 12248.3s, 621.9s to go
# on time step 14751 (time=73.755), 0.640599 s/step
# Meep progress: 73.79/77.5 = 95.2% done in 12252.8s, 616.0s to go
# on time step 14758 (time=73.79), 0.636358 s/step
# Meep progress: 73.825/77.5 = 95.3% done in 12257.3s, 610.2s to go
# on time step 14765 (time=73.825), 0.642243 s/step
# Meep progress: 73.86/77.5 = 95.3% done in 12261.7s, 604.3s to go
# on time step 14772 (time=73.86), 0.630247 s/step
# Meep progress: 73.895/77.5 = 95.3% done in 12266.1s, 598.4s to go
# on time step 14779 (time=73.895), 0.6271 s/step
# Meep progress: 73.93/77.5 = 95.4% done in 12270.4s, 592.5s to go
# on time step 14786 (time=73.93), 0.625214 s/step
# Meep progress: 73.965/77.5 = 95.4% done in 12274.8s, 586.6s to go
# on time step 14793 (time=73.965), 0.620695 s/step
# Meep progress: 74.0/77.5 = 95.5% done in 12279.1s, 580.8s to go
# on time step 14800 (time=74), 0.617359 s/step
# Meep progress: 74.035/77.5 = 95.5% done in 12283.4s, 574.9s to go
# on time step 14807 (time=74.035), 0.618378 s/step
# Meep progress: 74.07000000000001/77.5 = 95.6% done in 12287.8s, 569.0s to go
# on time step 14814 (time=74.07), 0.619765 s/step
# Meep progress: 74.105/77.5 = 95.6% done in 12292.1s, 563.1s to go
# on time step 14821 (time=74.105), 0.618016 s/step
# Meep progress: 74.14/77.5 = 95.7% done in 12296.4s, 557.3s to go
# on time step 14828 (time=74.14), 0.620184 s/step
# Meep progress: 74.175/77.5 = 95.7% done in 12300.8s, 551.4s to go
# on time step 14835 (time=74.175), 0.620153 s/step
# Meep progress: 74.21000000000001/77.5 = 95.8% done in 12305.1s, 545.5s to go
# on time step 14842 (time=74.21), 0.619896 s/step
# Meep progress: 74.245/77.5 = 95.8% done in 12309.5s, 539.7s to go
# on time step 14849 (time=74.245), 0.618967 s/step
# Meep progress: 74.28/77.5 = 95.8% done in 12313.8s, 533.8s to go
# on time step 14856 (time=74.28), 0.620023 s/step
# Meep progress: 74.315/77.5 = 95.9% done in 12318.1s, 527.9s to go
# on time step 14863 (time=74.315), 0.618768 s/step
# Meep progress: 74.35000000000001/77.5 = 95.9% done in 12322.5s, 522.1s to go
# on time step 14870 (time=74.35), 0.620482 s/step
# Meep progress: 74.385/77.5 = 96.0% done in 12326.8s, 516.2s to go
# on time step 14877 (time=74.385), 0.619122 s/step
# Meep progress: 74.42/77.5 = 96.0% done in 12331.2s, 510.3s to go
# on time step 14884 (time=74.42), 0.622056 s/step
# Meep progress: 74.455/77.5 = 96.1% done in 12335.5s, 504.5s to go
# on time step 14891 (time=74.455), 0.620398 s/step
# Meep progress: 74.49/77.5 = 96.1% done in 12339.9s, 498.6s to go
# on time step 14898 (time=74.49), 0.620312 s/step
# Meep progress: 74.525/77.5 = 96.2% done in 12344.2s, 492.8s to go
# on time step 14905 (time=74.525), 0.62058 s/step
# Meep progress: 74.56/77.5 = 96.2% done in 12348.5s, 486.9s to go
# on time step 14912 (time=74.56), 0.620307 s/step
# Meep progress: 74.595/77.5 = 96.3% done in 12352.9s, 481.1s to go
# on time step 14919 (time=74.595), 0.62217 s/step
# Meep progress: 74.63/77.5 = 96.3% done in 12357.2s, 475.2s to go
# on time step 14926 (time=74.63), 0.619952 s/step
# Meep progress: 74.665/77.5 = 96.3% done in 12361.6s, 469.4s to go
# on time step 14933 (time=74.665), 0.622371 s/step
# Meep progress: 74.7/77.5 = 96.4% done in 12366.0s, 463.5s to go
# on time step 14940 (time=74.7), 0.629878 s/step
# Meep progress: 74.735/77.5 = 96.4% done in 12370.4s, 457.7s to go
# on time step 14947 (time=74.735), 0.622482 s/step
# Meep progress: 74.775/77.5 = 96.5% done in 12374.4s, 451.0s to go
# on time step 14955 (time=74.775), 0.500421 s/step
# Meep progress: 74.815/77.5 = 96.5% done in 12378.8s, 444.3s to go
# on time step 14963 (time=74.815), 0.55777 s/step
# Meep progress: 74.855/77.5 = 96.6% done in 12383.2s, 437.6s to go
# on time step 14971 (time=74.855), 0.546145 s/step
# Meep progress: 74.895/77.5 = 96.6% done in 12387.6s, 430.9s to go
# on time step 14979 (time=74.895), 0.55493 s/step
# Meep progress: 74.935/77.5 = 96.7% done in 12392.0s, 424.2s to go
# on time step 14987 (time=74.935), 0.548816 s/step
# Meep progress: 74.97500000000001/77.5 = 96.7% done in 12396.5s, 417.5s to go
# on time step 14995 (time=74.975), 0.553913 s/step
# Meep progress: 75.015/77.5 = 96.8% done in 12400.8s, 410.8s to go
# on time step 15003 (time=75.015), 0.543428 s/step
# Meep progress: 75.055/77.5 = 96.8% done in 12405.2s, 404.1s to go
# on time step 15011 (time=75.055), 0.548223 s/step
# Meep progress: 75.095/77.5 = 96.9% done in 12409.6s, 397.4s to go
# on time step 15019 (time=75.095), 0.548171 s/step
# Meep progress: 75.135/77.5 = 96.9% done in 12414.1s, 390.8s to go
# on time step 15027 (time=75.135), 0.563552 s/step
# Meep progress: 75.17/77.5 = 97.0% done in 12418.2s, 384.9s to go
# on time step 15034 (time=75.17), 0.585312 s/step
# Meep progress: 75.21000000000001/77.5 = 97.0% done in 12422.7s, 378.2s to go
# on time step 15042 (time=75.21), 0.566969 s/step
# Meep progress: 75.25/77.5 = 97.1% done in 12427.2s, 371.6s to go
# on time step 15050 (time=75.25), 0.563029 s/step
# Meep progress: 75.285/77.5 = 97.1% done in 12431.3s, 365.7s to go
# on time step 15057 (time=75.285), 0.576519 s/step
# Meep progress: 75.32000000000001/77.5 = 97.2% done in 12435.3s, 359.9s to go
# on time step 15064 (time=75.32), 0.575249 s/step
# Meep progress: 75.36/77.5 = 97.2% done in 12439.8s, 353.3s to go
# on time step 15072 (time=75.36), 0.563257 s/step
# Meep progress: 75.4/77.5 = 97.3% done in 12444.3s, 346.6s to go
# on time step 15080 (time=75.4), 0.564738 s/step
# Meep progress: 75.44/77.5 = 97.3% done in 12448.8s, 339.9s to go
# on time step 15088 (time=75.44), 0.561252 s/step
# Meep progress: 75.48/77.5 = 97.4% done in 12453.4s, 333.3s to go
# on time step 15096 (time=75.48), 0.568869 s/step
# Meep progress: 75.52/77.5 = 97.4% done in 12457.9s, 326.6s to go
# on time step 15104 (time=75.52), 0.560239 s/step
# Meep progress: 75.56/77.5 = 97.5% done in 12462.3s, 320.0s to go
# on time step 15112 (time=75.56), 0.551989 s/step
# Meep progress: 75.60000000000001/77.5 = 97.5% done in 12466.8s, 313.3s to go
# on time step 15120 (time=75.6), 0.566206 s/step
# Meep progress: 75.64/77.5 = 97.6% done in 12471.4s, 306.7s to go
# on time step 15128 (time=75.64), 0.573929 s/step
# Meep progress: 75.675/77.5 = 97.6% done in 12475.4s, 300.9s to go
# on time step 15135 (time=75.675), 0.578134 s/step
# Meep progress: 75.71000000000001/77.5 = 97.7% done in 12479.5s, 295.1s to go
# on time step 15142 (time=75.71), 0.577326 s/step
# Meep progress: 75.75/77.5 = 97.7% done in 12484.0s, 288.4s to go
# on time step 15150 (time=75.75), 0.56953 s/step
# Meep progress: 75.785/77.5 = 97.8% done in 12488.1s, 282.6s to go
# on time step 15157 (time=75.785), 0.57527 s/step
# Meep progress: 75.825/77.5 = 97.8% done in 12492.6s, 276.0s to go
# on time step 15165 (time=75.825), 0.566021 s/step
# Meep progress: 75.86/77.5 = 97.9% done in 12496.6s, 270.2s to go
# on time step 15172 (time=75.86), 0.574111 s/step
# Meep progress: 75.895/77.5 = 97.9% done in 12500.7s, 264.4s to go
# on time step 15179 (time=75.895), 0.576701 s/step
# Meep progress: 75.93/77.5 = 98.0% done in 12504.7s, 258.6s to go
# on time step 15186 (time=75.93), 0.576164 s/step
# Meep progress: 75.965/77.5 = 98.0% done in 12508.7s, 252.8s to go
# on time step 15193 (time=75.965), 0.578961 s/step
# Meep progress: 76.005/77.5 = 98.1% done in 12513.3s, 246.1s to go
# on time step 15201 (time=76.005), 0.573008 s/step
# Meep progress: 76.04/77.5 = 98.1% done in 12517.5s, 240.3s to go
# on time step 15208 (time=76.04), 0.600434 s/step
# Meep progress: 76.075/77.5 = 98.2% done in 12521.8s, 234.6s to go
# on time step 15215 (time=76.075), 0.611999 s/step
# Meep progress: 76.11/77.5 = 98.2% done in 12526.3s, 228.8s to go
# on time step 15222 (time=76.11), 0.641318 s/step
# Meep progress: 76.135/77.5 = 98.2% done in 12530.4s, 224.7s to go
# on time step 15227 (time=76.135), 0.82192 s/step
# Meep progress: 76.16/77.5 = 98.3% done in 12534.5s, 220.5s to go
# on time step 15232 (time=76.16), 0.818219 s/step
# Meep progress: 76.185/77.5 = 98.3% done in 12538.7s, 216.4s to go
# on time step 15237 (time=76.185), 0.832541 s/step
# Meep progress: 76.21000000000001/77.5 = 98.3% done in 12542.7s, 212.3s to go
# on time step 15242 (time=76.21), 0.813075 s/step
# Meep progress: 76.235/77.5 = 98.4% done in 12546.9s, 208.2s to go
# on time step 15247 (time=76.235), 0.828519 s/step
# Meep progress: 76.265/77.5 = 98.4% done in 12551.1s, 203.2s to go
# on time step 15253 (time=76.265), 0.709291 s/step
# Meep progress: 76.295/77.5 = 98.4% done in 12555.3s, 198.3s to go
# on time step 15259 (time=76.295), 0.694773 s/step
# Meep progress: 76.33/77.5 = 98.5% done in 12559.4s, 192.5s to go
# on time step 15266 (time=76.33), 0.588842 s/step
# Meep progress: 76.365/77.5 = 98.5% done in 12563.7s, 186.7s to go
# on time step 15273 (time=76.365), 0.604251 s/step
# Meep progress: 76.4/77.5 = 98.6% done in 12567.8s, 180.9s to go
# on time step 15280 (time=76.4), 0.588807 s/step
# Meep progress: 76.43/77.5 = 98.6% done in 12572.3s, 176.0s to go
# on time step 15286 (time=76.43), 0.744887 s/step
# Meep progress: 76.46000000000001/77.5 = 98.7% done in 12576.6s, 171.1s to go
# on time step 15292 (time=76.46), 0.727723 s/step
# Meep progress: 76.49/77.5 = 98.7% done in 12581.2s, 166.1s to go
# on time step 15298 (time=76.49), 0.755015 s/step
# Meep progress: 76.52/77.5 = 98.7% done in 12585.6s, 161.2s to go
# on time step 15304 (time=76.52), 0.738966 s/step
# Meep progress: 76.55/77.5 = 98.8% done in 12590.0s, 156.2s to go
# on time step 15310 (time=76.55), 0.727852 s/step
# Meep progress: 76.58/77.5 = 98.8% done in 12594.3s, 151.3s to go
# on time step 15316 (time=76.58), 0.728661 s/step
# Meep progress: 76.61/77.5 = 98.9% done in 12599.0s, 146.4s to go
# on time step 15322 (time=76.61), 0.769862 s/step
# Meep progress: 76.64/77.5 = 98.9% done in 12603.3s, 141.4s to go
# on time step 15328 (time=76.64), 0.731818 s/step
# Meep progress: 76.67/77.5 = 98.9% done in 12607.7s, 136.5s to go
# on time step 15334 (time=76.67), 0.731115 s/step
# Meep progress: 76.7/77.5 = 99.0% done in 12612.1s, 131.5s to go
# on time step 15340 (time=76.7), 0.729652 s/step
# Meep progress: 76.73/77.5 = 99.0% done in 12616.5s, 126.6s to go
# on time step 15346 (time=76.73), 0.730321 s/step
# Meep progress: 76.76/77.5 = 99.0% done in 12621.1s, 121.7s to go
# on time step 15352 (time=76.76), 0.767171 s/step
# Meep progress: 76.79/77.5 = 99.1% done in 12625.5s, 116.7s to go
# on time step 15358 (time=76.79), 0.736087 s/step
# Meep progress: 76.82000000000001/77.5 = 99.1% done in 12629.9s, 111.8s to go
# on time step 15364 (time=76.82), 0.727244 s/step
# Meep progress: 76.85000000000001/77.5 = 99.2% done in 12634.2s, 106.9s to go
# on time step 15370 (time=76.85), 0.727463 s/step
# Meep progress: 76.88/77.5 = 99.2% done in 12638.6s, 101.9s to go
# on time step 15376 (time=76.88), 0.728242 s/step
# Meep progress: 76.91/77.5 = 99.2% done in 12643.0s, 97.0s to go
# on time step 15382 (time=76.91), 0.729425 s/step
# Meep progress: 76.94/77.5 = 99.3% done in 12647.4s, 92.1s to go
# on time step 15388 (time=76.94), 0.73089 s/step
# Meep progress: 76.97/77.5 = 99.3% done in 12651.8s, 87.1s to go
# on time step 15394 (time=76.97), 0.740433 s/step
# Meep progress: 77.0/77.5 = 99.4% done in 12656.4s, 82.2s to go
# on time step 15400 (time=77), 0.756216 s/step
# Meep progress: 77.03/77.5 = 99.4% done in 12660.8s, 77.2s to go
# on time step 15406 (time=77.03), 0.733964 s/step
# Meep progress: 77.06/77.5 = 99.4% done in 12665.2s, 72.3s to go
# on time step 15412 (time=77.06), 0.737117 s/step
# Meep progress: 77.09/77.5 = 99.5% done in 12669.6s, 67.4s to go
# on time step 15418 (time=77.09), 0.727425 s/step
# Meep progress: 77.12/77.5 = 99.5% done in 12673.9s, 62.4s to go
# on time step 15424 (time=77.12), 0.731747 s/step
# Meep progress: 77.15/77.5 = 99.5% done in 12678.2s, 57.5s to go
# on time step 15430 (time=77.15), 0.703765 s/step
# Meep progress: 77.18/77.5 = 99.6% done in 12682.3s, 52.6s to go
# on time step 15436 (time=77.18), 0.692468 s/step
# Meep progress: 77.21000000000001/77.5 = 99.6% done in 12686.5s, 47.7s to go
# on time step 15442 (time=77.21), 0.6891 s/step
# Meep progress: 77.24/77.5 = 99.7% done in 12690.6s, 42.7s to go
# on time step 15448 (time=77.24), 0.690091 s/step
# Meep progress: 77.27/77.5 = 99.7% done in 12694.7s, 37.8s to go
# on time step 15454 (time=77.27), 0.690958 s/step
# Meep progress: 77.3/77.5 = 99.7% done in 12698.9s, 32.9s to go
# on time step 15460 (time=77.3), 0.690293 s/step
# Meep progress: 77.33/77.5 = 99.8% done in 12703.0s, 27.9s to go
# on time step 15466 (time=77.33), 0.688329 s/step
# Meep progress: 77.36/77.5 = 99.8% done in 12707.2s, 23.0s to go
# on time step 15472 (time=77.36), 0.703472 s/step
# Meep progress: 77.39/77.5 = 99.9% done in 12711.5s, 18.1s to go
# on time step 15478 (time=77.39), 0.706665 s/step
# Meep progress: 77.42/77.5 = 99.9% done in 12715.7s, 13.1s to go
# on time step 15484 (time=77.42), 0.697512 s/step
# Meep progress: 77.45/77.5 = 99.9% done in 12719.8s, 8.2s to go
# on time step 15490 (time=77.45), 0.694815 s/step
# Meep progress: 77.48/77.5 = 100.0% done in 12724.0s, 3.3s to go
# on time step 15496 (time=77.48), 0.692423 s/step
# run 0 finished at t = 77.5 (15500 timesteps)

# %%
Ex_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ex,0)
Ey_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ey,0)
Ez_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xz.npy',Ex_xz)
np.save('DFT_GAS/Dft_GAS_Ey_xz.npy',Ey_xz)
np.save('DFT_GAS/Dft_GAS_Ez_xz.npy',Ez_xz)

Ex_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ex,0)
Ey_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ey,0)
Ez_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_yz.npy',Ex_yz)
np.save('DFT_GAS/Dft_GAS_Ey_yz.npy',Ey_yz)
np.save('DFT_GAS/Dft_GAS_Ez_yz.npy',Ez_yz)

Ex01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ex,0)
Ey01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ey,0)
Ez01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xyz1.npy',Ex01)
np.save('DFT_GAS/Dft_GAS_Ey_xyz1.npy',Ey01)
np.save('DFT_GAS/Dft_GAS_Ez_xyz1.npy',Ez01)

Ex00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ex,0)
Ey00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ey,0)
Ez00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ez,0)
np.save('DFT_GAS/Dft_GAS_Ex_xyz0.npy',Ex00)
np.save('DFT_GAS/Dft_GAS_Ey_xyz0.npy',Ey00)
np.save('DFT_GAS/Dft_GAS_Ez_xyz0.npy',Ez00)
