# %%
import meep as mp
import meep.adjoint as mpa
from meep import Animate2D
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
from meep.materials import Ag
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from PIL import Image
import matplotlib.colors as mcolors

mp.verbosity(1)
TiO2 = mp.Medium(index=2.6)
SiO2 = mp.Medium(index=1.44)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1)

# %%
os.makedirs('DFT_FOM_TEST',exist_ok=True) # Create Folder


resolution = 100
design_region_resolution = int(resolution)

design_region_x_width  = 1   #100 nm
design_region_y_height = 1   #100 nm
design_region_z_height = 0.02  #20 nm or 10nm

pml_size = 1.0
pml_layers = [mp.PML(pml_size,direction=mp.Z)]

Sz_size = 0.6
Sx = design_region_x_width
Sy = design_region_y_height 
Sz = 2 * pml_size + design_region_z_height + Sz_size
cell_size = mp.Vector3(Sx, Sy, Sz)

wavelengths = np.array([1.55])     # wavelengths = np.array([1.5 ,1.55, 1.6])
frequencies = np.array([1 / 1.55])

nf = 1                 #3 #wavelengths Number

minimum_length = 0.02  # minimum length scale (microns)
eta_i = 0.5            # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55           # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e      # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

Source_distance = -0.2

fcen   = 1 / 1.55
width  = 0.2  
fwidth = width * fcen
source_center = mp.Vector3(0,0,Source_distance)  
source_size   = mp.Vector3(design_region_x_width, design_region_y_height, 0)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)]   

Nx = int(design_region_resolution * design_region_x_width) + 1
Ny = int(design_region_resolution * design_region_y_height) + 1
Nz = 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, Ag, grid_type="U_MEAN")
design_region    = mpa.DesignRegion(
            design_variables,
            volume=mp.Volume(
            center=mp.Vector3(0,0,0),
            size=mp.Vector3(design_region_x_width, design_region_y_height, design_region_z_height),
            ),
)

def mapping(x, eta, beta):
    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_x_width,
        design_region_y_height,
        design_region_resolution,
    )
    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)
    projected_field = (npa.fliplr(projected_field) + projected_field) / 2
    projected_field = (npa.flipud(projected_field) + projected_field) / 2  # left-right symmetry    
    
    return projected_field.flatten()


geometry = [mp.Block(center=design_region.center, size=design_region.size, material=design_variables)]

kpoint = mp.Vector3()
sim = mp.Simulation(
    cell_size        = cell_size,
    boundary_layers  = pml_layers,
    geometry         = geometry,
    sources          = source,
    default_material = Air,
    k_point          = kpoint,
    symmetries       = [mp.Mirror(direction=mp.X)],
    resolution       = resolution,
    extra_materials  = [Ag],       # Introducing metal complex terms
)
#---------------------------------------------------------------------------------------------------#


#-----------------[4]---------------------------------#
monitor_position   = mp.Vector3(0, 0, 0)       # Focus position
monitor_size       = mp.Vector3(0.01,0.01,design_region_z_height)     # Focus Size//////0.11
FourierFields_x    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ex,yee_grid=True)
FourierFields_y    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ey,yee_grid=True)
FourierFields_z    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list            = [FourierFields_x,FourierFields_y,FourierFields_z]


def J(fields_x,fields_y,fields_z):
    ET_x = 0
    ET_y = 0
    ET_z = 0
    ET_x_length = fields_x.shape[1]
    ET_y_length = fields_y.shape[1]
    ET_z_length = fields_z.shape[1]
    for k in range(0,ET_x_length):
        ET_x = ET_x + npa.abs(fields_x[:,k]) ** 2
    for k in range(0,ET_y_length):
        ET_y = ET_y + npa.abs(fields_y[:,k]) ** 2
    for k in range(0,ET_z_length):
        ET_z = ET_z + npa.abs(fields_z[:,k]) ** 2
    ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2)  
    return ET


opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decimation_factor = 1 ,           # KEY BUG!!
    maximum_run_time=50,
)



beta_A  = np.load("Post_beta_scale_array.npy")
eta_A   = np.load("Post_eta_i_array.npy")
cur_A   = np.load("Post_cur_beta_array.npy")
x_A     = np.load("Post_x_array.npy")
opt.update_design([mapping(x_A, eta_A, cur_A/beta_A)])  # cur_beta/beta_scale is the final beta in the optimization.


opt.sim = mp.Simulation(
    cell_size=mp.Vector3(Sx, Sy ,Sz),
    boundary_layers=pml_layers,
    geometry=geometry,
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point=kpoint,
    #symmetries=[mp.Mirror(direction=mp.X)],
    extra_materials = [Ag],
)
#src = mp.ContinuousSource(frequency=frequencies[0], fwidth=0.01 ,is_integrated=True)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)] 
opt.sim.change_sources(source)

dft_fields_test = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                frequencies,
                                center=monitor_position,
                                size=monitor_size,
                                yee_grid=True
                                )


opt.sim.run(until_after_sources=mp.stop_when_dft_decayed(tol=1e-11,minimum_run_time=0,maximum_run_time=50))

Ex_xz = opt.sim.get_dft_array(dft_fields_test,mp.Ex,0)
Ey_xz = opt.sim.get_dft_array(dft_fields_test,mp.Ey,0)
Ez_xz = opt.sim.get_dft_array(dft_fields_test,mp.Ez,0)

np.save('DFT_FOM_TEST/Dft_test_Ex.npy',Ex_xz)
np.save('DFT_FOM_TEST/Dft_test_Ey.npy',Ey_xz)
np.save('DFT_FOM_TEST/Dft_test_Ez.npy',Ez_xz)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000124216 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 2.62 with resolution 100
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)
# time for set_epsilon = 7.77162 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# on time step 1 (time=0.005), 4.18716 s/step
# on time step 9 (time=0.045), 0.546231 s/step
# on time step 17 (time=0.085), 0.548614 s/step
# on time step 25 (time=0.125), 0.544813 s/step
# on time step 33 (time=0.165), 0.555273 s/step
# on time step 41 (time=0.205), 0.548812 s/step
# on time step 49 (time=0.245), 0.552904 s/step
# on time step 57 (time=0.285), 0.539736 s/step
# on time step 65 (time=0.325), 0.553212 s/step
# on time step 73 (time=0.365), 0.549194 s/step
# on time step 83 (time=0.415), 0.437674 s/step
# on time step 93 (time=0.465), 0.400846 s/step
# on time step 103 (time=0.515), 0.416107 s/step
# on time step 112 (time=0.56), 0.465551 s/step
# on time step 122 (time=0.61), 0.436079 s/step
# on time step 131 (time=0.655), 0.446049 s/step
# on time step 141 (time=0.705), 0.416281 s/step
# on time step 151 (time=0.755), 0.445275 s/step
# on time step 161 (time=0.805), 0.440514 s/step
# on time step 171 (time=0.855), 0.435859 s/step
# on time step 181 (time=0.905), 0.427257 s/step
# on time step 191 (time=0.955), 0.411997 s/step
# on time step 201 (time=1.005), 0.404271 s/step
# on time step 211 (time=1.055), 0.409919 s/step
# on time step 221 (time=1.105), 0.406218 s/step
# on time step 231 (time=1.155), 0.409645 s/step
# on time step 241 (time=1.205), 0.410191 s/step
# on time step 251 (time=1.255), 0.405556 s/step
# on time step 261 (time=1.305), 0.406987 s/step
# on time step 271 (time=1.355), 0.415565 s/step
# on time step 281 (time=1.405), 0.419093 s/step
# on time step 290 (time=1.45), 0.452964 s/step
# on time step 298 (time=1.49), 0.536695 s/step
# on time step 306 (time=1.53), 0.526118 s/step
# on time step 316 (time=1.58), 0.401639 s/step
# on time step 325 (time=1.625), 0.499723 s/step
# on time step 333 (time=1.665), 0.562766 s/step
# on time step 341 (time=1.705), 0.567611 s/step
# on time step 349 (time=1.745), 0.564498 s/step
# on time step 356 (time=1.78), 0.576717 s/step
# on time step 364 (time=1.82), 0.56112 s/step
# on time step 372 (time=1.86), 0.570862 s/step
# on time step 380 (time=1.9), 0.563298 s/step
# on time step 388 (time=1.94), 0.572632 s/step
# on time step 395 (time=1.975), 0.571487 s/step
# on time step 403 (time=2.015), 0.56264 s/step
# on time step 410 (time=2.05), 0.574455 s/step
# on time step 418 (time=2.09), 0.568458 s/step
# on time step 425 (time=2.125), 0.57609 s/step
# on time step 432 (time=2.16), 0.57238 s/step
# on time step 439 (time=2.195), 0.576207 s/step
# on time step 446 (time=2.23), 0.574827 s/step
# on time step 454 (time=2.27), 0.570362 s/step
# on time step 462 (time=2.31), 0.573173 s/step
# on time step 470 (time=2.35), 0.568889 s/step
# on time step 478 (time=2.39), 0.571478 s/step
# on time step 486 (time=2.43), 0.566727 s/step
# on time step 493 (time=2.465), 0.577406 s/step
# on time step 500 (time=2.5), 0.581516 s/step
# on time step 508 (time=2.54), 0.558742 s/step
# on time step 515 (time=2.575), 0.572384 s/step
# on time step 523 (time=2.615), 0.564283 s/step
# on time step 531 (time=2.655), 0.558324 s/step
# on time step 539 (time=2.695), 0.566304 s/step
# on time step 547 (time=2.735), 0.561754 s/step
# on time step 555 (time=2.775), 0.571132 s/step
# on time step 569 (time=2.845), 0.293835 s/step
# on time step 580 (time=2.9), 0.390564 s/step
# on time step 590 (time=2.95), 0.404904 s/step
# on time step 600 (time=3), 0.402437 s/step
# on time step 610 (time=3.05), 0.402974 s/step
# on time step 620 (time=3.1), 0.41289 s/step
# on time step 630 (time=3.15), 0.406396 s/step
# on time step 640 (time=3.2), 0.416019 s/step
# on time step 650 (time=3.25), 0.406315 s/step
# on time step 660 (time=3.3), 0.406821 s/step
# on time step 670 (time=3.35), 0.411812 s/step
# on time step 680 (time=3.4), 0.405957 s/step
# on time step 690 (time=3.45), 0.413996 s/step
# on time step 700 (time=3.5), 0.408329 s/step
# on time step 710 (time=3.55), 0.421764 s/step
# on time step 720 (time=3.6), 0.410505 s/step
# on time step 730 (time=3.65), 0.41018 s/step
# on time step 740 (time=3.7), 0.405938 s/step
# on time step 750 (time=3.75), 0.470874 s/step
# on time step 756 (time=3.78), 0.719592 s/step
# on time step 763 (time=3.815), 0.602577 s/step
# on time step 771 (time=3.855), 0.521946 s/step
# on time step 779 (time=3.895), 0.5475 s/step
# on time step 787 (time=3.935), 0.524202 s/step
# on time step 795 (time=3.975), 0.553943 s/step
# on time step 805 (time=4.025), 0.419503 s/step
# on time step 815 (time=4.075), 0.42902 s/step
# on time step 825 (time=4.125), 0.408687 s/step
# on time step 835 (time=4.175), 0.40941 s/step
# on time step 845 (time=4.225), 0.411776 s/step
# on time step 855 (time=4.275), 0.409544 s/step
# on time step 865 (time=4.325), 0.411028 s/step
# on time step 875 (time=4.375), 0.42347 s/step
# on time step 885 (time=4.425), 0.414238 s/step
# on time step 895 (time=4.475), 0.413081 s/step
# on time step 905 (time=4.525), 0.412098 s/step
# on time step 915 (time=4.575), 0.406548 s/step
# on time step 925 (time=4.625), 0.409313 s/step
# on time step 935 (time=4.675), 0.408011 s/step
# on time step 945 (time=4.725), 0.411332 s/step
# on time step 955 (time=4.775), 0.407488 s/step
# on time step 965 (time=4.825), 0.409813 s/step
# on time step 975 (time=4.875), 0.408774 s/step
# on time step 985 (time=4.925), 0.415251 s/step
# on time step 995 (time=4.975), 0.411779 s/step
# on time step 1005 (time=5.025), 0.420239 s/step
# on time step 1015 (time=5.075), 0.419359 s/step
# on time step 1023 (time=5.115), 0.555919 s/step
# on time step 1032 (time=5.16), 0.46566 s/step
# on time step 1042 (time=5.21), 0.431254 s/step
# on time step 1051 (time=5.255), 0.444978 s/step
# on time step 1061 (time=5.305), 0.415593 s/step
# on time step 1071 (time=5.355), 0.423087 s/step
# on time step 1081 (time=5.405), 0.441811 s/step
# on time step 1091 (time=5.455), 0.430687 s/step
# on time step 1101 (time=5.505), 0.420736 s/step
# on time step 1111 (time=5.555), 0.430454 s/step
# on time step 1121 (time=5.605), 0.421703 s/step
# on time step 1131 (time=5.655), 0.430102 s/step
# on time step 1141 (time=5.705), 0.433467 s/step
# on time step 1151 (time=5.755), 0.415446 s/step
# on time step 1161 (time=5.805), 0.41866 s/step
# on time step 1171 (time=5.855), 0.419912 s/step
# on time step 1181 (time=5.905), 0.422157 s/step
# on time step 1191 (time=5.955), 0.419673 s/step
# on time step 1201 (time=6.005), 0.42112 s/step
# on time step 1211 (time=6.055), 0.446159 s/step
# on time step 1220 (time=6.1), 0.469767 s/step
# on time step 1229 (time=6.145), 0.472245 s/step
# on time step 1238 (time=6.19), 0.465886 s/step
# on time step 1245 (time=6.225), 0.615208 s/step
# on time step 1252 (time=6.26), 0.609825 s/step
# on time step 1259 (time=6.295), 0.606269 s/step
# on time step 1266 (time=6.33), 0.604735 s/step
# on time step 1273 (time=6.365), 0.601759 s/step
# on time step 1280 (time=6.4), 0.60527 s/step
# on time step 1287 (time=6.435), 0.60781 s/step
# on time step 1294 (time=6.47), 0.605689 s/step
# on time step 1301 (time=6.505), 0.60866 s/step
# on time step 1308 (time=6.54), 0.607947 s/step
# on time step 1315 (time=6.575), 0.606856 s/step
# on time step 1322 (time=6.61), 0.604483 s/step
# on time step 1329 (time=6.645), 0.607711 s/step
# on time step 1336 (time=6.68), 0.606365 s/step
# on time step 1343 (time=6.715), 0.60012 s/step
# on time step 1350 (time=6.75), 0.598468 s/step
# on time step 1357 (time=6.785), 0.600234 s/step
# on time step 1364 (time=6.82), 0.608296 s/step
# on time step 1371 (time=6.855), 0.596292 s/step
# on time step 1378 (time=6.89), 0.612188 s/step
# on time step 1385 (time=6.925), 0.597121 s/step
# on time step 1392 (time=6.96), 0.606046 s/step
# on time step 1399 (time=6.995), 0.614899 s/step
# on time step 1406 (time=7.03), 0.603059 s/step
# on time step 1413 (time=7.065), 0.613273 s/step
# on time step 1420 (time=7.1), 0.603627 s/step
# on time step 1427 (time=7.135), 0.606744 s/step
# on time step 1434 (time=7.17), 0.593034 s/step
# on time step 1442 (time=7.21), 0.549414 s/step
# on time step 1455 (time=7.275), 0.340541 s/step
# on time step 1465 (time=7.325), 0.451018 s/step
# on time step 1472 (time=7.36), 0.661051 s/step
# on time step 1480 (time=7.4), 0.522769 s/step
# on time step 1488 (time=7.44), 0.513591 s/step
# on time step 1495 (time=7.475), 0.594775 s/step
# on time step 1503 (time=7.515), 0.55237 s/step
# on time step 1511 (time=7.555), 0.562217 s/step
# on time step 1519 (time=7.595), 0.551566 s/step
# on time step 1526 (time=7.63), 0.593144 s/step
# on time step 1534 (time=7.67), 0.563585 s/step
# on time step 1542 (time=7.71), 0.562166 s/step
# on time step 1550 (time=7.75), 0.560989 s/step
# on time step 1557 (time=7.785), 0.592427 s/step
# on time step 1564 (time=7.82), 0.579528 s/step
# on time step 1571 (time=7.855), 0.57418 s/step
# on time step 1578 (time=7.89), 0.599952 s/step
# on time step 1585 (time=7.925), 0.589594 s/step
# on time step 1592 (time=7.96), 0.586953 s/step
# on time step 1599 (time=7.995), 0.589237 s/step
# on time step 1606 (time=8.03), 0.585402 s/step
# on time step 1613 (time=8.065), 0.584352 s/step
# on time step 1620 (time=8.1), 0.58291 s/step
# on time step 1627 (time=8.135), 0.603844 s/step
# on time step 1634 (time=8.17), 0.600248 s/step
# on time step 1641 (time=8.205), 0.596476 s/step
# on time step 1648 (time=8.24), 0.584598 s/step
# on time step 1655 (time=8.275), 0.582201 s/step
# on time step 1662 (time=8.31), 0.588833 s/step
# on time step 1669 (time=8.345), 0.576446 s/step
# on time step 1676 (time=8.38), 0.58296 s/step
# on time step 1683 (time=8.415), 0.598696 s/step
# on time step 1690 (time=8.45), 0.584486 s/step
# on time step 1697 (time=8.485), 0.589695 s/step
# on time step 1704 (time=8.52), 0.588204 s/step
# on time step 1711 (time=8.555), 0.583347 s/step
# on time step 1718 (time=8.59), 0.589705 s/step
# on time step 1725 (time=8.625), 0.587401 s/step
# on time step 1732 (time=8.66), 0.576333 s/step
# on time step 1739 (time=8.695), 0.579666 s/step
# on time step 1746 (time=8.73), 0.587182 s/step
# on time step 1753 (time=8.765), 0.587432 s/step
# on time step 1760 (time=8.8), 0.58657 s/step
# on time step 1767 (time=8.835), 0.580133 s/step
# on time step 1774 (time=8.87), 0.577201 s/step
# on time step 1781 (time=8.905), 0.579749 s/step
# on time step 1788 (time=8.94), 0.580327 s/step
# on time step 1795 (time=8.975), 0.593449 s/step
# on time step 1802 (time=9.01), 0.590813 s/step
# on time step 1809 (time=9.045), 0.583157 s/step
# on time step 1816 (time=9.08), 0.587022 s/step
# on time step 1823 (time=9.115), 0.579429 s/step
# on time step 1834 (time=9.17), 0.365429 s/step
# on time step 1848 (time=9.24), 0.300265 s/step
# on time step 1863 (time=9.315), 0.308144 s/step
# on time step 1869 (time=9.345), 0.667125 s/step
# on time step 1876 (time=9.38), 0.637893 s/step
# on time step 1883 (time=9.415), 0.62313 s/step
# on time step 1890 (time=9.45), 0.624995 s/step
# on time step 1897 (time=9.485), 0.610907 s/step
# on time step 1904 (time=9.52), 0.601105 s/step
# on time step 1911 (time=9.555), 0.596558 s/step
# on time step 1918 (time=9.59), 0.593768 s/step
# on time step 1925 (time=9.625), 0.591642 s/step
# on time step 1932 (time=9.66), 0.598395 s/step
# on time step 1939 (time=9.695), 0.610686 s/step
# on time step 1946 (time=9.73), 0.600167 s/step
# on time step 1953 (time=9.765), 0.601844 s/step
# on time step 1960 (time=9.8), 0.605151 s/step
# on time step 1967 (time=9.835), 0.609674 s/step
# on time step 1974 (time=9.87), 0.612646 s/step
# on time step 1981 (time=9.905), 0.605908 s/step
# on time step 1988 (time=9.94), 0.608558 s/step
# on time step 1995 (time=9.975), 0.606866 s/step
# on time step 2002 (time=10.01), 0.607571 s/step
# on time step 2010 (time=10.05), 0.51399 s/step
# on time step 2019 (time=10.095), 0.469008 s/step
# on time step 2028 (time=10.14), 0.470255 s/step
# on time step 2037 (time=10.185), 0.470088 s/step
# on time step 2046 (time=10.23), 0.467674 s/step
# on time step 2060 (time=10.3), 0.313532 s/step
# on time step 2069 (time=10.345), 0.501062 s/step
# on time step 2076 (time=10.38), 0.577513 s/step
# on time step 2083 (time=10.415), 0.57407 s/step
# on time step 2090 (time=10.45), 0.577291 s/step
# on time step 2098 (time=10.49), 0.558917 s/step
# on time step 2106 (time=10.53), 0.561892 s/step
# on time step 2114 (time=10.57), 0.558338 s/step
# on time step 2122 (time=10.61), 0.568562 s/step
# on time step 2130 (time=10.65), 0.560006 s/step
# on time step 2138 (time=10.69), 0.572849 s/step
# on time step 2145 (time=10.725), 0.585696 s/step
# on time step 2152 (time=10.76), 0.579747 s/step
# on time step 2159 (time=10.795), 0.58334 s/step
# on time step 2166 (time=10.83), 0.578713 s/step
# on time step 2173 (time=10.865), 0.578281 s/step
# on time step 2180 (time=10.9), 0.587223 s/step
# on time step 2187 (time=10.935), 0.58336 s/step
# on time step 2194 (time=10.97), 0.583345 s/step
# on time step 2204 (time=11.02), 0.409934 s/step
# on time step 2216 (time=11.08), 0.355728 s/step
# on time step 2227 (time=11.135), 0.39438 s/step
# on time step 2238 (time=11.19), 0.41016 s/step
# on time step 2245 (time=11.225), 0.586615 s/step
# on time step 2252 (time=11.26), 0.576433 s/step
# on time step 2259 (time=11.295), 0.587177 s/step
# on time step 2266 (time=11.33), 0.589347 s/step
# on time step 2273 (time=11.365), 0.579516 s/step
# on time step 2280 (time=11.4), 0.591802 s/step
# on time step 2287 (time=11.435), 0.585603 s/step
# on time step 2294 (time=11.47), 0.586776 s/step
# on time step 2301 (time=11.505), 0.57859 s/step
# on time step 2308 (time=11.54), 0.58322 s/step
# on time step 2315 (time=11.575), 0.59678 s/step
# on time step 2322 (time=11.61), 0.589325 s/step
# on time step 2329 (time=11.645), 0.588891 s/step
# on time step 2336 (time=11.68), 0.589442 s/step
# on time step 2343 (time=11.715), 0.589251 s/step
# on time step 2350 (time=11.75), 0.583183 s/step
# on time step 2357 (time=11.785), 0.590315 s/step
# on time step 2364 (time=11.82), 0.593393 s/step
# on time step 2371 (time=11.855), 0.589649 s/step
# on time step 2381 (time=11.905), 0.42663 s/step
# on time step 2391 (time=11.955), 0.413964 s/step
# on time step 2401 (time=12.005), 0.415993 s/step
# on time step 2411 (time=12.055), 0.403993 s/step
# on time step 2421 (time=12.105), 0.403132 s/step
# on time step 2431 (time=12.155), 0.403251 s/step
# on time step 2440 (time=12.2), 0.45775 s/step
# on time step 2448 (time=12.24), 0.534788 s/step
# on time step 2456 (time=12.28), 0.534151 s/step
# on time step 2465 (time=12.325), 0.465684 s/step
# on time step 2476 (time=12.38), 0.407933 s/step
# on time step 2484 (time=12.42), 0.550169 s/step
# on time step 2492 (time=12.46), 0.547965 s/step
# on time step 2500 (time=12.5), 0.55261 s/step
# on time step 2508 (time=12.54), 0.543694 s/step
# on time step 2516 (time=12.58), 0.548496 s/step
# on time step 2524 (time=12.62), 0.54122 s/step
# on time step 2532 (time=12.66), 0.543304 s/step
# on time step 2540 (time=12.7), 0.542751 s/step
# on time step 2548 (time=12.74), 0.558349 s/step
# on time step 2556 (time=12.78), 0.562887 s/step
# on time step 2564 (time=12.82), 0.56271 s/step
# on time step 2572 (time=12.86), 0.565405 s/step
# on time step 2580 (time=12.9), 0.581999 s/step
# on time step 2587 (time=12.935), 0.604184 s/step
# on time step 2595 (time=12.975), 0.523857 s/step
# on time step 2603 (time=13.015), 0.517378 s/step
# on time step 2611 (time=13.055), 0.509752 s/step
# on time step 2619 (time=13.095), 0.514126 s/step
# on time step 2627 (time=13.135), 0.511129 s/step
# on time step 2635 (time=13.175), 0.519316 s/step
# on time step 2643 (time=13.215), 0.528821 s/step
# on time step 2651 (time=13.255), 0.518646 s/step
# on time step 2659 (time=13.295), 0.522209 s/step
# on time step 2667 (time=13.335), 0.527092 s/step
# on time step 2675 (time=13.375), 0.52949 s/step
# on time step 2683 (time=13.415), 0.529954 s/step
# on time step 2691 (time=13.455), 0.520804 s/step
# on time step 2699 (time=13.495), 0.539287 s/step
# on time step 2707 (time=13.535), 0.518178 s/step
# on time step 2715 (time=13.575), 0.519426 s/step
# on time step 2723 (time=13.615), 0.531051 s/step
# on time step 2731 (time=13.655), 0.535052 s/step
# on time step 2739 (time=13.695), 0.534594 s/step
# on time step 2747 (time=13.735), 0.524285 s/step
# on time step 2755 (time=13.775), 0.502218 s/step
# on time step 2764 (time=13.82), 0.502177 s/step
# on time step 2772 (time=13.86), 0.501653 s/step
# on time step 2780 (time=13.9), 0.502487 s/step
# on time step 2788 (time=13.94), 0.502019 s/step
# on time step 2796 (time=13.98), 0.500303 s/step
# on time step 2804 (time=14.02), 0.501733 s/step
# on time step 2813 (time=14.065), 0.49856 s/step
# on time step 2822 (time=14.11), 0.49743 s/step
# on time step 2831 (time=14.155), 0.494098 s/step
# on time step 2840 (time=14.2), 0.47873 s/step
# on time step 2849 (time=14.245), 0.480012 s/step
# on time step 2859 (time=14.295), 0.429461 s/step
# on time step 2867 (time=14.335), 0.540913 s/step
# on time step 2875 (time=14.375), 0.536525 s/step
# on time step 2884 (time=14.42), 0.45291 s/step
# on time step 2895 (time=14.475), 0.39769 s/step
# on time step 2905 (time=14.525), 0.40309 s/step
# on time step 2916 (time=14.58), 0.398984 s/step
# on time step 2927 (time=14.635), 0.393227 s/step
# on time step 2938 (time=14.69), 0.396055 s/step
# on time step 2949 (time=14.745), 0.396633 s/step
# on time step 2959 (time=14.795), 0.430559 s/step
# on time step 2970 (time=14.85), 0.397138 s/step
# on time step 2981 (time=14.905), 0.39583 s/step
# on time step 2992 (time=14.96), 0.384096 s/step
# on time step 3003 (time=15.015), 0.385888 s/step
# on time step 3014 (time=15.07), 0.39603 s/step
# on time step 3025 (time=15.125), 0.391133 s/step
# on time step 3036 (time=15.18), 0.392249 s/step
# on time step 3047 (time=15.235), 0.391287 s/step
# on time step 3058 (time=15.29), 0.382753 s/step
# on time step 3069 (time=15.345), 0.388629 s/step
# on time step 3080 (time=15.4), 0.393536 s/step
# on time step 3091 (time=15.455), 0.390161 s/step
# on time step 3102 (time=15.51), 0.39314 s/step
# on time step 3113 (time=15.565), 0.385471 s/step
# on time step 3124 (time=15.62), 0.386668 s/step
# on time step 3135 (time=15.675), 0.381285 s/step
# on time step 3146 (time=15.73), 0.386182 s/step
# on time step 3157 (time=15.785), 0.382952 s/step
# on time step 3168 (time=15.84), 0.384687 s/step
# on time step 3179 (time=15.895), 0.38443 s/step
# on time step 3190 (time=15.95), 0.380953 s/step
# on time step 3201 (time=16.005), 0.384867 s/step
# on time step 3212 (time=16.06), 0.384997 s/step
# on time step 3223 (time=16.115), 0.388976 s/step
# on time step 3234 (time=16.17), 0.388536 s/step
# on time step 3244 (time=16.22), 0.400819 s/step
# on time step 3255 (time=16.275), 0.387738 s/step
# on time step 3266 (time=16.33), 0.382733 s/step
# on time step 3277 (time=16.385), 0.383838 s/step
# on time step 3288 (time=16.44), 0.382261 s/step
# on time step 3299 (time=16.495), 0.385611 s/step
# on time step 3310 (time=16.55), 0.382579 s/step
# on time step 3321 (time=16.605), 0.383004 s/step
# on time step 3332 (time=16.66), 0.382137 s/step
# on time step 3343 (time=16.715), 0.381077 s/step
# on time step 3354 (time=16.77), 0.387581 s/step
# on time step 3365 (time=16.825), 0.385931 s/step
# on time step 3376 (time=16.88), 0.384459 s/step
# on time step 3387 (time=16.935), 0.386326 s/step
# on time step 3398 (time=16.99), 0.386897 s/step
# on time step 3409 (time=17.045), 0.368963 s/step
# on time step 3421 (time=17.105), 0.358825 s/step
# on time step 3429 (time=17.145), 0.519587 s/step
# on time step 3437 (time=17.185), 0.565089 s/step
# on time step 3445 (time=17.225), 0.549895 s/step
# on time step 3453 (time=17.265), 0.548224 s/step
# on time step 3461 (time=17.305), 0.542889 s/step
# on time step 3469 (time=17.345), 0.538444 s/step
# on time step 3477 (time=17.385), 0.549986 s/step
# on time step 3485 (time=17.425), 0.552682 s/step
# on time step 3493 (time=17.465), 0.543778 s/step
# on time step 3501 (time=17.505), 0.554224 s/step
# on time step 3509 (time=17.545), 0.552988 s/step
# on time step 3517 (time=17.585), 0.55753 s/step
# on time step 3525 (time=17.625), 0.558126 s/step
# on time step 3533 (time=17.665), 0.555005 s/step
# on time step 3541 (time=17.705), 0.555874 s/step
# on time step 3549 (time=17.745), 0.555715 s/step
# on time step 3557 (time=17.785), 0.555002 s/step
# on time step 3565 (time=17.825), 0.553997 s/step
# on time step 3573 (time=17.865), 0.552776 s/step
# on time step 3581 (time=17.905), 0.547902 s/step
# on time step 3589 (time=17.945), 0.54234 s/step
# on time step 3597 (time=17.985), 0.560156 s/step
# on time step 3605 (time=18.025), 0.543772 s/step
# on time step 3613 (time=18.065), 0.551279 s/step
# on time step 3621 (time=18.105), 0.558897 s/step
# on time step 3629 (time=18.145), 0.550966 s/step
# on time step 3637 (time=18.185), 0.541937 s/step
# on time step 3645 (time=18.225), 0.55125 s/step
# on time step 3653 (time=18.265), 0.549957 s/step
# on time step 3661 (time=18.305), 0.523702 s/step
# on time step 3669 (time=18.345), 0.525781 s/step
# on time step 3677 (time=18.385), 0.515866 s/step
# on time step 3685 (time=18.425), 0.520161 s/step
# on time step 3693 (time=18.465), 0.540399 s/step
# on time step 3701 (time=18.505), 0.543297 s/step
# on time step 3709 (time=18.545), 0.56118 s/step
# on time step 3717 (time=18.585), 0.548354 s/step
# on time step 3725 (time=18.625), 0.544559 s/step
# on time step 3733 (time=18.665), 0.544793 s/step
# on time step 3741 (time=18.705), 0.557142 s/step
# on time step 3749 (time=18.745), 0.555364 s/step
# on time step 3757 (time=18.785), 0.539352 s/step
# on time step 3765 (time=18.825), 0.552549 s/step
# on time step 3773 (time=18.865), 0.563291 s/step
# on time step 3781 (time=18.905), 0.542586 s/step
# on time step 3789 (time=18.945), 0.550309 s/step
# on time step 3797 (time=18.985), 0.53976 s/step
# on time step 3805 (time=19.025), 0.55185 s/step
# on time step 3813 (time=19.065), 0.563302 s/step
# on time step 3823 (time=19.115), 0.416908 s/step
# on time step 3837 (time=19.185), 0.295848 s/step
# on time step 3852 (time=19.26), 0.270364 s/step
# on time step 3862 (time=19.31), 0.452625 s/step
# on time step 3870 (time=19.35), 0.52911 s/step
# on time step 3878 (time=19.39), 0.533714 s/step
# on time step 3886 (time=19.43), 0.53481 s/step
# on time step 3894 (time=19.47), 0.535767 s/step
# on time step 3902 (time=19.51), 0.537403 s/step
# on time step 3910 (time=19.55), 0.534058 s/step
# on time step 3918 (time=19.59), 0.535989 s/step
# on time step 3926 (time=19.63), 0.536102 s/step
# on time step 3934 (time=19.67), 0.535998 s/step
# on time step 3942 (time=19.71), 0.536627 s/step
# on time step 3950 (time=19.75), 0.546005 s/step
# on time step 3958 (time=19.79), 0.534462 s/step
# on time step 3966 (time=19.83), 0.549158 s/step
# on time step 3974 (time=19.87), 0.538474 s/step
# on time step 3982 (time=19.91), 0.534706 s/step
# on time step 3990 (time=19.95), 0.540027 s/step
# on time step 3998 (time=19.99), 0.53439 s/step
# on time step 4006 (time=20.03), 0.544951 s/step
# on time step 4014 (time=20.07), 0.540807 s/step
# on time step 4022 (time=20.11), 0.540586 s/step
# on time step 4034 (time=20.17), 0.346481 s/step
# on time step 4042 (time=20.21), 0.556089 s/step
# on time step 4049 (time=20.245), 0.575447 s/step
# on time step 4056 (time=20.28), 0.572012 s/step
# on time step 4063 (time=20.315), 0.574602 s/step
# on time step 4071 (time=20.355), 0.570729 s/step
# on time step 4078 (time=20.39), 0.579674 s/step
# on time step 4085 (time=20.425), 0.577168 s/step
# on time step 4092 (time=20.46), 0.576122 s/step
# on time step 4099 (time=20.495), 0.576527 s/step
# on time step 4106 (time=20.53), 0.573128 s/step
# on time step 4113 (time=20.565), 0.575924 s/step
# on time step 4120 (time=20.6), 0.575257 s/step
# on time step 4127 (time=20.635), 0.573707 s/step
# on time step 4134 (time=20.67), 0.572711 s/step
# on time step 4141 (time=20.705), 0.574869 s/step
# on time step 4148 (time=20.74), 0.574008 s/step
# on time step 4155 (time=20.775), 0.578689 s/step
# on time step 4162 (time=20.81), 0.574028 s/step
# on time step 4169 (time=20.845), 0.577685 s/step
# on time step 4176 (time=20.88), 0.577678 s/step
# on time step 4184 (time=20.92), 0.571735 s/step
# on time step 4191 (time=20.955), 0.573722 s/step
# on time step 4198 (time=20.99), 0.57213 s/step
# on time step 4205 (time=21.025), 0.59147 s/step
# on time step 4212 (time=21.06), 0.574929 s/step
# on time step 4219 (time=21.095), 0.585918 s/step
# on time step 4226 (time=21.13), 0.575698 s/step
# on time step 4233 (time=21.165), 0.575602 s/step
# on time step 4240 (time=21.2), 0.580607 s/step
# on time step 4247 (time=21.235), 0.572271 s/step
# on time step 4255 (time=21.275), 0.542328 s/step
# on time step 4266 (time=21.33), 0.390083 s/step
# on time step 4275 (time=21.375), 0.493672 s/step
# on time step 4283 (time=21.415), 0.5541 s/step
# on time step 4291 (time=21.455), 0.553412 s/step
# on time step 4299 (time=21.495), 0.55153 s/step
# on time step 4307 (time=21.535), 0.551707 s/step
# on time step 4315 (time=21.575), 0.549201 s/step
# on time step 4323 (time=21.615), 0.548673 s/step
# on time step 4331 (time=21.655), 0.555079 s/step
# on time step 4339 (time=21.695), 0.553287 s/step
# on time step 4347 (time=21.735), 0.552655 s/step
# on time step 4355 (time=21.775), 0.550795 s/step
# on time step 4363 (time=21.815), 0.552293 s/step
# on time step 4371 (time=21.855), 0.544895 s/step
# on time step 4379 (time=21.895), 0.54978 s/step
# on time step 4387 (time=21.935), 0.55226 s/step
# on time step 4395 (time=21.975), 0.551704 s/step
# on time step 4403 (time=22.015), 0.549323 s/step
# on time step 4411 (time=22.055), 0.556293 s/step
# on time step 4419 (time=22.095), 0.561312 s/step
# on time step 4427 (time=22.135), 0.55764 s/step
# on time step 4441 (time=22.205), 0.287559 s/step
# on time step 4454 (time=22.27), 0.323852 s/step
# on time step 4462 (time=22.31), 0.540415 s/step
# on time step 4470 (time=22.35), 0.544386 s/step
# on time step 4478 (time=22.39), 0.538139 s/step
# on time step 4486 (time=22.43), 0.52682 s/step
# on time step 4494 (time=22.47), 0.542513 s/step
# on time step 4502 (time=22.51), 0.526066 s/step
# on time step 4510 (time=22.55), 0.547844 s/step
# on time step 4518 (time=22.59), 0.530582 s/step
# on time step 4526 (time=22.63), 0.545153 s/step
# on time step 4534 (time=22.67), 0.530295 s/step
# on time step 4542 (time=22.71), 0.529278 s/step
# on time step 4550 (time=22.75), 0.542953 s/step
# on time step 4558 (time=22.79), 0.53738 s/step
# on time step 4566 (time=22.83), 0.544867 s/step
# on time step 4574 (time=22.87), 0.53523 s/step
# on time step 4582 (time=22.91), 0.542435 s/step
# on time step 4590 (time=22.95), 0.537633 s/step
# on time step 4598 (time=22.99), 0.544094 s/step
# on time step 4606 (time=23.03), 0.533854 s/step
# on time step 4614 (time=23.07), 0.534459 s/step
# on time step 4622 (time=23.11), 0.528841 s/step
# on time step 4630 (time=23.15), 0.536337 s/step
# on time step 4638 (time=23.19), 0.52207 s/step
# on time step 4646 (time=23.23), 0.523056 s/step
# on time step 4654 (time=23.27), 0.547403 s/step
# on time step 4662 (time=23.31), 0.540746 s/step
# on time step 4670 (time=23.35), 0.549874 s/step
# on time step 4678 (time=23.39), 0.528065 s/step
# on time step 4686 (time=23.43), 0.541729 s/step
# on time step 4694 (time=23.47), 0.540894 s/step
# on time step 4702 (time=23.51), 0.542639 s/step
# on time step 4710 (time=23.55), 0.534086 s/step
# on time step 4718 (time=23.59), 0.533908 s/step
# on time step 4726 (time=23.63), 0.541143 s/step
# on time step 4734 (time=23.67), 0.536852 s/step
# on time step 4742 (time=23.71), 0.537023 s/step
# on time step 4750 (time=23.75), 0.559813 s/step
# on time step 4758 (time=23.79), 0.533796 s/step
# on time step 4766 (time=23.83), 0.530165 s/step
# on time step 4774 (time=23.87), 0.538792 s/step
# on time step 4782 (time=23.91), 0.537412 s/step
# on time step 4790 (time=23.95), 0.559805 s/step
# on time step 4798 (time=23.99), 0.540199 s/step
# on time step 4806 (time=24.03), 0.540246 s/step
# on time step 4814 (time=24.07), 0.533026 s/step
# on time step 4822 (time=24.11), 0.537497 s/step
# on time step 4830 (time=24.15), 0.549678 s/step
# on time step 4838 (time=24.19), 0.549909 s/step
# on time step 4846 (time=24.23), 0.547044 s/step
# on time step 4854 (time=24.27), 0.541508 s/step
# on time step 4862 (time=24.31), 0.537388 s/step
# on time step 4870 (time=24.35), 0.534554 s/step
# on time step 4880 (time=24.4), 0.41153 s/step
# on time step 4888 (time=24.44), 0.565513 s/step
# on time step 4895 (time=24.475), 0.638089 s/step
# on time step 4903 (time=24.515), 0.510317 s/step
# on time step 4913 (time=24.565), 0.436294 s/step
# on time step 4923 (time=24.615), 0.419323 s/step
# on time step 4932 (time=24.66), 0.44991 s/step
# on time step 4942 (time=24.71), 0.418113 s/step
# on time step 4952 (time=24.76), 0.416797 s/step
# on time step 4962 (time=24.81), 0.434371 s/step
# on time step 4972 (time=24.86), 0.426548 s/step
# on time step 4982 (time=24.91), 0.420774 s/step
# on time step 4992 (time=24.96), 0.42256 s/step
# on time step 5002 (time=25.01), 0.418223 s/step
# on time step 5012 (time=25.06), 0.414906 s/step
# on time step 5022 (time=25.11), 0.434357 s/step
# on time step 5032 (time=25.16), 0.424266 s/step
# on time step 5042 (time=25.21), 0.427145 s/step
# on time step 5052 (time=25.26), 0.414586 s/step
# on time step 5062 (time=25.31), 0.41738 s/step
# on time step 5072 (time=25.36), 0.424086 s/step
# on time step 5082 (time=25.41), 0.418023 s/step
# on time step 5092 (time=25.46), 0.420381 s/step
# on time step 5102 (time=25.51), 0.417906 s/step
# on time step 5112 (time=25.56), 0.421455 s/step
# on time step 5122 (time=25.61), 0.420949 s/step
# on time step 5132 (time=25.66), 0.425176 s/step
# on time step 5142 (time=25.71), 0.431261 s/step
# on time step 5152 (time=25.76), 0.421153 s/step
# on time step 5162 (time=25.81), 0.426048 s/step
# on time step 5172 (time=25.86), 0.422788 s/step
# on time step 5182 (time=25.91), 0.425245 s/step
# on time step 5192 (time=25.96), 0.435435 s/step
# on time step 5201 (time=26.005), 0.44498 s/step
# on time step 5210 (time=26.05), 0.446517 s/step
# on time step 5220 (time=26.1), 0.443362 s/step
# on time step 5229 (time=26.145), 0.450647 s/step
# on time step 5238 (time=26.19), 0.447819 s/step
# on time step 5248 (time=26.24), 0.445528 s/step
# on time step 5257 (time=26.285), 0.448931 s/step
# on time step 5266 (time=26.33), 0.451617 s/step
# on time step 5275 (time=26.375), 0.449358 s/step
# on time step 5284 (time=26.42), 0.447456 s/step
# on time step 5293 (time=26.465), 0.448129 s/step
# on time step 5302 (time=26.51), 0.44575 s/step
# on time step 5311 (time=26.555), 0.446749 s/step
# on time step 5320 (time=26.6), 0.453076 s/step
# on time step 5329 (time=26.645), 0.451367 s/step
# on time step 5338 (time=26.69), 0.446397 s/step
# on time step 5348 (time=26.74), 0.423449 s/step
# on time step 5362 (time=26.81), 0.320832 s/step
# on time step 5370 (time=26.85), 0.549587 s/step
# on time step 5378 (time=26.89), 0.541906 s/step
# on time step 5386 (time=26.93), 0.539967 s/step
# on time step 5394 (time=26.97), 0.53443 s/step
# on time step 5402 (time=27.01), 0.52887 s/step
# on time step 5410 (time=27.05), 0.534058 s/step
# on time step 5418 (time=27.09), 0.536536 s/step
# on time step 5426 (time=27.13), 0.530522 s/step
# on time step 5434 (time=27.17), 0.533395 s/step
# on time step 5442 (time=27.21), 0.526608 s/step
# on time step 5450 (time=27.25), 0.529836 s/step
# on time step 5458 (time=27.29), 0.531542 s/step
# on time step 5466 (time=27.33), 0.522817 s/step
# on time step 5474 (time=27.37), 0.531794 s/step
# on time step 5482 (time=27.41), 0.513509 s/step
# on time step 5490 (time=27.45), 0.510351 s/step
# on time step 5498 (time=27.49), 0.509832 s/step
# on time step 5506 (time=27.53), 0.509329 s/step
# on time step 5514 (time=27.57), 0.510953 s/step
# on time step 5522 (time=27.61), 0.508062 s/step
# on time step 5530 (time=27.65), 0.514867 s/step
# on time step 5538 (time=27.69), 0.509745 s/step
# on time step 5546 (time=27.73), 0.509384 s/step
# on time step 5554 (time=27.77), 0.51069 s/step
# on time step 5562 (time=27.81), 0.511317 s/step
# on time step 5570 (time=27.85), 0.512194 s/step
# on time step 5578 (time=27.89), 0.511703 s/step
# on time step 5586 (time=27.93), 0.518344 s/step
# on time step 5594 (time=27.97), 0.51229 s/step
# on time step 5602 (time=28.01), 0.525154 s/step
# on time step 5610 (time=28.05), 0.507769 s/step
# on time step 5618 (time=28.09), 0.514582 s/step
# on time step 5626 (time=28.13), 0.515448 s/step
# on time step 5634 (time=28.17), 0.508168 s/step
# on time step 5642 (time=28.21), 0.51989 s/step
# on time step 5650 (time=28.25), 0.539667 s/step
# on time step 5658 (time=28.29), 0.566338 s/step
# on time step 5666 (time=28.33), 0.566929 s/step
# on time step 5674 (time=28.37), 0.562775 s/step
# on time step 5682 (time=28.41), 0.56785 s/step
# on time step 5690 (time=28.45), 0.562062 s/step
# on time step 5698 (time=28.49), 0.563434 s/step
# on time step 5707 (time=28.535), 0.480397 s/step
# on time step 5716 (time=28.58), 0.464746 s/step
# on time step 5725 (time=28.625), 0.464165 s/step
# on time step 5734 (time=28.67), 0.463444 s/step
# on time step 5743 (time=28.715), 0.46324 s/step
# on time step 5752 (time=28.76), 0.460593 s/step
# on time step 5761 (time=28.805), 0.459073 s/step
# on time step 5775 (time=28.875), 0.286762 s/step
# on time step 5788 (time=28.94), 0.324498 s/step
# on time step 5803 (time=29.015), 0.293093 s/step
# on time step 5810 (time=29.05), 0.608595 s/step
# on time step 5817 (time=29.085), 0.606913 s/step
# on time step 5824 (time=29.12), 0.600639 s/step
# on time step 5831 (time=29.155), 0.60706 s/step
# on time step 5838 (time=29.19), 0.609073 s/step
# on time step 5845 (time=29.225), 0.606027 s/step
# on time step 5852 (time=29.26), 0.601863 s/step
# on time step 5859 (time=29.295), 0.604809 s/step
# on time step 5866 (time=29.33), 0.605209 s/step
# on time step 5873 (time=29.365), 0.605441 s/step
# on time step 5880 (time=29.4), 0.615906 s/step
# on time step 5887 (time=29.435), 0.598478 s/step
# on time step 5894 (time=29.47), 0.604872 s/step
# on time step 5901 (time=29.505), 0.615378 s/step
# on time step 5908 (time=29.54), 0.610188 s/step
# on time step 5915 (time=29.575), 0.611818 s/step
# on time step 5922 (time=29.61), 0.6078 s/step
# on time step 5929 (time=29.645), 0.612263 s/step
# on time step 5936 (time=29.68), 0.605984 s/step
# on time step 5943 (time=29.715), 0.606843 s/step
# on time step 5950 (time=29.75), 0.612209 s/step
# on time step 5958 (time=29.79), 0.52027 s/step
# on time step 5970 (time=29.85), 0.351017 s/step
# on time step 5978 (time=29.89), 0.547157 s/step
# on time step 5986 (time=29.93), 0.548117 s/step
# on time step 5994 (time=29.97), 0.547287 s/step
# on time step 6002 (time=30.01), 0.542399 s/step
# on time step 6010 (time=30.05), 0.547491 s/step
# on time step 6018 (time=30.09), 0.552655 s/step
# on time step 6026 (time=30.13), 0.543579 s/step
# on time step 6034 (time=30.17), 0.550759 s/step
# on time step 6042 (time=30.21), 0.553287 s/step
# on time step 6050 (time=30.25), 0.548101 s/step
# on time step 6058 (time=30.29), 0.547426 s/step
# on time step 6066 (time=30.33), 0.549151 s/step
# on time step 6074 (time=30.37), 0.547738 s/step
# on time step 6082 (time=30.41), 0.54726 s/step
# on time step 6090 (time=30.45), 0.543895 s/step
# on time step 6098 (time=30.49), 0.547958 s/step
# on time step 6106 (time=30.53), 0.553874 s/step
# on time step 6114 (time=30.57), 0.547724 s/step
# on time step 6122 (time=30.61), 0.541431 s/step
# on time step 6130 (time=30.65), 0.545043 s/step
# on time step 6138 (time=30.69), 0.563461 s/step
# on time step 6146 (time=30.73), 0.555608 s/step
# on time step 6154 (time=30.77), 0.562338 s/step
# on time step 6162 (time=30.81), 0.54362 s/step
# on time step 6170 (time=30.85), 0.548779 s/step
# on time step 6178 (time=30.89), 0.543968 s/step
# on time step 6186 (time=30.93), 0.549897 s/step
# on time step 6194 (time=30.97), 0.553763 s/step
# on time step 6201 (time=31.005), 0.578088 s/step
# on time step 6210 (time=31.05), 0.45421 s/step
# on time step 6218 (time=31.09), 0.544393 s/step
# on time step 6226 (time=31.13), 0.546538 s/step
# on time step 6234 (time=31.17), 0.555129 s/step
# on time step 6242 (time=31.21), 0.564419 s/step
# on time step 6250 (time=31.25), 0.555898 s/step
# on time step 6258 (time=31.29), 0.561088 s/step
# on time step 6266 (time=31.33), 0.556938 s/step
# on time step 6274 (time=31.37), 0.551435 s/step
# on time step 6282 (time=31.41), 0.548062 s/step
# on time step 6290 (time=31.45), 0.554381 s/step
# on time step 6298 (time=31.49), 0.557964 s/step
# on time step 6306 (time=31.53), 0.556748 s/step
# on time step 6314 (time=31.57), 0.560215 s/step
# on time step 6322 (time=31.61), 0.559591 s/step
# on time step 6330 (time=31.65), 0.549985 s/step
# on time step 6338 (time=31.69), 0.550935 s/step
# on time step 6346 (time=31.73), 0.554487 s/step
# on time step 6354 (time=31.77), 0.542322 s/step
# on time step 6364 (time=31.82), 0.438127 s/step
# on time step 6374 (time=31.87), 0.429241 s/step
# on time step 6387 (time=31.935), 0.329085 s/step
# on time step 6396 (time=31.98), 0.463632 s/step
# on time step 6405 (time=32.025), 0.47229 s/step
# on time step 6413 (time=32.065), 0.500169 s/step
# on time step 6422 (time=32.11), 0.470345 s/step
# on time step 6431 (time=32.155), 0.473575 s/step
# on time step 6440 (time=32.2), 0.456991 s/step
# on time step 6449 (time=32.245), 0.453744 s/step
# on time step 6458 (time=32.29), 0.463215 s/step
# on time step 6468 (time=32.34), 0.411492 s/step
# on time step 6478 (time=32.39), 0.407667 s/step
# on time step 6488 (time=32.44), 0.407329 s/step
# on time step 6498 (time=32.49), 0.408181 s/step
# on time step 6510 (time=32.55), 0.347486 s/step
# on time step 6522 (time=32.61), 0.339 s/step
# on time step 6534 (time=32.67), 0.337318 s/step
# on time step 6546 (time=32.73), 0.340275 s/step
# on time step 6558 (time=32.79), 0.33692 s/step
# on time step 6570 (time=32.85), 0.345368 s/step
# on time step 6582 (time=32.91), 0.335299 s/step
# on time step 6594 (time=32.97), 0.336535 s/step
# on time step 6606 (time=33.03), 0.335583 s/step
# on time step 6618 (time=33.09), 0.343816 s/step
# on time step 6630 (time=33.15), 0.337355 s/step
# on time step 6642 (time=33.21), 0.337133 s/step
# on time step 6654 (time=33.27), 0.336808 s/step
# on time step 6666 (time=33.33), 0.339063 s/step
# on time step 6678 (time=33.39), 0.336166 s/step
# on time step 6690 (time=33.45), 0.338802 s/step
# on time step 6702 (time=33.51), 0.339058 s/step
# on time step 6714 (time=33.57), 0.337846 s/step
# on time step 6727 (time=33.635), 0.333725 s/step
# on time step 6739 (time=33.695), 0.336831 s/step
# on time step 6751 (time=33.755), 0.333815 s/step
# on time step 6763 (time=33.815), 0.335434 s/step
# on time step 6775 (time=33.875), 0.335196 s/step
# on time step 6787 (time=33.935), 0.334938 s/step
# on time step 6799 (time=33.995), 0.336226 s/step
# on time step 6811 (time=34.055), 0.334008 s/step
# on time step 6823 (time=34.115), 0.352922 s/step
# on time step 6835 (time=34.175), 0.338345 s/step
# on time step 6847 (time=34.235), 0.336866 s/step
# on time step 6859 (time=34.295), 0.336346 s/step
# on time step 6871 (time=34.355), 0.339067 s/step
# on time step 6883 (time=34.415), 0.338412 s/step
# on time step 6895 (time=34.475), 0.364343 s/step
# on time step 6906 (time=34.53), 0.393009 s/step
# on time step 6917 (time=34.585), 0.39287 s/step
# on time step 6928 (time=34.64), 0.39749 s/step
# on time step 6939 (time=34.695), 0.390199 s/step
# on time step 6950 (time=34.75), 0.393668 s/step
# on time step 6961 (time=34.805), 0.393977 s/step
# on time step 6971 (time=34.855), 0.404871 s/step
# on time step 6981 (time=34.905), 0.41513 s/step
# on time step 6993 (time=34.965), 0.349045 s/step
# on time step 7005 (time=35.025), 0.353702 s/step
# on time step 7016 (time=35.08), 0.365362 s/step
# on time step 7028 (time=35.14), 0.360919 s/step
# on time step 7039 (time=35.195), 0.364619 s/step
# on time step 7050 (time=35.25), 0.383085 s/step
# on time step 7061 (time=35.305), 0.374397 s/step
# on time step 7072 (time=35.36), 0.367559 s/step
# on time step 7084 (time=35.42), 0.363152 s/step
# on time step 7095 (time=35.475), 0.377055 s/step
# on time step 7107 (time=35.535), 0.356394 s/step
# on time step 7119 (time=35.595), 0.360525 s/step
# on time step 7130 (time=35.65), 0.378521 s/step
# on time step 7142 (time=35.71), 0.361642 s/step
# on time step 7153 (time=35.765), 0.367251 s/step
# on time step 7164 (time=35.82), 0.370412 s/step
# on time step 7176 (time=35.88), 0.356719 s/step
# on time step 7188 (time=35.94), 0.361872 s/step
# on time step 7200 (time=36), 0.3591 s/step
# on time step 7211 (time=36.055), 0.37854 s/step
# on time step 7223 (time=36.115), 0.362174 s/step
# on time step 7234 (time=36.17), 0.374851 s/step
# on time step 7245 (time=36.225), 0.373814 s/step
# on time step 7256 (time=36.28), 0.372411 s/step
# on time step 7267 (time=36.335), 0.371077 s/step
# on time step 7278 (time=36.39), 0.366406 s/step
# on time step 7289 (time=36.445), 0.36863 s/step
# on time step 7301 (time=36.505), 0.363336 s/step
# on time step 7312 (time=36.56), 0.372289 s/step
# on time step 7323 (time=36.615), 0.365682 s/step
# on time step 7334 (time=36.67), 0.364977 s/step
# on time step 7345 (time=36.725), 0.364623 s/step
# on time step 7356 (time=36.78), 0.365951 s/step
# on time step 7367 (time=36.835), 0.373399 s/step
# on time step 7378 (time=36.89), 0.375329 s/step
# on time step 7389 (time=36.945), 0.370118 s/step
# on time step 7400 (time=37), 0.368052 s/step
# on time step 7411 (time=37.055), 0.370011 s/step
# on time step 7422 (time=37.11), 0.365187 s/step
# on time step 7434 (time=37.17), 0.36199 s/step
# on time step 7446 (time=37.23), 0.359738 s/step
# on time step 7458 (time=37.29), 0.361578 s/step
# on time step 7470 (time=37.35), 0.36271 s/step
# on time step 7480 (time=37.4), 0.401698 s/step
# on time step 7489 (time=37.445), 0.475819 s/step
# on time step 7498 (time=37.49), 0.46453 s/step
# on time step 7507 (time=37.535), 0.471939 s/step
# on time step 7516 (time=37.58), 0.478118 s/step
# on time step 7529 (time=37.645), 0.321254 s/step
# on time step 7538 (time=37.69), 0.484962 s/step
# on time step 7546 (time=37.73), 0.508528 s/step
# on time step 7554 (time=37.77), 0.511405 s/step
# on time step 7562 (time=37.81), 0.50648 s/step
# on time step 7572 (time=37.86), 0.402758 s/step
# on time step 7583 (time=37.915), 0.380114 s/step
# on time step 7594 (time=37.97), 0.378696 s/step
# on time step 7605 (time=38.025), 0.379686 s/step
# on time step 7616 (time=38.08), 0.378503 s/step
# on time step 7627 (time=38.135), 0.378608 s/step
# on time step 7638 (time=38.19), 0.384089 s/step
# on time step 7649 (time=38.245), 0.396839 s/step
# on time step 7660 (time=38.3), 0.379331 s/step
# on time step 7671 (time=38.355), 0.379764 s/step
# on time step 7682 (time=38.41), 0.378984 s/step
# on time step 7693 (time=38.465), 0.380492 s/step
# on time step 7704 (time=38.52), 0.39465 s/step
# on time step 7715 (time=38.575), 0.385961 s/step
# on time step 7726 (time=38.63), 0.37876 s/step
# on time step 7737 (time=38.685), 0.379764 s/step
# on time step 7748 (time=38.74), 0.379832 s/step
# on time step 7759 (time=38.795), 0.379334 s/step
# on time step 7770 (time=38.85), 0.378891 s/step
# on time step 7781 (time=38.905), 0.391074 s/step
# on time step 7792 (time=38.96), 0.384417 s/step
# on time step 7803 (time=39.015), 0.383826 s/step
# on time step 7814 (time=39.07), 0.378849 s/step
# on time step 7825 (time=39.125), 0.379826 s/step
# on time step 7836 (time=39.18), 0.379968 s/step
# on time step 7847 (time=39.235), 0.380953 s/step
# on time step 7858 (time=39.29), 0.378245 s/step
# on time step 7869 (time=39.345), 0.378689 s/step
# on time step 7880 (time=39.4), 0.377481 s/step
# on time step 7891 (time=39.455), 0.379341 s/step
# on time step 7902 (time=39.51), 0.382705 s/step
# on time step 7913 (time=39.565), 0.382544 s/step
# on time step 7924 (time=39.62), 0.377676 s/step
# on time step 7935 (time=39.675), 0.381362 s/step
# on time step 7946 (time=39.73), 0.378912 s/step
# on time step 7957 (time=39.785), 0.380662 s/step
# on time step 7968 (time=39.84), 0.380199 s/step
# on time step 7979 (time=39.895), 0.37892 s/step
# on time step 7990 (time=39.95), 0.378859 s/step
# on time step 8001 (time=40.005), 0.3775 s/step
# on time step 8012 (time=40.06), 0.384592 s/step
# on time step 8023 (time=40.115), 0.388186 s/step
# on time step 8034 (time=40.17), 0.387959 s/step
# on time step 8045 (time=40.225), 0.387556 s/step
# on time step 8056 (time=40.28), 0.388758 s/step
# on time step 8071 (time=40.355), 0.270912 s/step
# on time step 8087 (time=40.435), 0.259396 s/step
# on time step 8109 (time=40.545), 0.189235 s/step
# on time step 8123 (time=40.615), 0.297242 s/step
# on time step 8135 (time=40.675), 0.33612 s/step
# on time step 8147 (time=40.735), 0.348921 s/step
# on time step 8160 (time=40.8), 0.332394 s/step
# on time step 8172 (time=40.86), 0.335532 s/step
# on time step 8184 (time=40.92), 0.337385 s/step
# on time step 8197 (time=40.985), 0.331207 s/step
# on time step 8210 (time=41.05), 0.33273 s/step
# on time step 8222 (time=41.11), 0.34602 s/step
# on time step 8234 (time=41.17), 0.334695 s/step
# on time step 8247 (time=41.235), 0.330077 s/step
# on time step 8259 (time=41.295), 0.339131 s/step
# on time step 8272 (time=41.36), 0.331064 s/step
# on time step 8284 (time=41.42), 0.343606 s/step
# on time step 8296 (time=41.48), 0.337351 s/step
# on time step 8309 (time=41.545), 0.328979 s/step
# on time step 8321 (time=41.605), 0.333583 s/step
# on time step 8333 (time=41.665), 0.333918 s/step
# on time step 8346 (time=41.73), 0.332661 s/step
# on time step 8358 (time=41.79), 0.33582 s/step
# on time step 8370 (time=41.85), 0.336051 s/step
# on time step 8382 (time=41.91), 0.337201 s/step
# on time step 8394 (time=41.97), 0.33563 s/step
# on time step 8406 (time=42.03), 0.347669 s/step
# on time step 8418 (time=42.09), 0.345411 s/step
# on time step 8430 (time=42.15), 0.343353 s/step
# on time step 8442 (time=42.21), 0.347954 s/step
# on time step 8453 (time=42.265), 0.370073 s/step
# on time step 8465 (time=42.325), 0.353934 s/step
# on time step 8477 (time=42.385), 0.339149 s/step
# on time step 8489 (time=42.445), 0.342351 s/step
# on time step 8501 (time=42.505), 0.340796 s/step
# on time step 8513 (time=42.565), 0.343585 s/step
# on time step 8525 (time=42.625), 0.343834 s/step
# on time step 8537 (time=42.685), 0.34535 s/step
# on time step 8549 (time=42.745), 0.341164 s/step
# on time step 8561 (time=42.805), 0.344545 s/step
# on time step 8573 (time=42.865), 0.342631 s/step
# on time step 8585 (time=42.925), 0.339804 s/step
# on time step 8597 (time=42.985), 0.345497 s/step
# on time step 8609 (time=43.045), 0.348252 s/step
# on time step 8621 (time=43.105), 0.346841 s/step
# on time step 8633 (time=43.165), 0.345753 s/step
# on time step 8645 (time=43.225), 0.344827 s/step
# on time step 8657 (time=43.285), 0.346486 s/step
# on time step 8669 (time=43.345), 0.345835 s/step
# on time step 8681 (time=43.405), 0.342072 s/step
# on time step 8693 (time=43.465), 0.344255 s/step
# on time step 8705 (time=43.525), 0.341109 s/step
# on time step 8717 (time=43.585), 0.344697 s/step
# on time step 8729 (time=43.645), 0.349669 s/step
# on time step 8741 (time=43.705), 0.341755 s/step
# on time step 8753 (time=43.765), 0.356338 s/step
# on time step 8765 (time=43.825), 0.341801 s/step
# on time step 8777 (time=43.885), 0.340126 s/step
# on time step 8789 (time=43.945), 0.341734 s/step
# on time step 8801 (time=44.005), 0.343596 s/step
# on time step 8813 (time=44.065), 0.363712 s/step
# on time step 8824 (time=44.12), 0.370642 s/step
# on time step 8834 (time=44.17), 0.435789 s/step
# on time step 8844 (time=44.22), 0.439744 s/step
# on time step 8853 (time=44.265), 0.450107 s/step
# on time step 8863 (time=44.315), 0.429444 s/step
# on time step 8873 (time=44.365), 0.431291 s/step
# on time step 8883 (time=44.415), 0.432222 s/step
# on time step 8892 (time=44.46), 0.46055 s/step
# on time step 8902 (time=44.51), 0.431293 s/step
# on time step 8912 (time=44.56), 0.428355 s/step
# on time step 8922 (time=44.61), 0.422886 s/step
# on time step 8932 (time=44.66), 0.436934 s/step
# on time step 8942 (time=44.71), 0.434028 s/step
# on time step 8952 (time=44.76), 0.423507 s/step
# on time step 8962 (time=44.81), 0.417577 s/step
# on time step 8972 (time=44.86), 0.425784 s/step
# on time step 8982 (time=44.91), 0.421369 s/step
# on time step 8992 (time=44.96), 0.433484 s/step
# on time step 9002 (time=45.01), 0.4419 s/step
# on time step 9011 (time=45.055), 0.444575 s/step
# on time step 9021 (time=45.105), 0.439419 s/step
# ...
# on time step 12423 (time=62.115), 0.588119 s/step
# on time step 12438 (time=62.19), 0.273913 s/step
# on time step 12452 (time=62.26), 0.297471 s/step
# on time step 12466 (time=62.33), 0.311462 s/step
# on time step 12475 (time=62.375), 0.461279 s/step
# on time step 12484 (time=62.42), 0.467066 s/step
# on time step 12493 (time=62.465), 0.466434 s/step
# on time step 12502 (time=62.51), 0.459185 s/step
# on time step 12511 (time=62.555), 0.467399 s/step
# on time step 12520 (time=62.6), 0.464997 s/step
# on time step 12529 (time=62.645), 0.476875 s/step
# on time step 12538 (time=62.69), 0.476981 s/step
# on time step 12547 (time=62.735), 0.476203 s/step
# on time step 12556 (time=62.78), 0.477266 s/step
# on time step 12565 (time=62.825), 0.482201 s/step
# on time step 12574 (time=62.87), 0.48008 s/step
# on time step 12583 (time=62.915), 0.477616 s/step
# on time step 12592 (time=62.96), 0.476264 s/step
# on time step 12601 (time=63.005), 0.481073 s/step
# on time step 12610 (time=63.05), 0.481647 s/step
# on time step 12619 (time=63.095), 0.47641 s/step
# on time step 12628 (time=63.14), 0.472961 s/step
# on time step 12637 (time=63.185), 0.476381 s/step
# on time step 12646 (time=63.23), 0.480184 s/step
# on time step 12655 (time=63.275), 0.481942 s/step
# on time step 12664 (time=63.32), 0.479037 s/step
# on time step 12673 (time=63.365), 0.481279 s/step
# on time step 12682 (time=63.41), 0.481372 s/step
# on time step 12691 (time=63.455), 0.477956 s/step
# on time step 12701 (time=63.505), 0.411102 s/step
# on time step 12713 (time=63.565), 0.362299 s/step
# on time step 12724 (time=63.62), 0.368849 s/step
# on time step 12735 (time=63.675), 0.36767 s/step
# on time step 12746 (time=63.73), 0.368507 s/step
# on time step 12757 (time=63.785), 0.377972 s/step
# on time step 12768 (time=63.84), 0.374069 s/step
# on time step 12779 (time=63.895), 0.371771 s/step
# on time step 12790 (time=63.95), 0.371354 s/step
# on time step 12801 (time=64.005), 0.367572 s/step
# on time step 12812 (time=64.06), 0.372638 s/step
# on time step 12823 (time=64.115), 0.368899 s/step
# on time step 12834 (time=64.17), 0.375135 s/step
# on time step 12845 (time=64.225), 0.374536 s/step
# on time step 12856 (time=64.28), 0.364161 s/step
# on time step 12867 (time=64.335), 0.370993 s/step
# on time step 12878 (time=64.39), 0.366236 s/step
# on time step 12889 (time=64.445), 0.364161 s/step
# on time step 12900 (time=64.5), 0.369985 s/step
# on time step 12911 (time=64.555), 0.364883 s/step
# on time step 12923 (time=64.615), 0.36175 s/step
# on time step 12935 (time=64.675), 0.360741 s/step
# on time step 12947 (time=64.735), 0.358478 s/step
# on time step 12958 (time=64.79), 0.36612 s/step
# on time step 12969 (time=64.845), 0.369672 s/step
# on time step 12981 (time=64.905), 0.362615 s/step
# on time step 12992 (time=64.96), 0.372784 s/step
# on time step 13003 (time=65.015), 0.377753 s/step
# on time step 13015 (time=65.075), 0.359237 s/step
# on time step 13027 (time=65.135), 0.36126 s/step
# on time step 13038 (time=65.19), 0.36794 s/step
# on time step 13049 (time=65.245), 0.364494 s/step
# on time step 13060 (time=65.3), 0.363663 s/step
# on time step 13071 (time=65.355), 0.378279 s/step
# on time step 13082 (time=65.41), 0.386347 s/step
# on time step 13093 (time=65.465), 0.36726 s/step
# on time step 13104 (time=65.52), 0.366127 s/step
# on time step 13115 (time=65.575), 0.378142 s/step
# on time step 13127 (time=65.635), 0.361748 s/step
# on time step 13138 (time=65.69), 0.379272 s/step
# on time step 13150 (time=65.75), 0.343918 s/step
# on time step 13160 (time=65.8), 0.408905 s/step
# on time step 13168 (time=65.84), 0.502466 s/step
# on time step 13177 (time=65.885), 0.489871 s/step
# on time step 13185 (time=65.925), 0.506015 s/step
# on time step 13194 (time=65.97), 0.495331 s/step
# on time step 13203 (time=66.015), 0.487856 s/step
# on time step 13211 (time=66.055), 0.506905 s/step
# on time step 13219 (time=66.095), 0.507934 s/step
# on time step 13227 (time=66.135), 0.500528 s/step
# on time step 13243 (time=66.215), 0.268037 s/step
# on time step 13251 (time=66.255), 0.564222 s/step
# on time step 13259 (time=66.295), 0.566897 s/step
# on time step 13267 (time=66.335), 0.570055 s/step
# on time step 13275 (time=66.375), 0.566627 s/step
# on time step 13283 (time=66.415), 0.569783 s/step
# on time step 13291 (time=66.455), 0.569899 s/step
# on time step 13299 (time=66.495), 0.568268 s/step
# on time step 13306 (time=66.53), 0.571622 s/step
# on time step 13313 (time=66.565), 0.571628 s/step
# on time step 13321 (time=66.605), 0.567552 s/step
# on time step 13328 (time=66.64), 0.573759 s/step
# on time step 13336 (time=66.68), 0.557959 s/step
# on time step 13343 (time=66.715), 0.573101 s/step
# on time step 13351 (time=66.755), 0.563946 s/step
# on time step 13359 (time=66.795), 0.56914 s/step
# on time step 13367 (time=66.835), 0.563712 s/step
# on time step 13375 (time=66.875), 0.565565 s/step
# on time step 13383 (time=66.915), 0.569194 s/step
# on time step 13390 (time=66.95), 0.571791 s/step
# on time step 13398 (time=66.99), 0.566859 s/step
# on time step 13406 (time=67.03), 0.56578 s/step
# on time step 13413 (time=67.065), 0.576628 s/step
# on time step 13421 (time=67.105), 0.567888 s/step
# on time step 13428 (time=67.14), 0.581781 s/step
# on time step 13436 (time=67.18), 0.57113 s/step
# on time step 13444 (time=67.22), 0.565695 s/step
# on time step 13452 (time=67.26), 0.556276 s/step
# on time step 13460 (time=67.3), 0.561102 s/step
# on time step 13468 (time=67.34), 0.5676 s/step
# on time step 13476 (time=67.38), 0.510862 s/step
# on time step 13484 (time=67.42), 0.502499 s/step
# on time step 13492 (time=67.46), 0.505464 s/step
# on time step 13500 (time=67.5), 0.50032 s/step
# on time step 13508 (time=67.54), 0.505286 s/step
# on time step 13516 (time=67.58), 0.507202 s/step
# on time step 13524 (time=67.62), 0.50285 s/step
# on time step 13532 (time=67.66), 0.502238 s/step
# on time step 13540 (time=67.7), 0.501466 s/step
# on time step 13548 (time=67.74), 0.501806 s/step
# on time step 13556 (time=67.78), 0.501439 s/step
# on time step 13564 (time=67.82), 0.507844 s/step
# on time step 13572 (time=67.86), 0.502011 s/step
# on time step 13580 (time=67.9), 0.500312 s/step
# on time step 13588 (time=67.94), 0.503775 s/step
# on time step 13596 (time=67.98), 0.508323 s/step
# on time step 13604 (time=68.02), 0.507836 s/step
# on time step 13612 (time=68.06), 0.510761 s/step
# on time step 13620 (time=68.1), 0.503885 s/step
# on time step 13628 (time=68.14), 0.503168 s/step
# on time step 13636 (time=68.18), 0.508118 s/step
# on time step 13644 (time=68.22), 0.50999 s/step
# on time step 13652 (time=68.26), 0.509299 s/step
# on time step 13660 (time=68.3), 0.508541 s/step
# on time step 13668 (time=68.34), 0.508206 s/step
# on time step 13676 (time=68.38), 0.504787 s/step
# on time step 13684 (time=68.42), 0.513344 s/step
# on time step 13692 (time=68.46), 0.507148 s/step
# on time step 13700 (time=68.5), 0.512032 s/step
# on time step 13708 (time=68.54), 0.511402 s/step
# on time step 13716 (time=68.58), 0.509067 s/step
# on time step 13724 (time=68.62), 0.514054 s/step
# on time step 13732 (time=68.66), 0.506824 s/step
# on time step 13740 (time=68.7), 0.515657 s/step
# on time step 13748 (time=68.74), 0.506007 s/step
# on time step 13756 (time=68.78), 0.509989 s/step
# on time step 13767 (time=68.835), 0.365522 s/step
# on time step 13777 (time=68.885), 0.403896 s/step
# on time step 13788 (time=68.94), 0.385812 s/step
# on time step 13799 (time=68.995), 0.388926 s/step
# on time step 13810 (time=69.05), 0.386949 s/step
# on time step 13821 (time=69.105), 0.387323 s/step
# on time step 13832 (time=69.16), 0.385015 s/step
# on time step 13843 (time=69.215), 0.381912 s/step
# on time step 13854 (time=69.27), 0.377066 s/step
# on time step 13865 (time=69.325), 0.379749 s/step
# on time step 13876 (time=69.38), 0.379723 s/step
# on time step 13887 (time=69.435), 0.38353 s/step
# on time step 13898 (time=69.49), 0.381992 s/step
# on time step 13909 (time=69.545), 0.381457 s/step
# on time step 13920 (time=69.6), 0.384122 s/step
# on time step 13931 (time=69.655), 0.382495 s/step
# on time step 13942 (time=69.71), 0.382624 s/step
# on time step 13953 (time=69.765), 0.384047 s/step
# on time step 13964 (time=69.82), 0.387017 s/step
# on time step 13975 (time=69.875), 0.381079 s/step
# on time step 13986 (time=69.93), 0.380415 s/step
# on time step 13997 (time=69.985), 0.380381 s/step
# on time step 14008 (time=70.04), 0.389365 s/step
# on time step 14019 (time=70.095), 0.382115 s/step
# on time step 14030 (time=70.15), 0.39361 s/step
# on time step 14041 (time=70.205), 0.383297 s/step
# on time step 14052 (time=70.26), 0.385176 s/step
# on time step 14063 (time=70.315), 0.380486 s/step
# on time step 14074 (time=70.37), 0.381334 s/step
# on time step 14085 (time=70.425), 0.382529 s/step
# on time step 14096 (time=70.48), 0.383076 s/step
# on time step 14107 (time=70.535), 0.393759 s/step
# on time step 14118 (time=70.59), 0.383976 s/step
# on time step 14129 (time=70.645), 0.38783 s/step
# on time step 14140 (time=70.7), 0.384857 s/step
# on time step 14151 (time=70.755), 0.381907 s/step
# on time step 14162 (time=70.81), 0.38804 s/step
# on time step 14173 (time=70.865), 0.391787 s/step
# on time step 14184 (time=70.92), 0.385985 s/step
# on time step 14195 (time=70.975), 0.38341 s/step
# on time step 14206 (time=71.03), 0.383392 s/step
# on time step 14217 (time=71.085), 0.384676 s/step
# on time step 14228 (time=71.14), 0.386184 s/step
# on time step 14239 (time=71.195), 0.377784 s/step
# on time step 14252 (time=71.26), 0.307905 s/step
# on time step 14261 (time=71.305), 0.485019 s/step
# on time step 14270 (time=71.35), 0.465625 s/step
# on time step 14279 (time=71.395), 0.463846 s/step
# on time step 14288 (time=71.44), 0.46495 s/step
# on time step 14298 (time=71.49), 0.434404 s/step
# on time step 14308 (time=71.54), 0.439714 s/step
# on time step 14317 (time=71.585), 0.449455 s/step
# on time step 14326 (time=71.63), 0.445281 s/step
# on time step 14336 (time=71.68), 0.437981 s/step
# on time step 14346 (time=71.73), 0.440863 s/step
# on time step 14356 (time=71.78), 0.441254 s/step
# on time step 14366 (time=71.83), 0.436357 s/step
# on time step 14375 (time=71.875), 0.459337 s/step
# on time step 14384 (time=71.92), 0.493084 s/step
# on time step 14393 (time=71.965), 0.487967 s/step
# on time step 14402 (time=72.01), 0.477314 s/step
# on time step 14411 (time=72.055), 0.47991 s/step
# on time step 14420 (time=72.1), 0.490388 s/step
# on time step 14429 (time=72.145), 0.481047 s/step
# on time step 14438 (time=72.19), 0.485974 s/step
# on time step 14447 (time=72.235), 0.490863 s/step
# on time step 14456 (time=72.28), 0.498153 s/step
# on time step 14465 (time=72.325), 0.497797 s/step
# on time step 14473 (time=72.365), 0.502814 s/step
# on time step 14481 (time=72.405), 0.51368 s/step
# on time step 14489 (time=72.445), 0.501432 s/step
# on time step 14497 (time=72.485), 0.506528 s/step
# on time step 14505 (time=72.525), 0.500052 s/step
# on time step 14514 (time=72.57), 0.502289 s/step
# on time step 14522 (time=72.61), 0.500168 s/step
# on time step 14531 (time=72.655), 0.496952 s/step
# on time step 14540 (time=72.7), 0.496785 s/step
# on time step 14549 (time=72.745), 0.495358 s/step
# on time step 14558 (time=72.79), 0.468664 s/step
# on time step 14575 (time=72.875), 0.23894 s/step
# on time step 14591 (time=72.955), 0.251015 s/step
# on time step 14604 (time=73.02), 0.312595 s/step
# on time step 14613 (time=73.065), 0.4449 s/step
# on time step 14622 (time=73.11), 0.447789 s/step
# on time step 14631 (time=73.155), 0.464041 s/step
# on time step 14640 (time=73.2), 0.454526 s/step
# on time step 14649 (time=73.245), 0.461486 s/step
# on time step 14658 (time=73.29), 0.462753 s/step
# on time step 14667 (time=73.335), 0.461454 s/step
# on time step 14676 (time=73.38), 0.460884 s/step
# on time step 14685 (time=73.425), 0.468023 s/step
# on time step 14694 (time=73.47), 0.461659 s/step
# on time step 14703 (time=73.515), 0.461354 s/step
# on time step 14712 (time=73.56), 0.467689 s/step
# on time step 14721 (time=73.605), 0.465597 s/step
# on time step 14730 (time=73.65), 0.469778 s/step
# on time step 14739 (time=73.695), 0.463813 s/step
# on time step 14748 (time=73.74), 0.470157 s/step
# on time step 14757 (time=73.785), 0.459627 s/step
# on time step 14766 (time=73.83), 0.462386 s/step
# on time step 14775 (time=73.875), 0.465094 s/step
# on time step 14784 (time=73.92), 0.461564 s/step
# on time step 14793 (time=73.965), 0.461204 s/step
# on time step 14802 (time=74.01), 0.464958 s/step
# on time step 14811 (time=74.055), 0.461856 s/step
# on time step 14820 (time=74.1), 0.46148 s/step
# on time step 14829 (time=74.145), 0.463226 s/step
# on time step 14838 (time=74.19), 0.464113 s/step
# on time step 14847 (time=74.235), 0.465034 s/step
# on time step 14856 (time=74.28), 0.492083 s/step
# on time step 14865 (time=74.325), 0.486664 s/step
# on time step 14874 (time=74.37), 0.486965 s/step
# on time step 14883 (time=74.415), 0.485511 s/step
# on time step 14892 (time=74.46), 0.490133 s/step
# on time step 14901 (time=74.505), 0.485056 s/step
# on time step 14910 (time=74.55), 0.487939 s/step
# on time step 14919 (time=74.595), 0.485924 s/step
# on time step 14928 (time=74.64), 0.488981 s/step
# on time step 14937 (time=74.685), 0.487626 s/step
# on time step 14946 (time=74.73), 0.490554 s/step
# on time step 14955 (time=74.775), 0.48702 s/step
# on time step 14964 (time=74.82), 0.489437 s/step
# on time step 14979 (time=74.895), 0.267284 s/step
# on time step 14987 (time=74.935), 0.508769 s/step
# on time step 14996 (time=74.98), 0.497438 s/step
# on time step 15004 (time=75.02), 0.508698 s/step
# on time step 15012 (time=75.06), 0.519212 s/step
# on time step 15020 (time=75.1), 0.523289 s/step
# on time step 15028 (time=75.14), 0.520267 s/step
# on time step 15037 (time=75.185), 0.488653 s/step
# on time step 15046 (time=75.23), 0.477096 s/step
# on time step 15055 (time=75.275), 0.482292 s/step
# on time step 15064 (time=75.32), 0.483652 s/step
# on time step 15073 (time=75.365), 0.488409 s/step
# on time step 15082 (time=75.41), 0.486339 s/step
# on time step 15091 (time=75.455), 0.483008 s/step
# on time step 15100 (time=75.5), 0.480639 s/step
# on time step 15109 (time=75.545), 0.478072 s/step
# on time step 15118 (time=75.59), 0.47818 s/step
# on time step 15127 (time=75.635), 0.484101 s/step
# on time step 15136 (time=75.68), 0.482345 s/step
# on time step 15145 (time=75.725), 0.476899 s/step
# on time step 15154 (time=75.77), 0.475823 s/step
# on time step 15163 (time=75.815), 0.486017 s/step
# on time step 15172 (time=75.86), 0.483051 s/step
# on time step 15181 (time=75.905), 0.48366 s/step
# on time step 15190 (time=75.95), 0.486349 s/step
# on time step 15199 (time=75.995), 0.485711 s/step
# on time step 15208 (time=76.04), 0.490615 s/step
# on time step 15217 (time=76.085), 0.48705 s/step
# on time step 15226 (time=76.13), 0.483871 s/step
# on time step 15234 (time=76.17), 0.571754 s/step
# on time step 15244 (time=76.22), 0.442701 s/step
# on time step 15254 (time=76.27), 0.42702 s/step
# on time step 15264 (time=76.32), 0.40933 s/step
# on time step 15274 (time=76.37), 0.401397 s/step
# on time step 15284 (time=76.42), 0.410117 s/step
# on time step 15294 (time=76.47), 0.425678 s/step
# on time step 15304 (time=76.52), 0.430447 s/step
# on time step 15318 (time=76.59), 0.307206 s/step
# on time step 15330 (time=76.65), 0.363602 s/step
# on time step 15342 (time=76.71), 0.362348 s/step
# on time step 15354 (time=76.77), 0.361429 s/step
# on time step 15365 (time=76.825), 0.364461 s/step
# on time step 15376 (time=76.88), 0.405399 s/step
# on time step 15385 (time=76.925), 0.487674 s/step
# on time step 15394 (time=76.97), 0.487304 s/step
# on time step 15403 (time=77.015), 0.489932 s/step
# on time step 15412 (time=77.06), 0.491226 s/step
# on time step 15421 (time=77.105), 0.487995 s/step
# on time step 15430 (time=77.15), 0.48722 s/step
# on time step 15439 (time=77.195), 0.454108 s/step
# on time step 15448 (time=77.24), 0.450949 s/step
# on time step 15457 (time=77.285), 0.453857 s/step
# on time step 15466 (time=77.33), 0.450184 s/step
# on time step 15475 (time=77.375), 0.451344 s/step
# on time step 15484 (time=77.42), 0.450316 s/step
# on time step 15493 (time=77.465), 0.457532 s/step
# run 0 finished at t = 77.5 (15500 timesteps)

# %%
evaluation_history = np.load('Post_evaluation_history.npy')
Ex= np.load('DFT_FOM_TEST/Dft_test_Ex.npy')
Ey= np.load('DFT_FOM_TEST/Dft_test_Ey.npy')
Ez= np.load('DFT_FOM_TEST/Dft_test_Ez.npy')

# %%
plt.figure()
plt.plot(evaluation_history, "o-")
print("FOM_FINAL =",evaluation_history[-1])
for i in range(1,13):
    plt.axvline(x=12*i, color='purple', linestyle='--', label='x=3')
plt.grid(True)
plt.xlim(0)
plt.ylim(0)
plt.xlabel("Iteration")
plt.ylabel("FOM")
# Out:
# FOM_FINAL = 363.52107947524075
# Text(0, 0.5, 'FOM')

# %%
ET_x = 0
ET_y = 0
ET_z = 0
ET_x_length = Ex.shape[0]
ET_y_length = Ey.shape[0]
ET_z_length = Ez.shape[0]
for k in range(0,ET_x_length):
    ET_x = ET_x + npa.abs(Ex[k]) ** 2
for k in range(0,ET_y_length):
    ET_y = ET_y + npa.abs(Ey[k]) ** 2
for k in range(0,ET_z_length):
    ET_z = ET_z + npa.abs(Ez[k]) ** 2
ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2) 
print(ET)
# Out:
# 363.52107947524047
