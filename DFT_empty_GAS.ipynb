# %%
import meep as mp
import meep.adjoint as mpa
from meep import Animate2D
import numpy as np
from autograd import numpy as npa
from autograd import tensor_jacobian_product, grad
import nlopt
from matplotlib import pyplot as plt
from matplotlib.patches import Circle
from meep.materials import Ag
import os
import matplotlib.pyplot as plt
import matplotlib.animation as animation
from PIL import Image
import matplotlib.colors as mcolors

mp.verbosity(1)
TiO2 = mp.Medium(index=2.6)
SiO2 = mp.Medium(index=1.44)
Si = mp.Medium(index=3.4)
Air = mp.Medium(index=1)

# %%
os.makedirs('DFT_empty_GAS',exist_ok=True) # Create Folder

# %%
resolution = 100
design_region_resolution = int(resolution)

design_region_x_width  = 1   #100 nm
design_region_y_height = 1   #100 nm
design_region_z_height = 0.02  #20 nm or 10nm

pml_size = 1.0
pml_layers = [mp.PML(pml_size,direction=mp.Z)]

Sz_size = 0.6
Sx = design_region_x_width
Sy = design_region_y_height 
Sz = 2 * pml_size + design_region_z_height + Sz_size
cell_size = mp.Vector3(Sx, Sy, Sz)

wavelengths = np.array([1.55])     # wavelengths = np.array([1.5 ,1.55, 1.6])
frequencies = np.array([1 / 1.55])

nf = 1                 #3 #wavelengths Number

minimum_length = 0.02  # minimum length scale (microns)
eta_i = 0.5            # blueprint (or intermediate) design field thresholding point (between 0 and 1)
eta_e = 0.55           # erosion design field thresholding point (between 0 and 1)
eta_d = 1 - eta_e      # dilation design field thresholding point (between 0 and 1)
filter_radius = mpa.get_conic_radius_from_eta_e(minimum_length, eta_e)

Source_distance = -0.2

fcen   = 1 / 1.55
width  = 0.2  
fwidth = width * fcen
source_center = mp.Vector3(0,0,Source_distance)  
source_size   = mp.Vector3(design_region_x_width, design_region_y_height, 0)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)]   

Nx = int(design_region_resolution * design_region_x_width) + 1
Ny = int(design_region_resolution * design_region_y_height) + 1
Nz = 1

design_variables = mp.MaterialGrid(mp.Vector3(Nx, Ny, Nz), Air, Ag, grid_type="U_MEAN")
design_region    = mpa.DesignRegion(
            design_variables,
            volume=mp.Volume(
            center=mp.Vector3(0,0,0),
            size=mp.Vector3(design_region_x_width, design_region_y_height, design_region_z_height),
            ),
)

def mapping(x, eta, beta):
    # filter
    filtered_field = mpa.conic_filter(
        x,
        filter_radius,
        design_region_x_width,
        design_region_y_height,
        design_region_resolution,
    )
    # projection
    projected_field = mpa.tanh_projection(filtered_field, beta, eta)
    projected_field = (npa.fliplr(projected_field) + projected_field) / 2
    projected_field = (npa.flipud(projected_field) + projected_field) / 2  # left-right symmetry    
    
    return projected_field.flatten()


geometry = [mp.Block(center=design_region.center, size=design_region.size, material=design_variables)]

kpoint = mp.Vector3()
sim = mp.Simulation(
    cell_size        = cell_size,
    boundary_layers  = pml_layers,
    geometry         = geometry,
    sources          = source,
    default_material = Air,
    k_point          = kpoint,
    symmetries       = [mp.Mirror(direction=mp.X)],
    resolution       = resolution,
    extra_materials  = [Ag],       # Introducing metal complex terms
)
#---------------------------------------------------------------------------------------------------#


#-----------------[4]---------------------------------#
monitor_position   = mp.Vector3(0, 0, 0)       # Focus position
monitor_size       = mp.Vector3(0.01,0.01,design_region_z_height)     # Focus Size//////0.11
FourierFields_x    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ex,yee_grid=True)
FourierFields_y    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ey,yee_grid=True)
FourierFields_z    = mpa.FourierFields(sim,mp.Volume(center=monitor_position,size=monitor_size),mp.Ez,yee_grid=True)
ob_list            = [FourierFields_x,FourierFields_y,FourierFields_z]


def J(fields_x,fields_y,fields_z):
    ET_x = 0
    ET_y = 0
    ET_z = 0
    ET_x_length = fields_x.shape[1]
    ET_y_length = fields_y.shape[1]
    ET_z_length = fields_z.shape[1]
    for k in range(0,ET_x_length):
        ET_x = ET_x + npa.abs(fields_x[:,k]) ** 2
    for k in range(0,ET_y_length):
        ET_y = ET_y + npa.abs(fields_y[:,k]) ** 2
    for k in range(0,ET_z_length):
        ET_z = ET_z + npa.abs(fields_z[:,k]) ** 2
    ET = ( (npa.mean(ET_x)) + (npa.mean(ET_y)) + (npa.mean(ET_z)) ) ** (1/2)  
    return ET


opt = mpa.OptimizationProblem(
    simulation=sim,
    objective_functions=[J],
    objective_arguments=ob_list,
    design_regions=[design_region],
    frequencies=frequencies,
    decimation_factor = 1 ,           # KEY BUG!!
    maximum_run_time=50,
)

# %%
evaluation_history = np.load('Post_evaluation_history.npy')
beta_A  = np.load("Post_beta_scale_array.npy")
eta_A   = np.load("Post_eta_i_array.npy")
cur_A   = np.load("Post_cur_beta_array.npy")
x_A     = np.load("Post_x_array.npy")

# %%
plt.figure()
plt.plot(evaluation_history, "o-")

for i in range(1,13):
    plt.axvline(x=15*i, color='purple', linestyle='--', label='x=3')
plt.grid(True)
plt.xlim(0)
plt.ylim(0)
plt.xlabel("Iteration")
plt.ylabel("FOM")
# Out:
# Text(0, 0.5, 'FOM')

# %%
opt.update_design([mapping(x_A, eta_A, cur_A/beta_A)])  # cur_beta/beta_scale is the final beta in the optimization.
plt.figure(figsize=(5,5))
ax = plt.gca()
opt.plot2D(
    False,
    ax=ax,
    plot_sources_flag=False,
    plot_monitors_flag=False,
    plot_boundaries_flag=False,
    output_plane = mp.Volume(center=mp.Vector3(0,0,0), size=mp.Vector3(design_region_x_width, design_region_y_height, 0))
)
circ = Circle((2, 2), minimum_length / 2)
ax.add_patch(circ)
ax.axis("off")
plt.show()
plt.close()
# Out:
#      block, center = (0,0,0)
#           size (1,1,0.02)
#           axes (1,0,0), (0,1,0), (0,0,1)

# %%
opt.sim = mp.Simulation(
    cell_size=mp.Vector3(Sx, Sy ,Sz),
    boundary_layers=pml_layers,
    geometry=[], ##_empty
    sources=source,
    default_material=Air,
    resolution=resolution,
    k_point=kpoint,
    #symmetries=[mp.Mirror(direction=mp.X)],
    extra_materials = [Ag],
)
#src = mp.ContinuousSource(frequency=frequencies[0], fwidth=0.01 ,is_integrated=True)
src    = mp.GaussianSource(frequency=fcen, fwidth=fwidth, is_integrated=True)
source = [mp.Source(src, component=mp.Ey, size=source_size, center=source_center)] 
opt.sim.change_sources(source)

dft_fields_xz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(Sx,0,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_yz = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(),
                                size=mp.Vector3(0,Sy,Sz-2 * pml_size),
                                yee_grid=False
                                )

dft_fields_xyz12 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False
                                )

dft_fields_xyz00 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0),
                                size=mp.Vector3(Sx,Sy,0),
                                yee_grid=False 
                                )

dft_fields_x0yz0 = opt.sim.add_dft_fields([mp.Ex,mp.Ey,mp.Ez],
                                fcen,0,1,
                                center=mp.Vector3(0,0,0.01),
                                size=mp.Vector3(0,Sy,0),
                                yee_grid=False
                                )


#opt.sim.run(until_after_sources = 0) 
opt.sim.run(until_after_sources=mp.stop_when_dft_decayed(
            tol=1e-11,
            minimum_run_time=0,
            maximum_run_time=50)
# Out:
# -----------
# Initializing structure...
# time for choose_chunkdivision = 0.000145912 s
# Working in 3D dimensions.
# Computational cell is 1 x 1 x 2.62 with resolution 100
# time for set_epsilon = 2.80045 s
# lorentzian susceptibility: frequency=16.365, gamma=1.95106
# lorentzian susceptibility: frequency=7.32593, gamma=0.738804
# lorentzian susceptibility: frequency=6.60165, gamma=0.052426
# lorentzian susceptibility: frequency=3.61417, gamma=0.364563
# lorentzian susceptibility: frequency=0.658148, gamma=3.13427
# drude susceptibility: frequency=1e-10, gamma=0.0387146
# -----------
# FloatProgress(value=0.0, description='0% done ', max=77.5)
# Meep progress: 0.025/77.5 = 0.0% done in 4.2s, 13110.6s to go
# on time step 5 (time=0.025), 0.844784 s/step
# Meep progress: 0.105/77.5 = 0.1% done in 8.2s, 6067.7s to go
# on time step 22 (time=0.11), 0.249973 s/step
# Meep progress: 0.185/77.5 = 0.2% done in 12.3s, 5154.0s to go
# on time step 38 (time=0.19), 0.256642 s/step
# Meep progress: 0.265/77.5 = 0.3% done in 16.4s, 4791.0s to go
# on time step 54 (time=0.27), 0.256644 s/step
# Meep progress: 0.34500000000000003/77.5 = 0.4% done in 20.5s, 4592.4s to go
# on time step 70 (time=0.35), 0.255933 s/step
# Meep progress: 0.42/77.5 = 0.5% done in 24.5s, 4503.6s to go
# on time step 86 (time=0.43), 0.266675 s/step
# Meep progress: 0.5/77.5 = 0.6% done in 28.7s, 4421.6s to go
# on time step 102 (time=0.51), 0.258863 s/step
# Meep progress: 0.585/77.5 = 0.8% done in 32.9s, 4326.4s to go
# on time step 119 (time=0.595), 0.246908 s/step
# Meep progress: 0.67/77.5 = 0.9% done in 37.1s, 4255.1s to go
# on time step 136 (time=0.68), 0.250481 s/step
# Meep progress: 0.735/77.5 = 0.9% done in 41.3s, 4313.0s to go
# on time step 149 (time=0.745), 0.328982 s/step
# Meep progress: 0.8/77.5 = 1.0% done in 45.6s, 4373.6s to go
# on time step 161 (time=0.805), 0.334147 s/step
# Meep progress: 0.86/77.5 = 1.1% done in 49.7s, 4427.9s to go
# on time step 173 (time=0.865), 0.338853 s/step
# Meep progress: 0.92/77.5 = 1.2% done in 53.8s, 4481.4s to go
# on time step 185 (time=0.925), 0.345607 s/step
# Meep progress: 0.98/77.5 = 1.3% done in 57.9s, 4524.1s to go
# on time step 197 (time=0.985), 0.340998 s/step
# Meep progress: 1.04/77.5 = 1.3% done in 62.0s, 4558.2s to go
# on time step 209 (time=1.045), 0.337793 s/step
# Meep progress: 1.1/77.5 = 1.4% done in 66.0s, 4584.9s to go
# on time step 221 (time=1.105), 0.334615 s/step
# Meep progress: 1.16/77.5 = 1.5% done in 70.0s, 4609.6s to go
# on time step 233 (time=1.165), 0.335844 s/step
# Meep progress: 1.22/77.5 = 1.6% done in 74.1s, 4630.3s to go
# on time step 245 (time=1.225), 0.334615 s/step
# Meep progress: 1.28/77.5 = 1.7% done in 78.1s, 4650.3s to go
# on time step 257 (time=1.285), 0.336709 s/step
# Meep progress: 1.34/77.5 = 1.7% done in 82.2s, 4669.2s to go
# on time step 269 (time=1.345), 0.337504 s/step
# Meep progress: 1.4000000000000001/77.5 = 1.8% done in 86.2s, 4686.4s to go
# on time step 281 (time=1.405), 0.337806 s/step
# Meep progress: 1.46/77.5 = 1.9% done in 90.3s, 4703.6s to go
# on time step 293 (time=1.465), 0.341136 s/step
# Meep progress: 1.52/77.5 = 2.0% done in 94.4s, 4716.3s to go
# on time step 305 (time=1.525), 0.336799 s/step
# Meep progress: 1.58/77.5 = 2.0% done in 98.4s, 4727.8s to go
# on time step 317 (time=1.585), 0.336969 s/step
# Meep progress: 1.6400000000000001/77.5 = 2.1% done in 102.5s, 4739.6s to go
# on time step 329 (time=1.645), 0.339279 s/step
# Meep progress: 1.7/77.5 = 2.2% done in 106.6s, 4752.7s to go
# on time step 341 (time=1.705), 0.343537 s/step
# Meep progress: 1.76/77.5 = 2.3% done in 110.7s, 4761.7s to go
# on time step 353 (time=1.765), 0.338485 s/step
# Meep progress: 1.82/77.5 = 2.3% done in 114.7s, 4768.6s to go
# on time step 365 (time=1.825), 0.334976 s/step
# Meep progress: 1.885/77.5 = 2.4% done in 119.0s, 4773.9s to go
# on time step 378 (time=1.89), 0.331994 s/step
# Meep progress: 1.945/77.5 = 2.5% done in 123.1s, 4780.2s to go
# on time step 390 (time=1.95), 0.338093 s/step
# Meep progress: 2.005/77.5 = 2.6% done in 127.1s, 4785.8s to go
# on time step 402 (time=2.01), 0.336723 s/step
# Meep progress: 2.065/77.5 = 2.7% done in 131.1s, 4789.5s to go
# on time step 414 (time=2.07), 0.334652 s/step
# Meep progress: 2.125/77.5 = 2.7% done in 135.2s, 4794.1s to go
# on time step 426 (time=2.13), 0.338362 s/step
# Meep progress: 2.185/77.5 = 2.8% done in 139.2s, 4798.3s to go
# on time step 438 (time=2.19), 0.334771 s/step
# Meep progress: 2.245/77.5 = 2.9% done in 143.2s, 4801.0s to go
# on time step 450 (time=2.25), 0.334804 s/step
# Meep progress: 2.305/77.5 = 3.0% done in 147.3s, 4804.3s to go
# on time step 462 (time=2.31), 0.337121 s/step
# Meep progress: 2.365/77.5 = 3.1% done in 151.3s, 4807.4s to go
# on time step 474 (time=2.37), 0.33797 s/step
# Meep progress: 2.4250000000000003/77.5 = 3.1% done in 155.4s, 4809.9s to go
# on time step 486 (time=2.43), 0.336585 s/step
# Meep progress: 2.485/77.5 = 3.2% done in 159.4s, 4813.1s to go
# on time step 498 (time=2.49), 0.33845 s/step
# Meep progress: 2.545/77.5 = 3.3% done in 163.5s, 4815.6s to go
# on time step 510 (time=2.55), 0.339674 s/step
# Meep progress: 2.605/77.5 = 3.4% done in 167.6s, 4817.3s to go
# on time step 522 (time=2.61), 0.337239 s/step
# Meep progress: 2.665/77.5 = 3.4% done in 171.6s, 4818.3s to go
# on time step 534 (time=2.67), 0.335497 s/step
# Meep progress: 2.725/77.5 = 3.5% done in 175.7s, 4820.0s to go
# on time step 546 (time=2.73), 0.338476 s/step
# Meep progress: 2.785/77.5 = 3.6% done in 179.7s, 4820.8s to go
# on time step 558 (time=2.79), 0.337198 s/step
# Meep progress: 2.845/77.5 = 3.7% done in 183.8s, 4821.8s to go
# on time step 570 (time=2.85), 0.338151 s/step
# Meep progress: 2.9050000000000002/77.5 = 3.7% done in 187.8s, 4822.6s to go
# on time step 582 (time=2.91), 0.339219 s/step
# Meep progress: 2.965/77.5 = 3.8% done in 191.9s, 4823.9s to go
# on time step 594 (time=2.97), 0.33869 s/step
# Meep progress: 3.025/77.5 = 3.9% done in 196.0s, 4824.4s to go
# on time step 606 (time=3.03), 0.337835 s/step
# Meep progress: 3.085/77.5 = 4.0% done in 200.0s, 4824.5s to go
# on time step 618 (time=3.09), 0.338106 s/step
# Meep progress: 3.145/77.5 = 4.1% done in 204.0s, 4824.2s to go
# on time step 630 (time=3.15), 0.33665 s/step
# Meep progress: 3.205/77.5 = 4.1% done in 208.1s, 4824.1s to go
# on time step 642 (time=3.21), 0.338398 s/step
# Meep progress: 3.265/77.5 = 4.2% done in 212.3s, 4826.7s to go
# on time step 654 (time=3.27), 0.346814 s/step
# Meep progress: 3.325/77.5 = 4.3% done in 216.3s, 4826.2s to go
# on time step 666 (time=3.33), 0.337933 s/step
# Meep progress: 3.3850000000000002/77.5 = 4.4% done in 220.4s, 4825.7s to go
# on time step 678 (time=3.39), 0.338964 s/step
# Meep progress: 3.4450000000000003/77.5 = 4.4% done in 224.5s, 4825.5s to go
# on time step 690 (time=3.45), 0.340877 s/step
# Meep progress: 3.505/77.5 = 4.5% done in 228.6s, 4825.4s to go
# on time step 702 (time=3.51), 0.338766 s/step
# Meep progress: 3.58/77.5 = 4.6% done in 232.8s, 4805.9s to go
# on time step 717 (time=3.585), 0.271004 s/step
# Meep progress: 3.67/77.5 = 4.7% done in 236.9s, 4765.0s to go
# on time step 735 (time=3.675), 0.227001 s/step
# Meep progress: 3.775/77.5 = 4.9% done in 241.1s, 4708.5s to go
# on time step 755 (time=3.775), 0.20172 s/step
# Meep progress: 3.86/77.5 = 5.0% done in 245.2s, 4677.7s to go
# on time step 772 (time=3.86), 0.240724 s/step
# Meep progress: 3.94/77.5 = 5.1% done in 249.4s, 4656.2s to go
# on time step 788 (time=3.94), 0.262793 s/step
# Meep progress: 4.05/77.5 = 5.2% done in 253.5s, 4596.5s to go
# on time step 810 (time=4.05), 0.184302 s/step
# Meep progress: 4.1450000000000005/77.5 = 5.3% done in 257.5s, 4556.8s to go
# on time step 829 (time=4.145), 0.212408 s/step
# Meep progress: 4.235/77.5 = 5.5% done in 261.5s, 4524.1s to go
# on time step 847 (time=4.235), 0.223415 s/step
# Meep progress: 4.325/77.5 = 5.6% done in 265.6s, 4493.0s to go
# on time step 865 (time=4.325), 0.22476 s/step
# Meep progress: 4.415/77.5 = 5.7% done in 269.6s, 4462.9s to go
# on time step 883 (time=4.415), 0.224432 s/step
# Meep progress: 4.505/77.5 = 5.8% done in 273.7s, 4435.1s to go
# on time step 901 (time=4.505), 0.228735 s/step
# Meep progress: 4.59/77.5 = 5.9% done in 277.7s, 4411.6s to go
# on time step 918 (time=4.59), 0.235776 s/step
# Meep progress: 4.675/77.5 = 6.0% done in 281.8s, 4389.7s to go
# on time step 935 (time=4.675), 0.239156 s/step
# Meep progress: 4.76/77.5 = 6.1% done in 285.8s, 4367.8s to go
# on time step 952 (time=4.76), 0.236803 s/step
# Meep progress: 4.835/77.5 = 6.2% done in 289.9s, 4356.4s to go
# on time step 967 (time=4.835), 0.26967 s/step
# Meep progress: 4.91/77.5 = 6.3% done in 294.1s, 4348.0s to go
# on time step 982 (time=4.91), 0.282049 s/step
# Meep progress: 4.985/77.5 = 6.4% done in 298.2s, 4338.0s to go
# on time step 997 (time=4.985), 0.27427 s/step
# Meep progress: 5.0600000000000005/77.5 = 6.5% done in 302.4s, 4328.9s to go
# on time step 1012 (time=5.06), 0.27744 s/step
# Meep progress: 5.135/77.5 = 6.6% done in 306.5s, 4319.4s to go
# on time step 1027 (time=5.135), 0.275079 s/step
# Meep progress: 5.21/77.5 = 6.7% done in 310.6s, 4310.3s to go
# on time step 1042 (time=5.21), 0.275857 s/step
# Meep progress: 5.285/77.5 = 6.8% done in 314.8s, 4301.1s to go
# on time step 1057 (time=5.285), 0.275124 s/step
# Meep progress: 5.36/77.5 = 6.9% done in 318.9s, 4292.4s to go
# on time step 1072 (time=5.36), 0.276575 s/step
# Meep progress: 5.4350000000000005/77.5 = 7.0% done in 323.1s, 4284.7s to go
# on time step 1087 (time=5.435), 0.281069 s/step
# Meep progress: 5.505/77.5 = 7.1% done in 327.2s, 4278.5s to go
# on time step 1101 (time=5.505), 0.28638 s/step
# Meep progress: 5.575/77.5 = 7.2% done in 331.2s, 4272.8s to go
# on time step 1115 (time=5.575), 0.288318 s/step
# Meep progress: 5.6450000000000005/77.5 = 7.3% done in 335.4s, 4268.7s to go
# on time step 1129 (time=5.645), 0.2974 s/step
# Meep progress: 5.715/77.5 = 7.4% done in 339.5s, 4264.1s to go
# on time step 1143 (time=5.715), 0.294738 s/step
# Meep progress: 5.785/77.5 = 7.5% done in 343.6s, 4259.1s to go
# on time step 1157 (time=5.785), 0.291564 s/step
# Meep progress: 5.855/77.5 = 7.6% done in 347.6s, 4253.9s to go
# on time step 1171 (time=5.855), 0.29105 s/step
# Meep progress: 5.925/77.5 = 7.6% done in 351.7s, 4249.2s to go
# on time step 1185 (time=5.925), 0.293259 s/step
# Meep progress: 5.995/77.5 = 7.7% done in 355.9s, 4244.4s to go
# on time step 1199 (time=5.995), 0.292983 s/step
# Meep progress: 6.065/77.5 = 7.8% done in 360.0s, 4239.6s to go
# on time step 1213 (time=6.065), 0.292959 s/step
# Meep progress: 6.135/77.5 = 7.9% done in 364.0s, 4234.8s to go
# on time step 1227 (time=6.135), 0.292293 s/step
# Meep progress: 6.205/77.5 = 8.0% done in 368.1s, 4230.0s to go
# on time step 1241 (time=6.205), 0.292619 s/step
# Meep progress: 6.275/77.5 = 8.1% done in 372.2s, 4225.2s to go
# on time step 1255 (time=6.275), 0.292511 s/step
# Meep progress: 6.345/77.5 = 8.2% done in 376.3s, 4220.3s to go
# on time step 1269 (time=6.345), 0.291646 s/step
# Meep progress: 6.42/77.5 = 8.3% done in 380.4s, 4211.9s to go
# on time step 1284 (time=6.42), 0.272981 s/step
# Meep progress: 6.525/77.5 = 8.4% done in 384.6s, 4183.3s to go
# on time step 1305 (time=6.525), 0.197714 s/step
# Meep progress: 6.615/77.5 = 8.5% done in 388.8s, 4165.8s to go
# on time step 1323 (time=6.615), 0.231301 s/step
# Meep progress: 6.7/77.5 = 8.6% done in 392.8s, 4150.7s to go
# on time step 1340 (time=6.7), 0.237689 s/step
# Meep progress: 6.78/77.5 = 8.7% done in 396.8s, 4139.2s to go
# on time step 1356 (time=6.78), 0.251924 s/step
# Meep progress: 6.86/77.5 = 8.9% done in 400.9s, 4128.4s to go
# on time step 1372 (time=6.86), 0.255808 s/step
# Meep progress: 6.94/77.5 = 9.0% done in 405.1s, 4118.7s to go
# on time step 1388 (time=6.94), 0.261235 s/step
# Meep progress: 7.0200000000000005/77.5 = 9.1% done in 409.3s, 4109.5s to go
# on time step 1404 (time=7.02), 0.263539 s/step
# Meep progress: 7.095/77.5 = 9.2% done in 413.4s, 4101.8s to go
# on time step 1419 (time=7.095), 0.268802 s/step
# Meep progress: 7.17/77.5 = 9.3% done in 417.4s, 4094.7s to go
# on time step 1434 (time=7.17), 0.272912 s/step
# Meep progress: 7.245/77.5 = 9.3% done in 421.6s, 4088.3s to go
# on time step 1449 (time=7.245), 0.277076 s/step
# Meep progress: 7.32/77.5 = 9.4% done in 425.7s, 4081.5s to go
# on time step 1464 (time=7.32), 0.27366 s/step
# Meep progress: 7.3950000000000005/77.5 = 9.5% done in 429.8s, 4074.9s to go
# on time step 1479 (time=7.395), 0.275198 s/step
# Meep progress: 7.47/77.5 = 9.6% done in 434.1s, 4069.6s to go
# on time step 1494 (time=7.47), 0.283793 s/step
# Meep progress: 7.545/77.5 = 9.7% done in 438.4s, 4064.3s to go
# on time step 1509 (time=7.545), 0.28374 s/step
# Meep progress: 7.62/77.5 = 9.8% done in 442.6s, 4058.7s to go
# on time step 1524 (time=7.62), 0.281101 s/step
# Meep progress: 7.695/77.5 = 9.9% done in 446.8s, 4053.2s to go
# on time step 1539 (time=7.695), 0.281876 s/step
# Meep progress: 7.765000000000001/77.5 = 10.0% done in 450.8s, 4048.6s to go
# on time step 1553 (time=7.765), 0.286656 s/step
# Meep progress: 7.835/77.5 = 10.1% done in 454.9s, 4045.0s to go
# on time step 1567 (time=7.835), 0.293726 s/step
# Meep progress: 7.905/77.5 = 10.2% done in 459.2s, 4042.6s to go
# on time step 1581 (time=7.905), 0.303439 s/step
# Meep progress: 7.9750000000000005/77.5 = 10.3% done in 463.2s, 4038.2s to go
# on time step 1595 (time=7.975), 0.288096 s/step
# Meep progress: 8.045/77.5 = 10.4% done in 467.3s, 4034.2s to go
# on time step 1609 (time=8.045), 0.290245 s/step
# Meep progress: 8.115/77.5 = 10.5% done in 471.3s, 4029.9s to go
# on time step 1623 (time=8.115), 0.288969 s/step
# Meep progress: 8.185/77.5 = 10.6% done in 475.3s, 4025.4s to go
# on time step 1637 (time=8.185), 0.28591 s/step
# Meep progress: 8.255/77.5 = 10.7% done in 479.4s, 4021.2s to go
# on time step 1651 (time=8.255), 0.289158 s/step
# Meep progress: 8.325/77.5 = 10.7% done in 483.4s, 4016.7s to go
# on time step 1665 (time=8.325), 0.287163 s/step
# Meep progress: 8.41/77.5 = 10.9% done in 487.6s, 4005.5s to go
# on time step 1682 (time=8.41), 0.245482 s/step
# Meep progress: 8.495000000000001/77.5 = 11.0% done in 491.6s, 3993.3s to go
# on time step 1699 (time=8.495), 0.23675 s/step
# Meep progress: 8.58/77.5 = 11.1% done in 495.7s, 3981.5s to go
# on time step 1716 (time=8.58), 0.238984 s/step
# Meep progress: 8.665000000000001/77.5 = 11.2% done in 499.7s, 3969.8s to go
# on time step 1733 (time=8.665), 0.238546 s/step
# Meep progress: 8.75/77.5 = 11.3% done in 503.8s, 3958.2s to go
# on time step 1750 (time=8.75), 0.238373 s/step
# Meep progress: 8.835/77.5 = 11.4% done in 507.9s, 3947.1s to go
# on time step 1767 (time=8.835), 0.24035 s/step
# Meep progress: 8.92/77.5 = 11.5% done in 511.9s, 3936.0s to go
# on time step 1784 (time=8.92), 0.239678 s/step
# Meep progress: 9.005/77.5 = 11.6% done in 516.0s, 3924.9s to go
# on time step 1801 (time=9.005), 0.238873 s/step
# Meep progress: 9.09/77.5 = 11.7% done in 520.0s, 3913.8s to go
# on time step 1818 (time=9.09), 0.238096 s/step
# Meep progress: 9.175/77.5 = 11.8% done in 524.2s, 3903.3s to go
# on time step 1835 (time=9.175), 0.241439 s/step
# Meep progress: 9.26/77.5 = 11.9% done in 528.3s, 3893.3s to go
# on time step 1852 (time=9.26), 0.244173 s/step
# Meep progress: 9.345/77.5 = 12.1% done in 532.4s, 3883.1s to go
# on time step 1869 (time=9.345), 0.242379 s/step
# Meep progress: 9.435/77.5 = 12.2% done in 536.7s, 3871.5s to go
# on time step 1887 (time=9.435), 0.234835 s/step
# Meep progress: 9.52/77.5 = 12.3% done in 540.9s, 3862.2s to go
# on time step 1904 (time=9.52), 0.247434 s/step
# Meep progress: 9.6/77.5 = 12.4% done in 544.9s, 3854.0s to go
# on time step 1920 (time=9.6), 0.251429 s/step
# Meep progress: 9.68/77.5 = 12.5% done in 548.9s, 3845.8s to go
# on time step 1936 (time=9.68), 0.251866 s/step
# Meep progress: 9.76/77.5 = 12.6% done in 552.9s, 3837.8s to go
# on time step 1952 (time=9.76), 0.251772 s/step
# Meep progress: 9.84/77.5 = 12.7% done in 557.0s, 3829.9s to go
# on time step 1968 (time=9.84), 0.252356 s/step
# Meep progress: 9.92/77.5 = 12.8% done in 561.0s, 3822.0s to go
# on time step 1984 (time=9.92), 0.252043 s/step
# Meep progress: 10.0/77.5 = 12.9% done in 565.1s, 3814.4s to go
# on time step 2000 (time=10), 0.254207 s/step
# Meep progress: 10.08/77.5 = 13.0% done in 569.2s, 3807.0s to go
# on time step 2016 (time=10.08), 0.256019 s/step
# Meep progress: 10.16/77.5 = 13.1% done in 573.3s, 3799.7s to go
# on time step 2032 (time=10.16), 0.256322 s/step
# Meep progress: 10.24/77.5 = 13.2% done in 577.5s, 3793.3s to go
# on time step 2048 (time=10.24), 0.263466 s/step
# Meep progress: 10.32/77.5 = 13.3% done in 581.8s, 3787.0s to go
# on time step 2064 (time=10.32), 0.265139 s/step
# Meep progress: 10.4/77.5 = 13.4% done in 586.0s, 3780.8s to go
# on time step 2080 (time=10.4), 0.265436 s/step
# Meep progress: 10.48/77.5 = 13.5% done in 590.3s, 3774.8s to go
# on time step 2096 (time=10.48), 0.266784 s/step
# Meep progress: 10.555/77.5 = 13.6% done in 594.3s, 3769.3s to go
# on time step 2111 (time=10.555), 0.268781 s/step
# Meep progress: 10.63/77.5 = 13.7% done in 598.3s, 3763.8s to go
# on time step 2126 (time=10.63), 0.267101 s/step
# Meep progress: 10.71/77.5 = 13.8% done in 602.6s, 3757.7s to go
# on time step 2142 (time=10.71), 0.265646 s/step
# Meep progress: 10.790000000000001/77.5 = 13.9% done in 606.8s, 3751.6s to go
# on time step 2158 (time=10.79), 0.265245 s/step
# Meep progress: 10.865/77.5 = 14.0% done in 610.9s, 3746.4s to go
# on time step 2173 (time=10.865), 0.27012 s/step
# Meep progress: 10.94/77.5 = 14.1% done in 614.9s, 3741.1s to go
# on time step 2188 (time=10.94), 0.269705 s/step
# Meep progress: 11.015/77.5 = 14.2% done in 619.0s, 3736.3s to go
# on time step 2203 (time=11.015), 0.273786 s/step
# Meep progress: 11.085/77.5 = 14.3% done in 623.1s, 3733.3s to go
# on time step 2217 (time=11.085), 0.292541 s/step
# Meep progress: 11.155/77.5 = 14.4% done in 627.2s, 3730.4s to go
# on time step 2231 (time=11.155), 0.292771 s/step
# Meep progress: 11.225/77.5 = 14.5% done in 631.3s, 3727.4s to go
# on time step 2245 (time=11.225), 0.292371 s/step
# Meep progress: 11.295/77.5 = 14.6% done in 635.4s, 3724.4s to go
# on time step 2259 (time=11.295), 0.29326 s/step
# Meep progress: 11.365/77.5 = 14.7% done in 639.5s, 3721.4s to go
# on time step 2273 (time=11.365), 0.292438 s/step
# Meep progress: 11.435/77.5 = 14.8% done in 643.6s, 3718.2s to go
# on time step 2287 (time=11.435), 0.290532 s/step
# Meep progress: 11.505/77.5 = 14.8% done in 647.8s, 3715.7s to go
# on time step 2301 (time=11.505), 0.29887 s/step
# Meep progress: 11.575000000000001/77.5 = 14.9% done in 651.8s, 3712.4s to go
# on time step 2315 (time=11.575), 0.289747 s/step
# Meep progress: 11.645/77.5 = 15.0% done in 655.9s, 3709.2s to go
# on time step 2329 (time=11.645), 0.290583 s/step
# Meep progress: 11.72/77.5 = 15.1% done in 660.1s, 3704.8s to go
# on time step 2344 (time=11.72), 0.279348 s/step
# Meep progress: 11.795/77.5 = 15.2% done in 664.3s, 3700.3s to go
# on time step 2359 (time=11.795), 0.278908 s/step
# Meep progress: 11.870000000000001/77.5 = 15.3% done in 668.4s, 3695.9s to go
# on time step 2374 (time=11.87), 0.278253 s/step
# Meep progress: 11.94/77.5 = 15.4% done in 672.4s, 3692.3s to go
# on time step 2388 (time=11.94), 0.285907 s/step
# Meep progress: 12.015/77.5 = 15.5% done in 676.7s, 3688.3s to go
# on time step 2403 (time=12.015), 0.284714 s/step
# Meep progress: 12.09/77.5 = 15.6% done in 681.0s, 3684.4s to go
# on time step 2418 (time=12.09), 0.285203 s/step
# Meep progress: 12.165000000000001/77.5 = 15.7% done in 685.3s, 3680.5s to go
# on time step 2433 (time=12.165), 0.285698 s/step
# Meep progress: 12.235/77.5 = 15.8% done in 689.3s, 3676.9s to go
# on time step 2447 (time=12.235), 0.286067 s/step
# Meep progress: 12.31/77.5 = 15.9% done in 693.6s, 3672.9s to go
# on time step 2462 (time=12.31), 0.284551 s/step
# Meep progress: 12.38/77.5 = 16.0% done in 697.6s, 3669.2s to go
# on time step 2477 (time=12.385), 0.285771 s/step
# Meep progress: 12.455/77.5 = 16.1% done in 701.8s, 3665.2s to go
# on time step 2492 (time=12.46), 0.284386 s/step
# Meep progress: 12.530000000000001/77.5 = 16.2% done in 706.1s, 3661.3s to go
# on time step 2507 (time=12.535), 0.285076 s/step
# Meep progress: 12.605/77.5 = 16.3% done in 710.4s, 3657.3s to go
# on time step 2522 (time=12.61), 0.284875 s/step
# Meep progress: 12.68/77.5 = 16.4% done in 714.7s, 3653.3s to go
# on time step 2537 (time=12.685), 0.285519 s/step
# Meep progress: 12.76/77.5 = 16.5% done in 718.7s, 3646.4s to go
# on time step 2555 (time=12.775), 0.224678 s/step
# Meep progress: 12.845/77.5 = 16.6% done in 722.7s, 3637.9s to go
# on time step 2570 (time=12.85), 0.273831 s/step
# Meep progress: 12.905000000000001/77.5 = 16.7% done in 726.9s, 3638.6s to go
# on time step 2582 (time=12.91), 0.348295 s/step
# Meep progress: 12.965/77.5 = 16.7% done in 731.2s, 3639.5s to go
# on time step 2594 (time=12.97), 0.354617 s/step
# Meep progress: 13.025/77.5 = 16.8% done in 735.5s, 3640.9s to go
# on time step 2606 (time=13.03), 0.361114 s/step
# Meep progress: 13.085/77.5 = 16.9% done in 739.8s, 3641.8s to go
# on time step 2618 (time=13.09), 0.355006 s/step
# Meep progress: 13.145/77.5 = 17.0% done in 744.0s, 3642.6s to go
# on time step 2630 (time=13.15), 0.353486 s/step
# Meep progress: 13.205/77.5 = 17.0% done in 748.3s, 3643.4s to go
# on time step 2642 (time=13.21), 0.355123 s/step
# Meep progress: 13.265/77.5 = 17.1% done in 752.6s, 3644.2s to go
# on time step 2654 (time=13.27), 0.356327 s/step
# Meep progress: 13.325000000000001/77.5 = 17.2% done in 756.8s, 3645.0s to go
# on time step 2666 (time=13.33), 0.354301 s/step
# Meep progress: 13.385/77.5 = 17.3% done in 761.1s, 3645.6s to go
# on time step 2678 (time=13.39), 0.353999 s/step
# Meep progress: 13.445/77.5 = 17.3% done in 765.3s, 3646.3s to go
# on time step 2690 (time=13.45), 0.356224 s/step
# Meep progress: 13.505/77.5 = 17.4% done in 769.6s, 3646.9s to go
# on time step 2702 (time=13.51), 0.355489 s/step
# Meep progress: 13.565/77.5 = 17.5% done in 773.9s, 3647.4s to go
# on time step 2714 (time=13.57), 0.353456 s/step
# Meep progress: 13.625/77.5 = 17.6% done in 778.1s, 3647.9s to go
# on time step 2726 (time=13.63), 0.356085 s/step
# Meep progress: 13.685/77.5 = 17.7% done in 782.5s, 3648.7s to go
# on time step 2738 (time=13.69), 0.363026 s/step
# Meep progress: 13.76/77.5 = 17.8% done in 786.5s, 3643.4s to go
# on time step 2755 (time=13.775), 0.238636 s/step
# Meep progress: 13.84/77.5 = 17.9% done in 790.7s, 3637.0s to go
# on time step 2769 (time=13.845), 0.296844 s/step
# Meep progress: 13.895/77.5 = 17.9% done in 794.8s, 3638.0s to go
# on time step 2780 (time=13.9), 0.368429 s/step
# Meep progress: 13.950000000000001/77.5 = 18.0% done in 798.8s, 3639.0s to go
# on time step 2791 (time=13.955), 0.368231 s/step
# Meep progress: 14.005/77.5 = 18.1% done in 802.8s, 3639.9s to go
# on time step 2802 (time=14.01), 0.367856 s/step
# Meep progress: 14.065/77.5 = 18.1% done in 807.0s, 3639.5s to go
# on time step 2814 (time=14.07), 0.338061 s/step
# Meep progress: 14.13/77.5 = 18.2% done in 811.2s, 3638.1s to go
# on time step 2827 (time=14.135), 0.328225 s/step
# Meep progress: 14.19/77.5 = 18.3% done in 815.3s, 3637.5s to go
# on time step 2839 (time=14.195), 0.340879 s/step
# Meep progress: 14.25/77.5 = 18.4% done in 819.4s, 3637.0s to go
# on time step 2851 (time=14.255), 0.341781 s/step
# Meep progress: 14.31/77.5 = 18.5% done in 823.5s, 3636.3s to go
# on time step 2863 (time=14.315), 0.340049 s/step
# Meep progress: 14.370000000000001/77.5 = 18.5% done in 827.5s, 3635.5s to go
# on time step 2875 (time=14.375), 0.338551 s/step
# Meep progress: 14.43/77.5 = 18.6% done in 831.6s, 3634.8s to go
# on time step 2887 (time=14.435), 0.339389 s/step
# Meep progress: 14.49/77.5 = 18.7% done in 835.7s, 3634.1s to go
# on time step 2899 (time=14.495), 0.340128 s/step
# Meep progress: 14.55/77.5 = 18.8% done in 839.8s, 3633.2s to go
# on time step 2911 (time=14.555), 0.339017 s/step
# Meep progress: 14.61/77.5 = 18.9% done in 843.9s, 3632.5s to go
# on time step 2923 (time=14.615), 0.340173 s/step
# Meep progress: 14.67/77.5 = 18.9% done in 848.0s, 3631.7s to go
# on time step 2935 (time=14.675), 0.341433 s/step
# Meep progress: 14.73/77.5 = 19.0% done in 852.0s, 3630.8s to go
# on time step 2947 (time=14.735), 0.340387 s/step
# Meep progress: 14.790000000000001/77.5 = 19.1% done in 856.1s, 3630.0s to go
# on time step 2959 (time=14.795), 0.340974 s/step
# Meep progress: 14.85/77.5 = 19.2% done in 860.2s, 3629.1s to go
# on time step 2971 (time=14.855), 0.340372 s/step
# Meep progress: 14.91/77.5 = 19.2% done in 864.3s, 3628.3s to go
# on time step 2983 (time=14.915), 0.341737 s/step
# Meep progress: 14.97/77.5 = 19.3% done in 868.4s, 3627.4s to go
# on time step 2995 (time=14.975), 0.34089 s/step
# Meep progress: 15.030000000000001/77.5 = 19.4% done in 872.5s, 3626.5s to go
# on time step 3007 (time=15.035), 0.342605 s/step
# Meep progress: 15.09/77.5 = 19.5% done in 876.6s, 3625.6s to go
# on time step 3019 (time=15.095), 0.340673 s/step
# Meep progress: 15.15/77.5 = 19.5% done in 880.7s, 3624.6s to go
# on time step 3031 (time=15.155), 0.342131 s/step
# Meep progress: 15.21/77.5 = 19.6% done in 884.8s, 3623.7s to go
# on time step 3043 (time=15.215), 0.342819 s/step
# Meep progress: 15.27/77.5 = 19.7% done in 889.0s, 3622.8s to go
# on time step 3055 (time=15.275), 0.342577 s/step
# Meep progress: 15.33/77.5 = 19.8% done in 893.0s, 3621.7s to go
# on time step 3067 (time=15.335), 0.341463 s/step
# Meep progress: 15.39/77.5 = 19.9% done in 897.1s, 3620.6s to go
# on time step 3079 (time=15.395), 0.339799 s/step
# Meep progress: 15.450000000000001/77.5 = 19.9% done in 901.2s, 3619.5s to go
# on time step 3091 (time=15.455), 0.341973 s/step
# Meep progress: 15.51/77.5 = 20.0% done in 905.3s, 3618.4s to go
# on time step 3103 (time=15.515), 0.340177 s/step
# Meep progress: 15.57/77.5 = 20.1% done in 909.4s, 3617.2s to go
# on time step 3115 (time=15.575), 0.341097 s/step
# Meep progress: 15.63/77.5 = 20.2% done in 913.5s, 3616.1s to go
# on time step 3127 (time=15.635), 0.341893 s/step
# Meep progress: 15.69/77.5 = 20.2% done in 917.6s, 3614.8s to go
# on time step 3139 (time=15.695), 0.33794 s/step
# Meep progress: 15.75/77.5 = 20.3% done in 921.7s, 3613.6s to go
# on time step 3151 (time=15.755), 0.342434 s/step
# Meep progress: 15.81/77.5 = 20.4% done in 925.8s, 3612.3s to go
# on time step 3163 (time=15.815), 0.340136 s/step
# Meep progress: 15.870000000000001/77.5 = 20.5% done in 929.8s, 3611.0s to go
# on time step 3175 (time=15.875), 0.339529 s/step
# Meep progress: 15.93/77.5 = 20.6% done in 933.9s, 3609.7s to go
# on time step 3187 (time=15.935), 0.341375 s/step
# Meep progress: 15.99/77.5 = 20.6% done in 938.0s, 3608.4s to go
# on time step 3199 (time=15.995), 0.341086 s/step
# Meep progress: 16.05/77.5 = 20.7% done in 942.1s, 3607.1s to go
# on time step 3211 (time=16.055), 0.340204 s/step
# Meep progress: 16.11/77.5 = 20.8% done in 946.2s, 3605.8s to go
# on time step 3223 (time=16.115), 0.341524 s/step
# Meep progress: 16.17/77.5 = 20.9% done in 950.3s, 3604.4s to go
# on time step 3235 (time=16.175), 0.341153 s/step
# Meep progress: 16.23/77.5 = 20.9% done in 954.4s, 3603.0s to go
# on time step 3247 (time=16.235), 0.342109 s/step
# Meep progress: 16.29/77.5 = 21.0% done in 958.5s, 3601.7s to go
# on time step 3259 (time=16.295), 0.342645 s/step
# Meep progress: 16.35/77.5 = 21.1% done in 962.6s, 3600.3s to go
# on time step 3271 (time=16.355), 0.341087 s/step
# Meep progress: 16.41/77.5 = 21.2% done in 966.7s, 3598.9s to go
# on time step 3283 (time=16.415), 0.34179 s/step
# Meep progress: 16.47/77.5 = 21.3% done in 970.8s, 3597.5s to go
# on time step 3295 (time=16.475), 0.341581 s/step
# Meep progress: 16.53/77.5 = 21.3% done in 974.9s, 3596.0s to go
# on time step 3307 (time=16.535), 0.341287 s/step
# Meep progress: 16.59/77.5 = 21.4% done in 979.0s, 3594.5s to go
# on time step 3319 (time=16.595), 0.340936 s/step
# Meep progress: 16.65/77.5 = 21.5% done in 983.2s, 3593.1s to go
# on time step 3331 (time=16.655), 0.343649 s/step
# Meep progress: 16.71/77.5 = 21.6% done in 987.3s, 3591.6s to go
# on time step 3343 (time=16.715), 0.341923 s/step
# Meep progress: 16.845/77.5 = 21.7% done in 991.6s, 3570.6s to go
# on time step 3369 (time=16.845), 0.154376 s/step
# Meep progress: 16.89/77.5 = 21.8% done in 995.6s, 3572.8s to go
# on time step 3378 (time=16.89), 0.445605 s/step
# Meep progress: 16.935/77.5 = 21.9% done in 999.6s, 3575.0s to go
# on time step 3387 (time=16.935), 0.446236 s/step
# Meep progress: 16.98/77.5 = 21.9% done in 1003.7s, 3577.2s to go
# on time step 3396 (time=16.98), 0.445786 s/step
# Meep progress: 17.025/77.5 = 22.0% done in 1007.7s, 3579.4s to go
# on time step 3405 (time=17.025), 0.446092 s/step
# Meep progress: 17.07/77.5 = 22.0% done in 1011.7s, 3581.5s to go
# on time step 3414 (time=17.07), 0.444856 s/step
# Meep progress: 17.12/77.5 = 22.1% done in 1016.1s, 3583.5s to go
# on time step 3424 (time=17.12), 0.438862 s/step
# Meep progress: 17.17/77.5 = 22.2% done in 1020.5s, 3585.6s to go
# on time step 3434 (time=17.17), 0.440743 s/step
# Meep progress: 17.22/77.5 = 22.2% done in 1024.8s, 3587.3s to go
# on time step 3444 (time=17.22), 0.43027 s/step
# Meep progress: 17.27/77.5 = 22.3% done in 1029.1s, 3588.9s to go
# on time step 3454 (time=17.27), 0.428725 s/step
# Meep progress: 17.32/77.5 = 22.3% done in 1033.4s, 3590.5s to go
# on time step 3464 (time=17.32), 0.428236 s/step
# Meep progress: 17.37/77.5 = 22.4% done in 1037.5s, 3591.4s to go
# on time step 3474 (time=17.37), 0.410553 s/step
# Meep progress: 17.42/77.5 = 22.5% done in 1041.6s, 3592.2s to go
# on time step 3484 (time=17.42), 0.409434 s/step
# Meep progress: 17.47/77.5 = 22.5% done in 1045.7s, 3593.2s to go
# on time step 3494 (time=17.47), 0.413191 s/step
# Meep progress: 17.52/77.5 = 22.6% done in 1049.8s, 3594.0s to go
# on time step 3504 (time=17.52), 0.409771 s/step
# Meep progress: 17.57/77.5 = 22.7% done in 1053.9s, 3594.7s to go
# on time step 3514 (time=17.57), 0.407701 s/step
# Meep progress: 17.62/77.5 = 22.7% done in 1058.0s, 3595.4s to go
# on time step 3524 (time=17.62), 0.408977 s/step
# Meep progress: 17.67/77.5 = 22.8% done in 1062.1s, 3596.1s to go
# on time step 3534 (time=17.67), 0.409513 s/step
# Meep progress: 17.72/77.5 = 22.9% done in 1066.1s, 3596.7s to go
# on time step 3544 (time=17.72), 0.407824 s/step
# Meep progress: 17.775000000000002/77.5 = 22.9% done in 1070.5s, 3596.9s to go
# on time step 3555 (time=17.775), 0.396725 s/step
# Meep progress: 17.830000000000002/77.5 = 23.0% done in 1074.9s, 3597.2s to go
# on time step 3566 (time=17.83), 0.397555 s/step
# Meep progress: 17.89/77.5 = 23.1% done in 1078.9s, 3595.1s to go
# on time step 3578 (time=17.89), 0.338728 s/step
# Meep progress: 17.95/77.5 = 23.2% done in 1083.0s, 3592.8s to go
# on time step 3590 (time=17.95), 0.335928 s/step
# Meep progress: 18.015/77.5 = 23.2% done in 1087.2s, 3590.0s to go
# on time step 3603 (time=18.015), 0.327042 s/step
# Meep progress: 18.080000000000002/77.5 = 23.3% done in 1091.5s, 3587.3s to go
# on time step 3616 (time=18.08), 0.33006 s/step
# Meep progress: 18.14/77.5 = 23.4% done in 1095.5s, 3585.0s to go
# on time step 3628 (time=18.14), 0.334833 s/step
# Meep progress: 18.205000000000002/77.5 = 23.5% done in 1099.9s, 3582.3s to go
# on time step 3641 (time=18.205), 0.332326 s/step
# Meep progress: 18.265/77.5 = 23.6% done in 1103.9s, 3580.1s to go
# on time step 3653 (time=18.265), 0.336793 s/step
# Meep progress: 18.325/77.5 = 23.6% done in 1107.9s, 3577.7s to go
# on time step 3665 (time=18.325), 0.334404 s/step
# Meep progress: 18.39/77.5 = 23.7% done in 1112.2s, 3575.0s to go
# on time step 3678 (time=18.39), 0.331215 s/step
# Meep progress: 18.45/77.5 = 23.8% done in 1116.3s, 3572.7s to go
# on time step 3690 (time=18.45), 0.336953 s/step
# Meep progress: 18.51/77.5 = 23.9% done in 1120.3s, 3570.4s to go
# on time step 3702 (time=18.51), 0.339048 s/step
# Meep progress: 18.57/77.5 = 24.0% done in 1124.4s, 3568.3s to go
# on time step 3714 (time=18.57), 0.341253 s/step
# Meep progress: 18.63/77.5 = 24.0% done in 1128.6s, 3566.3s to go
# on time step 3726 (time=18.63), 0.34678 s/step
# Meep progress: 18.69/77.5 = 24.1% done in 1132.7s, 3564.3s to go
# on time step 3738 (time=18.69), 0.344479 s/step
# Meep progress: 18.75/77.5 = 24.2% done in 1136.8s, 3561.8s to go
# on time step 3750 (time=18.75), 0.334919 s/step
# Meep progress: 18.815/77.5 = 24.3% done in 1141.1s, 3559.0s to go
# on time step 3763 (time=18.815), 0.331079 s/step
# Meep progress: 18.875/77.5 = 24.4% done in 1145.2s, 3557.0s to go
# on time step 3775 (time=18.875), 0.34522 s/step
# Meep progress: 18.935/77.5 = 24.4% done in 1149.3s, 3554.9s to go
# on time step 3787 (time=18.935), 0.345222 s/step
# Meep progress: 18.995/77.5 = 24.5% done in 1153.5s, 3552.9s to go
# on time step 3799 (time=18.995), 0.347127 s/step
# Meep progress: 19.055/77.5 = 24.6% done in 1157.7s, 3550.9s to go
# on time step 3811 (time=19.055), 0.348152 s/step
# Meep progress: 19.115000000000002/77.5 = 24.7% done in 1161.9s, 3548.8s to go
# on time step 3823 (time=19.115), 0.346168 s/step
# Meep progress: 19.175/77.5 = 24.7% done in 1166.0s, 3546.8s to go
# on time step 3835 (time=19.175), 0.34933 s/step
# Meep progress: 19.235/77.5 = 24.8% done in 1170.2s, 3544.6s to go
# on time step 3847 (time=19.235), 0.343555 s/step
# Meep progress: 19.3/77.5 = 24.9% done in 1174.5s, 3541.6s to go
# on time step 3860 (time=19.3), 0.329906 s/step
# Meep progress: 19.36/77.5 = 25.0% done in 1178.5s, 3539.2s to go
# on time step 3872 (time=19.36), 0.337865 s/step
# Meep progress: 19.42/77.5 = 25.1% done in 1182.6s, 3536.9s to go
# on time step 3884 (time=19.42), 0.343418 s/step
# Meep progress: 19.48/77.5 = 25.1% done in 1186.8s, 3534.8s to go
# on time step 3896 (time=19.48), 0.346845 s/step
# Meep progress: 19.54/77.5 = 25.2% done in 1191.0s, 3532.7s to go
# on time step 3908 (time=19.54), 0.346874 s/step
# Meep progress: 19.6/77.5 = 25.3% done in 1195.0s, 3530.2s to go
# on time step 3920 (time=19.6), 0.339273 s/step
# Meep progress: 19.66/77.5 = 25.4% done in 1199.1s, 3527.7s to go
# on time step 3932 (time=19.66), 0.337589 s/step
# Meep progress: 19.72/77.5 = 25.4% done in 1203.5s, 3526.2s to go
# on time step 3944 (time=19.72), 0.364167 s/step
# Meep progress: 19.775000000000002/77.5 = 25.5% done in 1207.6s, 3525.0s to go
# on time step 3955 (time=19.775), 0.372142 s/step
# Meep progress: 19.830000000000002/77.5 = 25.6% done in 1211.7s, 3523.8s to go
# on time step 3966 (time=19.83), 0.373014 s/step
# Meep progress: 19.885/77.5 = 25.7% done in 1215.7s, 3522.5s to go
# on time step 3977 (time=19.885), 0.370296 s/step
# Meep progress: 19.94/77.5 = 25.7% done in 1219.8s, 3521.1s to go
# on time step 3988 (time=19.94), 0.368063 s/step
# Meep progress: 19.995/77.5 = 25.8% done in 1223.9s, 3519.8s to go
# on time step 3999 (time=19.995), 0.371412 s/step
# Meep progress: 20.05/77.5 = 25.9% done in 1228.0s, 3518.6s to go
# on time step 4010 (time=20.05), 0.374748 s/step
# Meep progress: 20.105/77.5 = 25.9% done in 1232.1s, 3517.4s to go
# on time step 4021 (time=20.105), 0.375926 s/step
# Meep progress: 20.165/77.5 = 26.0% done in 1236.5s, 3515.6s to go
# on time step 4033 (time=20.165), 0.361218 s/step
# Meep progress: 20.225/77.5 = 26.1% done in 1240.8s, 3513.9s to go
# on time step 4045 (time=20.225), 0.363927 s/step
# Meep progress: 20.28/77.5 = 26.2% done in 1245.0s, 3512.7s to go
# on time step 4056 (time=20.28), 0.377261 s/step
# Meep progress: 20.335/77.5 = 26.2% done in 1249.0s, 3511.3s to go
# on time step 4067 (time=20.335), 0.368173 s/step
# Meep progress: 20.39/77.5 = 26.3% done in 1253.2s, 3510.0s to go
# on time step 4078 (time=20.39), 0.375185 s/step
# Meep progress: 20.445/77.5 = 26.4% done in 1257.3s, 3508.7s to go
# on time step 4089 (time=20.445), 0.37706 s/step
# Meep progress: 20.5/77.5 = 26.5% done in 1261.4s, 3507.4s to go
# on time step 4100 (time=20.5), 0.375062 s/step
# Meep progress: 20.555/77.5 = 26.5% done in 1265.6s, 3506.1s to go
# on time step 4111 (time=20.555), 0.376272 s/step
# Meep progress: 20.61/77.5 = 26.6% done in 1269.7s, 3504.8s to go
# on time step 4122 (time=20.61), 0.375947 s/step
# Meep progress: 20.665/77.5 = 26.7% done in 1273.9s, 3503.5s to go
# on time step 4133 (time=20.665), 0.376797 s/step
# Meep progress: 20.72/77.5 = 26.7% done in 1277.9s, 3502.0s to go
# on time step 4144 (time=20.72), 0.36959 s/step
# Meep progress: 20.775000000000002/77.5 = 26.8% done in 1282.0s, 3500.4s to go
# on time step 4155 (time=20.775), 0.36904 s/step
# Meep progress: 20.830000000000002/77.5 = 26.9% done in 1286.1s, 3499.1s to go
# on time step 4166 (time=20.83), 0.376856 s/step
# Meep progress: 20.885/77.5 = 26.9% done in 1290.3s, 3497.7s to go
# on time step 4177 (time=20.885), 0.37717 s/step
# Meep progress: 20.94/77.5 = 27.0% done in 1294.4s, 3496.4s to go
# on time step 4188 (time=20.94), 0.377016 s/step
# Meep progress: 20.995/77.5 = 27.1% done in 1298.6s, 3494.9s to go
# on time step 4199 (time=20.995), 0.375656 s/step
# Meep progress: 21.05/77.5 = 27.2% done in 1302.7s, 3493.5s to go
# on time step 4210 (time=21.05), 0.37642 s/step
# Meep progress: 21.105/77.5 = 27.2% done in 1306.7s, 3491.7s to go
# on time step 4221 (time=21.105), 0.363949 s/step
# Meep progress: 21.165/77.5 = 27.3% done in 1311.0s, 3489.5s to go
# on time step 4233 (time=21.165), 0.35654 s/step
# Meep progress: 21.22/77.5 = 27.4% done in 1315.0s, 3487.7s to go
# on time step 4244 (time=21.22), 0.365793 s/step
# Meep progress: 21.28/77.5 = 27.5% done in 1319.4s, 3485.6s to go
# on time step 4256 (time=21.28), 0.360283 s/step
# Meep progress: 21.335/77.5 = 27.5% done in 1323.4s, 3483.9s to go
# on time step 4267 (time=21.335), 0.367258 s/step
# Meep progress: 21.395/77.5 = 27.6% done in 1327.7s, 3481.6s to go
# on time step 4279 (time=21.395), 0.357233 s/step
# Meep progress: 21.45/77.5 = 27.7% done in 1331.7s, 3479.8s to go
# on time step 4290 (time=21.45), 0.364453 s/step
# Meep progress: 21.51/77.5 = 27.8% done in 1335.9s, 3477.4s to go
# on time step 4302 (time=21.51), 0.354089 s/step
# Meep progress: 21.57/77.5 = 27.8% done in 1340.3s, 3475.2s to go
# on time step 4314 (time=21.57), 0.359561 s/step
# Meep progress: 21.63/77.5 = 27.9% done in 1344.5s, 3472.8s to go
# on time step 4326 (time=21.63), 0.35317 s/step
# Meep progress: 21.69/77.5 = 28.0% done in 1348.5s, 3469.8s to go
# on time step 4339 (time=21.695), 0.33244 s/step
# Meep progress: 21.755/77.5 = 28.1% done in 1352.7s, 3466.2s to go
# on time step 4352 (time=21.76), 0.324887 s/step
# Meep progress: 21.82/77.5 = 28.2% done in 1356.9s, 3462.5s to go
# on time step 4365 (time=21.825), 0.321718 s/step
# Meep progress: 21.885/77.5 = 28.2% done in 1361.2s, 3459.2s to go
# on time step 4378 (time=21.89), 0.331016 s/step
# Meep progress: 21.95/77.5 = 28.3% done in 1365.5s, 3455.8s to go
# on time step 4391 (time=21.955), 0.331005 s/step
# Meep progress: 22.01/77.5 = 28.4% done in 1369.5s, 3452.7s to go
# on time step 4403 (time=22.015), 0.333814 s/step
# Meep progress: 22.075/77.5 = 28.5% done in 1373.8s, 3449.3s to go
# on time step 4416 (time=22.08), 0.331054 s/step
# Meep progress: 22.14/77.5 = 28.6% done in 1378.1s, 3445.9s to go
# on time step 4429 (time=22.145), 0.330448 s/step
# Meep progress: 22.205000000000002/77.5 = 28.7% done in 1382.4s, 3442.5s to go
# on time step 4442 (time=22.21), 0.330488 s/step
# Meep progress: 22.27/77.5 = 28.7% done in 1386.7s, 3439.1s to go
# on time step 4455 (time=22.275), 0.332931 s/step
# Meep progress: 22.335/77.5 = 28.8% done in 1391.1s, 3435.8s to go
# on time step 4468 (time=22.34), 0.331196 s/step
# Meep progress: 22.400000000000002/77.5 = 28.9% done in 1395.4s, 3432.4s to go
# on time step 4481 (time=22.405), 0.332948 s/step
# Meep progress: 22.465/77.5 = 29.0% done in 1399.7s, 3429.0s to go
# on time step 4494 (time=22.47), 0.33092 s/step
# Meep progress: 22.53/77.5 = 29.1% done in 1404.0s, 3425.6s to go
# on time step 4507 (time=22.535), 0.332617 s/step
# Meep progress: 22.59/77.5 = 29.1% done in 1408.0s, 3422.5s to go
# on time step 4520 (time=22.6), 0.332976 s/step
# Meep progress: 22.650000000000002/77.5 = 29.2% done in 1412.0s, 3419.4s to go
# on time step 4532 (time=22.66), 0.334048 s/step
# Meep progress: 22.715/77.5 = 29.3% done in 1416.3s, 3416.0s to go
# on time step 4545 (time=22.725), 0.33234 s/step
# Meep progress: 22.78/77.5 = 29.4% done in 1420.7s, 3412.6s to go
# on time step 4558 (time=22.79), 0.331603 s/step
# Meep progress: 22.845/77.5 = 29.5% done in 1424.9s, 3409.1s to go
# on time step 4571 (time=22.855), 0.330231 s/step
# Meep progress: 22.905/77.5 = 29.6% done in 1429.0s, 3406.0s to go
# on time step 4583 (time=22.915), 0.334118 s/step
# Meep progress: 22.97/77.5 = 29.6% done in 1433.3s, 3402.5s to go
# on time step 4596 (time=22.98), 0.33145 s/step
# Meep progress: 23.035/77.5 = 29.7% done in 1437.6s, 3399.1s to go
# on time step 4609 (time=23.045), 0.330951 s/step
# Meep progress: 23.1/77.5 = 29.8% done in 1441.9s, 3395.7s to go
# on time step 4622 (time=23.11), 0.332263 s/step
# Meep progress: 23.16/77.5 = 29.9% done in 1445.9s, 3392.6s to go
# on time step 4634 (time=23.17), 0.337067 s/step
# Meep progress: 23.225/77.5 = 30.0% done in 1450.3s, 3389.1s to go
# on time step 4647 (time=23.235), 0.331383 s/step
# Meep progress: 23.29/77.5 = 30.1% done in 1454.6s, 3385.7s to go
# on time step 4660 (time=23.3), 0.330849 s/step
# Meep progress: 23.355/77.5 = 30.1% done in 1458.9s, 3382.2s to go
# on time step 4672 (time=23.36), 0.334006 s/step
# Meep progress: 23.415/77.5 = 30.2% done in 1462.9s, 3379.1s to go
# on time step 4685 (time=23.425), 0.332241 s/step
# Meep progress: 23.48/77.5 = 30.3% done in 1467.2s, 3375.7s to go
# on time step 4697 (time=23.485), 0.334403 s/step
# Meep progress: 23.545/77.5 = 30.4% done in 1471.5s, 3372.1s to go
# on time step 4710 (time=23.55), 0.330324 s/step
# Meep progress: 23.605/77.5 = 30.5% done in 1475.6s, 3369.0s to go
# on time step 4722 (time=23.61), 0.336118 s/step
# Meep progress: 23.665/77.5 = 30.5% done in 1479.6s, 3365.8s to go
# on time step 4734 (time=23.67), 0.333339 s/step
# Meep progress: 23.73/77.5 = 30.6% done in 1483.9s, 3362.3s to go
# on time step 4747 (time=23.735), 0.332244 s/step
# Meep progress: 23.795/77.5 = 30.7% done in 1488.2s, 3358.9s to go
# on time step 4760 (time=23.8), 0.331511 s/step
# Meep progress: 23.86/77.5 = 30.8% done in 1492.5s, 3355.4s to go
# on time step 4773 (time=23.865), 0.331799 s/step
# Meep progress: 23.925/77.5 = 30.9% done in 1496.8s, 3351.8s to go
# on time step 4786 (time=23.93), 0.331136 s/step
# Meep progress: 23.990000000000002/77.5 = 31.0% done in 1501.1s, 3348.3s to go
# on time step 4799 (time=23.995), 0.331246 s/step
# Meep progress: 24.055/77.5 = 31.0% done in 1505.4s, 3344.7s to go
# on time step 4812 (time=24.06), 0.331217 s/step
# Meep progress: 24.12/77.5 = 31.1% done in 1509.7s, 3341.2s to go
# on time step 4825 (time=24.125), 0.33082 s/step
# Meep progress: 24.185000000000002/77.5 = 31.2% done in 1514.1s, 3337.7s to go
# on time step 4838 (time=24.19), 0.33288 s/step
# Meep progress: 24.25/77.5 = 31.3% done in 1518.3s, 3334.1s to go
# on time step 4851 (time=24.255), 0.328823 s/step
# Meep progress: 24.315/77.5 = 31.4% done in 1522.6s, 3330.5s to go
# on time step 4864 (time=24.32), 0.330406 s/step
# Meep progress: 24.38/77.5 = 31.5% done in 1526.9s, 3326.9s to go
# on time step 4877 (time=24.385), 0.330336 s/step
# Meep progress: 24.445/77.5 = 31.5% done in 1531.2s, 3323.4s to go
# on time step 4890 (time=24.45), 0.331892 s/step
# Meep progress: 24.51/77.5 = 31.6% done in 1535.6s, 3319.8s to go
# on time step 4903 (time=24.515), 0.329786 s/step
# Meep progress: 24.575/77.5 = 31.7% done in 1539.9s, 3316.3s to go
# on time step 4916 (time=24.58), 0.33237 s/step
# Meep progress: 24.64/77.5 = 31.8% done in 1544.2s, 3312.7s to go
# on time step 4929 (time=24.645), 0.329135 s/step
# Meep progress: 24.705000000000002/77.5 = 31.9% done in 1548.5s, 3309.1s to go
# on time step 4942 (time=24.71), 0.329412 s/step
# Meep progress: 24.77/77.5 = 32.0% done in 1552.7s, 3305.4s to go
# on time step 4955 (time=24.775), 0.330047 s/step
# Meep progress: 24.835/77.5 = 32.0% done in 1557.0s, 3301.9s to go
# on time step 4968 (time=24.84), 0.331926 s/step
# Meep progress: 24.900000000000002/77.5 = 32.1% done in 1561.4s, 3298.3s to go
# on time step 4981 (time=24.905), 0.332571 s/step
# Meep progress: 24.965/77.5 = 32.2% done in 1565.7s, 3294.7s to go
# on time step 4994 (time=24.97), 0.329277 s/step
# Meep progress: 25.025000000000002/77.5 = 32.3% done in 1569.7s, 3291.4s to go
# on time step 5006 (time=25.03), 0.334146 s/step
# Meep progress: 25.09/77.5 = 32.4% done in 1574.0s, 3287.8s to go
# on time step 5019 (time=25.095), 0.330805 s/step
# Meep progress: 25.155/77.5 = 32.5% done in 1578.3s, 3284.3s to go
# on time step 5032 (time=25.16), 0.331962 s/step
# Meep progress: 25.22/77.5 = 32.5% done in 1582.6s, 3280.7s to go
# on time step 5044 (time=25.22), 0.333705 s/step
# Meep progress: 25.285/77.5 = 32.6% done in 1586.9s, 3277.1s to go
# on time step 5057 (time=25.285), 0.329964 s/step
# Meep progress: 25.35/77.5 = 32.7% done in 1591.2s, 3273.4s to go
# on time step 5070 (time=25.35), 0.328983 s/step
# Meep progress: 25.415/77.5 = 32.8% done in 1595.5s, 3269.8s to go
# on time step 5083 (time=25.415), 0.331794 s/step
# Meep progress: 25.48/77.5 = 32.9% done in 1599.8s, 3266.2s to go
# on time step 5096 (time=25.48), 0.330414 s/step
# Meep progress: 25.545/77.5 = 33.0% done in 1604.1s, 3262.5s to go
# on time step 5109 (time=25.545), 0.330001 s/step
# Meep progress: 25.61/77.5 = 33.0% done in 1608.4s, 3258.9s to go
# on time step 5122 (time=25.61), 0.332816 s/step
# Meep progress: 25.675/77.5 = 33.1% done in 1612.7s, 3255.3s to go
# on time step 5135 (time=25.675), 0.331017 s/step
# Meep progress: 25.740000000000002/77.5 = 33.2% done in 1617.0s, 3251.6s to go
# on time step 5148 (time=25.74), 0.329821 s/step
# Meep progress: 25.805/77.5 = 33.3% done in 1621.3s, 3248.0s to go
# on time step 5161 (time=25.805), 0.332044 s/step
# Meep progress: 25.87/77.5 = 33.4% done in 1625.7s, 3244.4s to go
# on time step 5174 (time=25.87), 0.332672 s/step
# Meep progress: 25.935000000000002/77.5 = 33.5% done in 1629.9s, 3240.7s to go
# on time step 5187 (time=25.935), 0.328439 s/step
# Meep progress: 26.0/77.5 = 33.5% done in 1634.2s, 3237.0s to go
# on time step 5200 (time=26), 0.330836 s/step
# Meep progress: 26.065/77.5 = 33.6% done in 1638.5s, 3233.4s to go
# on time step 5213 (time=26.065), 0.329915 s/step
# Meep progress: 26.13/77.5 = 33.7% done in 1642.8s, 3229.7s to go
# on time step 5226 (time=26.13), 0.331213 s/step
# Meep progress: 26.195/77.5 = 33.8% done in 1647.1s, 3226.0s to go
# on time step 5239 (time=26.195), 0.330664 s/step
# Meep progress: 26.26/77.5 = 33.9% done in 1651.4s, 3222.3s to go
# on time step 5252 (time=26.26), 0.328114 s/step
# Meep progress: 26.325/77.5 = 34.0% done in 1655.7s, 3218.7s to go
# on time step 5265 (time=26.325), 0.332118 s/step
# Meep progress: 26.39/77.5 = 34.1% done in 1660.0s, 3215.0s to go
# on time step 5278 (time=26.39), 0.331439 s/step
# Meep progress: 26.455000000000002/77.5 = 34.1% done in 1664.3s, 3211.3s to go
# on time step 5291 (time=26.455), 0.330653 s/step
# Meep progress: 26.52/77.5 = 34.2% done in 1668.6s, 3207.6s to go
# on time step 5304 (time=26.52), 0.330337 s/step
# Meep progress: 26.585/77.5 = 34.3% done in 1673.0s, 3204.0s to go
# on time step 5317 (time=26.585), 0.333152 s/step
# Meep progress: 26.650000000000002/77.5 = 34.4% done in 1677.2s, 3200.3s to go
# on time step 5330 (time=26.65), 0.329662 s/step
# Meep progress: 26.715/77.5 = 34.5% done in 1681.6s, 3196.6s to go
# on time step 5343 (time=26.715), 0.331049 s/step
# Meep progress: 26.78/77.5 = 34.6% done in 1685.9s, 3192.9s to go
# on time step 5356 (time=26.78), 0.331006 s/step
# Meep progress: 26.845/77.5 = 34.6% done in 1690.1s, 3189.2s to go
# on time step 5369 (time=26.845), 0.329062 s/step
# Meep progress: 26.91/77.5 = 34.7% done in 1694.4s, 3185.4s to go
# on time step 5382 (time=26.91), 0.329071 s/step
# Meep progress: 26.975/77.5 = 34.8% done in 1698.6s, 3181.6s to go
# on time step 5395 (time=26.975), 0.32439 s/step
# Meep progress: 27.04/77.5 = 34.9% done in 1702.9s, 3177.8s to go
# on time step 5408 (time=27.04), 0.328167 s/step
# Meep progress: 27.105/77.5 = 35.0% done in 1707.1s, 3174.0s to go
# on time step 5421 (time=27.105), 0.324957 s/step
# Meep progress: 27.17/77.5 = 35.1% done in 1711.3s, 3170.1s to go
# on time step 5434 (time=27.17), 0.324441 s/step
# Meep progress: 27.240000000000002/77.5 = 35.1% done in 1715.5s, 3165.2s to go
# on time step 5448 (time=27.24), 0.295718 s/step
# Meep progress: 27.32/77.5 = 35.3% done in 1719.7s, 3158.6s to go
# on time step 5464 (time=27.32), 0.262163 s/step
# Meep progress: 27.425/77.5 = 35.4% done in 1723.7s, 3147.3s to go
# on time step 5485 (time=27.425), 0.191747 s/step
# Meep progress: 27.515/77.5 = 35.5% done in 1727.7s, 3138.7s to go
# on time step 5503 (time=27.515), 0.223329 s/step
# Meep progress: 27.6/77.5 = 35.6% done in 1731.8s, 3131.0s to go
# ...
# Meep progress: 69.60000000000001/77.5 = 89.8% done in 4439.9s, 504.0s to go
# on time step 13921 (time=69.605), 0.385594 s/step
# Meep progress: 69.655/77.5 = 89.9% done in 4444.1s, 500.5s to go
# on time step 13932 (time=69.66), 0.383387 s/step
# Meep progress: 69.71000000000001/77.5 = 89.9% done in 4448.3s, 497.1s to go
# on time step 13943 (time=69.715), 0.37971 s/step
# Meep progress: 69.765/77.5 = 90.0% done in 4452.5s, 493.7s to go
# on time step 13954 (time=69.77), 0.37907 s/step
# Meep progress: 69.82000000000001/77.5 = 90.1% done in 4456.7s, 490.2s to go
# on time step 13965 (time=69.825), 0.380464 s/step
# Meep progress: 69.875/77.5 = 90.2% done in 4460.9s, 486.8s to go
# on time step 13976 (time=69.88), 0.38059 s/step
# Meep progress: 69.93/77.5 = 90.2% done in 4465.0s, 483.3s to go
# on time step 13987 (time=69.935), 0.377872 s/step
# Meep progress: 69.985/77.5 = 90.3% done in 4469.4s, 479.9s to go
# on time step 13998 (time=69.99), 0.39238 s/step
# Meep progress: 70.04/77.5 = 90.4% done in 4473.4s, 476.5s to go
# on time step 14009 (time=70.045), 0.367867 s/step
# Meep progress: 70.10000000000001/77.5 = 90.5% done in 4477.6s, 472.7s to go
# on time step 14021 (time=70.105), 0.3483 s/step
# Meep progress: 70.16/77.5 = 90.5% done in 4481.8s, 468.9s to go
# on time step 14033 (time=70.165), 0.347912 s/step
# Meep progress: 70.22/77.5 = 90.6% done in 4485.9s, 465.1s to go
# on time step 14045 (time=70.225), 0.344478 s/step
# Meep progress: 70.28/77.5 = 90.7% done in 4490.1s, 461.3s to go
# on time step 14057 (time=70.285), 0.34644 s/step
# Meep progress: 70.34/77.5 = 90.8% done in 4494.3s, 457.5s to go
# on time step 14069 (time=70.345), 0.348341 s/step
# Meep progress: 70.4/77.5 = 90.8% done in 4498.4s, 453.7s to go
# on time step 14081 (time=70.405), 0.34791 s/step
# Meep progress: 70.46000000000001/77.5 = 90.9% done in 4502.6s, 449.9s to go
# on time step 14093 (time=70.465), 0.346371 s/step
# Meep progress: 70.52/77.5 = 91.0% done in 4506.7s, 446.1s to go
# on time step 14105 (time=70.525), 0.345834 s/step
# Meep progress: 70.58/77.5 = 91.1% done in 4510.9s, 442.3s to go
# on time step 14117 (time=70.585), 0.345198 s/step
# Meep progress: 70.64/77.5 = 91.1% done in 4515.1s, 438.5s to go
# on time step 14129 (time=70.645), 0.346525 s/step
# Meep progress: 70.7/77.5 = 91.2% done in 4519.2s, 434.7s to go
# on time step 14141 (time=70.705), 0.343649 s/step
# Meep progress: 70.76/77.5 = 91.3% done in 4523.4s, 430.9s to go
# on time step 14153 (time=70.765), 0.348503 s/step
# Meep progress: 70.82000000000001/77.5 = 91.4% done in 4527.5s, 427.1s to go
# on time step 14165 (time=70.825), 0.34691 s/step
# Meep progress: 70.88/77.5 = 91.5% done in 4531.7s, 423.3s to go
# on time step 14177 (time=70.885), 0.356423 s/step
# Meep progress: 70.94/77.5 = 91.5% done in 4536.0s, 419.5s to go
# on time step 14189 (time=70.945), 0.347488 s/step
# Meep progress: 71.0/77.5 = 91.6% done in 4540.2s, 415.6s to go
# on time step 14201 (time=71.005), 0.348187 s/step
# Meep progress: 71.06/77.5 = 91.7% done in 4544.3s, 411.8s to go
# on time step 14213 (time=71.065), 0.347029 s/step
# Meep progress: 71.12/77.5 = 91.8% done in 4548.5s, 408.0s to go
# on time step 14225 (time=71.125), 0.346105 s/step
# Meep progress: 71.18/77.5 = 91.8% done in 4552.6s, 404.2s to go
# on time step 14237 (time=71.185), 0.34333 s/step
# Meep progress: 71.24/77.5 = 91.9% done in 4556.8s, 400.4s to go
# on time step 14249 (time=71.245), 0.347253 s/step
# Meep progress: 71.3/77.5 = 92.0% done in 4561.0s, 396.6s to go
# on time step 14261 (time=71.305), 0.354863 s/step
# Meep progress: 71.36/77.5 = 92.1% done in 4565.3s, 392.8s to go
# on time step 14273 (time=71.365), 0.35523 s/step
# Meep progress: 71.42/77.5 = 92.2% done in 4569.5s, 389.0s to go
# on time step 14285 (time=71.425), 0.351621 s/step
# Meep progress: 71.48/77.5 = 92.2% done in 4573.7s, 385.2s to go
# on time step 14297 (time=71.485), 0.352178 s/step
# Meep progress: 71.54/77.5 = 92.3% done in 4578.0s, 381.4s to go
# on time step 14309 (time=71.545), 0.353182 s/step
# Meep progress: 71.60000000000001/77.5 = 92.4% done in 4582.3s, 377.6s to go
# on time step 14321 (time=71.605), 0.360811 s/step
# Meep progress: 71.655/77.5 = 92.5% done in 4586.3s, 374.1s to go
# on time step 14333 (time=71.665), 0.358682 s/step
# Meep progress: 71.715/77.5 = 92.5% done in 4590.5s, 370.3s to go
# on time step 14345 (time=71.725), 0.352438 s/step
# Meep progress: 71.775/77.5 = 92.6% done in 4594.8s, 366.5s to go
# on time step 14357 (time=71.785), 0.35455 s/step
# Meep progress: 71.83500000000001/77.5 = 92.7% done in 4599.0s, 362.7s to go
# on time step 14369 (time=71.845), 0.350514 s/step
# Meep progress: 71.895/77.5 = 92.8% done in 4603.2s, 358.9s to go
# on time step 14381 (time=71.905), 0.350715 s/step
# Meep progress: 71.955/77.5 = 92.8% done in 4607.4s, 355.1s to go
# on time step 14393 (time=71.965), 0.351149 s/step
# Meep progress: 72.015/77.5 = 92.9% done in 4611.7s, 351.2s to go
# on time step 14405 (time=72.025), 0.3553 s/step
# Meep progress: 72.075/77.5 = 93.0% done in 4615.9s, 347.4s to go
# on time step 14417 (time=72.085), 0.352187 s/step
# Meep progress: 72.135/77.5 = 93.1% done in 4620.2s, 343.6s to go
# on time step 14429 (time=72.145), 0.354303 s/step
# Meep progress: 72.19500000000001/77.5 = 93.2% done in 4624.4s, 339.8s to go
# on time step 14441 (time=72.205), 0.356249 s/step
# Meep progress: 72.255/77.5 = 93.2% done in 4628.8s, 336.0s to go
# on time step 14452 (time=72.26), 0.364092 s/step
# Meep progress: 72.31/77.5 = 93.3% done in 4632.8s, 332.5s to go
# on time step 14464 (time=72.32), 0.362904 s/step
# Meep progress: 72.37/77.5 = 93.4% done in 4637.1s, 328.7s to go
# on time step 14476 (time=72.38), 0.362768 s/step
# Meep progress: 72.43/77.5 = 93.5% done in 4641.5s, 324.9s to go
# on time step 14488 (time=72.44), 0.363162 s/step
# Meep progress: 72.49/77.5 = 93.5% done in 4645.8s, 321.1s to go
# on time step 14500 (time=72.5), 0.360535 s/step
# Meep progress: 72.545/77.5 = 93.6% done in 4649.8s, 317.6s to go
# on time step 14512 (time=72.56), 0.363763 s/step
# Meep progress: 72.605/77.5 = 93.7% done in 4654.2s, 313.8s to go
# on time step 14524 (time=72.62), 0.361151 s/step
# Meep progress: 72.665/77.5 = 93.8% done in 4658.5s, 310.0s to go
# on time step 14536 (time=72.68), 0.36155 s/step
# Meep progress: 72.72500000000001/77.5 = 93.8% done in 4662.8s, 306.2s to go
# on time step 14548 (time=72.74), 0.3589 s/step
# Meep progress: 72.785/77.5 = 93.9% done in 4667.2s, 302.3s to go
# on time step 14560 (time=72.8), 0.361938 s/step
# Meep progress: 72.845/77.5 = 94.0% done in 4671.5s, 298.5s to go
# on time step 14572 (time=72.86), 0.359538 s/step
# Meep progress: 72.905/77.5 = 94.1% done in 4675.8s, 294.7s to go
# on time step 14584 (time=72.92), 0.359906 s/step
# Meep progress: 72.965/77.5 = 94.1% done in 4680.1s, 290.9s to go
# on time step 14596 (time=72.98), 0.362426 s/step
# Meep progress: 73.02/77.5 = 94.2% done in 4684.2s, 287.4s to go
# on time step 14607 (time=73.035), 0.369869 s/step
# Meep progress: 73.075/77.5 = 94.3% done in 4688.3s, 283.9s to go
# on time step 14618 (time=73.09), 0.374882 s/step
# Meep progress: 73.13/77.5 = 94.4% done in 4692.5s, 280.4s to go
# on time step 14629 (time=73.145), 0.377384 s/step
# Meep progress: 73.185/77.5 = 94.4% done in 4696.6s, 276.9s to go
# on time step 14640 (time=73.2), 0.373073 s/step
# Meep progress: 73.24/77.5 = 94.5% done in 4700.7s, 273.4s to go
# on time step 14651 (time=73.255), 0.378679 s/step
# Meep progress: 73.295/77.5 = 94.6% done in 4704.9s, 269.9s to go
# on time step 14662 (time=73.31), 0.379471 s/step
# Meep progress: 73.35000000000001/77.5 = 94.6% done in 4709.2s, 266.4s to go
# on time step 14673 (time=73.365), 0.398842 s/step
# Meep progress: 73.4/77.5 = 94.7% done in 4713.3s, 263.3s to go
# on time step 14683 (time=73.415), 0.413296 s/step
# Meep progress: 73.45/77.5 = 94.8% done in 4717.5s, 260.1s to go
# on time step 14693 (time=73.465), 0.412057 s/step
# Meep progress: 73.5/77.5 = 94.8% done in 4721.6s, 257.0s to go
# on time step 14703 (time=73.515), 0.414407 s/step
# Meep progress: 73.55/77.5 = 94.9% done in 4725.7s, 253.8s to go
# on time step 14713 (time=73.565), 0.410949 s/step
# Meep progress: 73.60000000000001/77.5 = 95.0% done in 4729.9s, 250.6s to go
# on time step 14723 (time=73.615), 0.414553 s/step
# Meep progress: 73.65/77.5 = 95.0% done in 4734.0s, 247.5s to go
# on time step 14733 (time=73.665), 0.415721 s/step
# Meep progress: 73.7/77.5 = 95.1% done in 4738.2s, 244.3s to go
# on time step 14743 (time=73.715), 0.413471 s/step
# Meep progress: 73.75/77.5 = 95.2% done in 4742.3s, 241.1s to go
# on time step 14753 (time=73.765), 0.414531 s/step
# Meep progress: 73.8/77.5 = 95.2% done in 4746.4s, 238.0s to go
# on time step 14763 (time=73.815), 0.415189 s/step
# Meep progress: 73.85000000000001/77.5 = 95.3% done in 4750.6s, 234.8s to go
# on time step 14773 (time=73.865), 0.415118 s/step
# Meep progress: 73.9/77.5 = 95.4% done in 4754.7s, 231.6s to go
# on time step 14783 (time=73.915), 0.41237 s/step
# Meep progress: 73.95/77.5 = 95.4% done in 4758.9s, 228.5s to go
# on time step 14793 (time=73.965), 0.41111 s/step
# Meep progress: 74.0/77.5 = 95.5% done in 4763.0s, 225.3s to go
# on time step 14803 (time=74.015), 0.414308 s/step
# Meep progress: 74.05/77.5 = 95.5% done in 4767.1s, 222.1s to go
# on time step 14813 (time=74.065), 0.413162 s/step
# Meep progress: 74.10000000000001/77.5 = 95.6% done in 4771.3s, 218.9s to go
# on time step 14823 (time=74.115), 0.415037 s/step
# Meep progress: 74.15/77.5 = 95.7% done in 4775.4s, 215.7s to go
# on time step 14833 (time=74.165), 0.411762 s/step
# Meep progress: 74.2/77.5 = 95.7% done in 4779.5s, 212.6s to go
# on time step 14843 (time=74.215), 0.412687 s/step
# Meep progress: 74.25/77.5 = 95.8% done in 4783.7s, 209.4s to go
# on time step 14853 (time=74.265), 0.412323 s/step
# Meep progress: 74.3/77.5 = 95.9% done in 4787.8s, 206.2s to go
# on time step 14863 (time=74.315), 0.409785 s/step
# Meep progress: 74.35000000000001/77.5 = 95.9% done in 4791.9s, 203.0s to go
# on time step 14873 (time=74.365), 0.409287 s/step
# Meep progress: 74.4/77.5 = 96.0% done in 4796.0s, 199.8s to go
# on time step 14883 (time=74.415), 0.410041 s/step
# Meep progress: 74.45/77.5 = 96.1% done in 4800.1s, 196.6s to go
# on time step 14893 (time=74.465), 0.409213 s/step
# Meep progress: 74.505/77.5 = 96.1% done in 4804.3s, 193.1s to go
# on time step 14905 (time=74.525), 0.350133 s/step
# Meep progress: 74.575/77.5 = 96.2% done in 4808.3s, 188.6s to go
# on time step 14919 (time=74.595), 0.288885 s/step
# Meep progress: 74.64/77.5 = 96.3% done in 4812.3s, 184.4s to go
# on time step 14932 (time=74.66), 0.326296 s/step
# Meep progress: 74.69500000000001/77.5 = 96.4% done in 4816.4s, 180.9s to go
# on time step 14944 (time=74.72), 0.340894 s/step
# Meep progress: 74.755/77.5 = 96.5% done in 4820.5s, 177.0s to go
# on time step 14955 (time=74.775), 0.37409 s/step
# Meep progress: 74.81/77.5 = 96.5% done in 4824.6s, 173.5s to go
# on time step 14966 (time=74.83), 0.375164 s/step
# Meep progress: 74.865/77.5 = 96.6% done in 4828.8s, 170.0s to go
# on time step 14977 (time=74.885), 0.379121 s/step
# Meep progress: 74.92/77.5 = 96.7% done in 4832.9s, 166.4s to go
# on time step 14988 (time=74.94), 0.373998 s/step
# Meep progress: 74.97500000000001/77.5 = 96.7% done in 4837.0s, 162.9s to go
# on time step 14999 (time=74.995), 0.370823 s/step
# Meep progress: 75.03/77.5 = 96.8% done in 4841.1s, 159.4s to go
# on time step 15010 (time=75.05), 0.374006 s/step
# Meep progress: 75.08500000000001/77.5 = 96.9% done in 4845.4s, 155.8s to go
# on time step 15021 (time=75.105), 0.387692 s/step
# Meep progress: 75.14/77.5 = 97.0% done in 4849.5s, 152.3s to go
# on time step 15032 (time=75.16), 0.386203 s/step
# Meep progress: 75.19500000000001/77.5 = 97.0% done in 4853.6s, 148.8s to go
# on time step 15044 (time=75.22), 0.34879 s/step
# Meep progress: 75.255/77.5 = 97.1% done in 4857.7s, 144.9s to go
# on time step 15056 (time=75.28), 0.345403 s/step
# Meep progress: 75.315/77.5 = 97.2% done in 4861.8s, 141.0s to go
# on time step 15068 (time=75.34), 0.337155 s/step
# Meep progress: 75.38/77.5 = 97.3% done in 4866.2s, 136.9s to go
# on time step 15080 (time=75.4), 0.334884 s/step
# Meep progress: 75.44/77.5 = 97.3% done in 4870.2s, 133.0s to go
# on time step 15092 (time=75.46), 0.336342 s/step
# Meep progress: 75.5/77.5 = 97.4% done in 4874.3s, 129.1s to go
# on time step 15104 (time=75.52), 0.346127 s/step
# Meep progress: 75.56/77.5 = 97.5% done in 4878.5s, 125.3s to go
# on time step 15116 (time=75.58), 0.338269 s/step
# Meep progress: 75.62/77.5 = 97.6% done in 4882.5s, 121.4s to go
# on time step 15128 (time=75.64), 0.337927 s/step
# Meep progress: 75.68/77.5 = 97.7% done in 4886.5s, 117.5s to go
# on time step 15140 (time=75.7), 0.334865 s/step
# Meep progress: 75.74/77.5 = 97.7% done in 4890.6s, 113.6s to go
# on time step 15152 (time=75.76), 0.33654 s/step
# Meep progress: 75.8/77.5 = 97.8% done in 4894.6s, 109.8s to go
# on time step 15164 (time=75.82), 0.336205 s/step
# Meep progress: 75.86/77.5 = 97.9% done in 4898.7s, 105.9s to go
# on time step 15176 (time=75.88), 0.347152 s/step
# Meep progress: 75.92/77.5 = 98.0% done in 4902.9s, 102.0s to go
# on time step 15188 (time=75.94), 0.351707 s/step
# Meep progress: 75.98/77.5 = 98.0% done in 4907.3s, 98.2s to go
# on time step 15200 (time=76), 0.359337 s/step
# Meep progress: 76.04/77.5 = 98.1% done in 4911.5s, 94.3s to go
# on time step 15212 (time=76.06), 0.352299 s/step
# Meep progress: 76.10000000000001/77.5 = 98.2% done in 4915.7s, 90.4s to go
# on time step 15224 (time=76.12), 0.35008 s/step
# Meep progress: 76.16/77.5 = 98.3% done in 4919.9s, 86.6s to go
# on time step 15236 (time=76.18), 0.348425 s/step
# Meep progress: 76.22/77.5 = 98.3% done in 4924.1s, 82.7s to go
# on time step 15248 (time=76.24), 0.359532 s/step
# Meep progress: 76.28/77.5 = 98.4% done in 4928.5s, 78.8s to go
# on time step 15260 (time=76.3), 0.361471 s/step
# Meep progress: 76.34/77.5 = 98.5% done in 4932.8s, 75.0s to go
# on time step 15272 (time=76.36), 0.360173 s/step
# Meep progress: 76.395/77.5 = 98.6% done in 4936.8s, 71.4s to go
# on time step 15284 (time=76.42), 0.363585 s/step
# Meep progress: 76.455/77.5 = 98.7% done in 4941.1s, 67.5s to go
# on time step 15296 (time=76.48), 0.359775 s/step
# Meep progress: 76.515/77.5 = 98.7% done in 4945.4s, 63.7s to go
# on time step 15308 (time=76.54), 0.353809 s/step
# Meep progress: 76.575/77.5 = 98.8% done in 4949.7s, 59.8s to go
# on time step 15320 (time=76.6), 0.363559 s/step
# Meep progress: 76.63/77.5 = 98.9% done in 4953.7s, 56.2s to go
# on time step 15331 (time=76.655), 0.363815 s/step
# Meep progress: 76.685/77.5 = 98.9% done in 4957.7s, 52.7s to go
# on time step 15343 (time=76.715), 0.363518 s/step
# Meep progress: 76.745/77.5 = 99.0% done in 4962.1s, 48.8s to go
# on time step 15355 (time=76.775), 0.362616 s/step
# Meep progress: 76.8/77.5 = 99.1% done in 4966.2s, 45.3s to go
# on time step 15366 (time=76.83), 0.371341 s/step
# Meep progress: 76.86/77.5 = 99.2% done in 4970.5s, 41.4s to go
# on time step 15378 (time=76.89), 0.360233 s/step
# Meep progress: 76.915/77.5 = 99.2% done in 4974.5s, 37.8s to go
# on time step 15389 (time=76.945), 0.364233 s/step
# Meep progress: 76.97500000000001/77.5 = 99.3% done in 4978.7s, 34.0s to go
# on time step 15401 (time=77.005), 0.339588 s/step
# Meep progress: 77.035/77.5 = 99.4% done in 4982.8s, 30.1s to go
# on time step 15413 (time=77.065), 0.336898 s/step
# Meep progress: 77.095/77.5 = 99.5% done in 4986.8s, 26.2s to go
# on time step 15425 (time=77.125), 0.337867 s/step
# Meep progress: 77.155/77.5 = 99.6% done in 4990.9s, 22.3s to go
# on time step 15437 (time=77.185), 0.33689 s/step
# Meep progress: 77.215/77.5 = 99.6% done in 4995.0s, 18.4s to go
# on time step 15449 (time=77.245), 0.340517 s/step
# Meep progress: 77.275/77.5 = 99.7% done in 4999.0s, 14.6s to go
# on time step 15461 (time=77.305), 0.337492 s/step
# Meep progress: 77.33500000000001/77.5 = 99.8% done in 5003.1s, 10.7s to go
# on time step 15473 (time=77.365), 0.339096 s/step
# Meep progress: 77.395/77.5 = 99.9% done in 5007.2s, 6.8s to go
# on time step 15485 (time=77.425), 0.33654 s/step
# Meep progress: 77.455/77.5 = 99.9% done in 5011.2s, 2.9s to go
# on time step 15497 (time=77.485), 0.337759 s/step
# run 0 finished at t = 77.5 (15500 timesteps)

# %%
Ex_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ex,0)
Ey_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ey,0)
Ez_xz = opt.sim.get_dft_array(dft_fields_xz,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xz.npy',Ex_xz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xz.npy',Ey_xz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xz.npy',Ez_xz)

Ex_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ex,0)
Ey_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ey,0)
Ez_yz = opt.sim.get_dft_array(dft_fields_yz,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_yz.npy',Ex_yz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_yz.npy',Ey_yz)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_yz.npy',Ez_yz)

Ex01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ex,0)
Ey01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ey,0)
Ez01 = opt.sim.get_dft_array(dft_fields_xyz12,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xyz1.npy',Ex01)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xyz1.npy',Ey01)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xyz1.npy',Ez01)

Ex00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ex,0)
Ey00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ey,0)
Ez00 = opt.sim.get_dft_array(dft_fields_xyz00,mp.Ez,0)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ex_xyz0.npy',Ex00)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ey_xyz0.npy',Ey00)
np.save('DFT_empty_GAS/Dft_empty_GAS_Ez_xyz0.npy',Ez00)
